# %%
import os, pickle
import pandas as pd

# %%
with open("../../../training_data/7.Extra_set/features.pkl", "rb") as f:
    featuresd = pickle.load(f)

len(featuresd), featuresd
# Out:
# (16,
#  {'7gqu': {'label_asym_id': ['D']},
#   '7x6v': {'label_asym_id': ['A']},
#   '7yg5': {'label_asym_id': ['V']},
#   '8aq6': {'label_asym_id': ['IA']},
#   '8cgw': {'label_asym_id': ['P']},
#   '8f4s': {'label_asym_id': ['D']},
#   '8jp0': {'label_asym_id': ['B']},
#   '8qni': {'label_asym_id': ['B']},
#   '8qns': {'label_asym_id': ['E']},
#   '8r4b': [{'label_asym_id': ['B']}, {'label_asym_id': ['C']}],
#   '8uk6': {'label_asym_id': ['C']},
#   '8v81': {'label_asym_id': ['L']},
#   '8vsd': {'label_asym_id': ['B', 'C']},
#   '9ckc': {'label_asym_id': ['E']},
#   '9dnm': {'label_asym_id': ['D']},
#   '9fvb': {'label_asym_id': ['C']}})

# %% [markdown]
# # "Predict"

# %% [markdown]
# On website.
#
# AllositePro doesn't find any sites for **9dnm** (and 8r4b, 8vsd; proteic modulators)
#
# <br>

# %%
# Any missing
for pdb in featuresd:
    pdbdir = f"{pdb}"
    if not os.path.isdir(pdbdir):
        os.makedirs(pdbdir, exist_ok=True)
    elif len(os.listdir(pdbdir)) < 2:
        pass
    else:
        continue
    print("Missing:", pdb)
# Out:
# Missing: 8aq6
# Missing: 8r4b
# Missing: 8vsd
# Missing: 9dnm

# %%
import tarfile

# %%
# Uncompress manually placed result
for pdb in featuresd:
    pdbdir = f"{pdb}"
    tar_exists = False
    for f in os.listdir(pdbdir):
        if f.endswith(".tar.gz"):
            tar_exists = True
            outdir = f"{pdbdir}/{f.replace('.tar.gz', '')}"
            if not os.path.isdir(outdir):
                with tarfile.open(f"{pdbdir}/{f}", 'r:gz') as tar:
                    tar.extractall(path=pdbdir)
                
    if not tar_exists:
        print("Missing result .tar.gz:", pdb)
# Out:
# Missing result .tar.gz: 8r4b
# Missing result .tar.gz: 8vsd
# Missing result .tar.gz: 9dnm

# %%
from Bio import PDB

# %%
# Sanity check
for pdb in featuresd:
    pdbdir = f"{pdb}"
    pdb_exists = False
    for d in os.listdir(pdbdir):
        if os.path.isdir(f"{pdbdir}/{d}") and not d.startswith("."):
            pdbf = f"{pdbdir}/{d}/{d.replace('_download', '')}.pdb"
            if os.path.isfile(pdbf):
                # Check that the length of the input pdb and output pdb (without heteroatoms of the pocket spheres) are the same
                if len(tuple(
                    residue
                    for model in PDB.PDBParser(QUIET=True).get_structure(pdb, f"../structures/{pdb}.pdb")
                    for chain in model
                    for residue in chain
                )) != len(tuple(
                    residue
                    for model in PDB.PDBParser(QUIET=True).get_structure(pdb, pdbf)
                    for chain in model
                    for residue in chain
                    if residue.id[0] == ' ' # it's not heteroatom                    
                )):
                    print("Input and output PDBs with different number of residues:", pdb)
            else:
                print("Missing pdb:", pdb)

# %% [markdown]
# # Processing

# %%
def process_allositepro_txt(file):
    with open(file, "r") as f:
        text = f.read().strip()
        lines = text.split('\n')
        pockets = {}
        current_pocket = None
    
        for line in lines:
            if line.startswith('pocket'):
                current_pocket = line
                pockets[current_pocket] = {}
            else:
                try:
                    key, value = line.split(':')
                except:
                    print(line)
                pockets[current_pocket][key.strip()] = float(value.strip())
    
        return pd.DataFrame(pockets).T.to_dict(orient="index")#.sort_values("hitScore", ascending=False)

# %%
import re

def process_allositepro_pml(file):
    with open(file, "r") as f:
        pymol_text = f.read().strip()
        pockets_dict = {}

        ## Lines can look like either:
        ## cmd.select("pocket2","///A/569+619+495+493+534+301+491+567+553+")
        ## cmd.select("pocket0","///A/187.0+15.0+250.0+251.0+186.0+247.0+254.0+") # PDBs with insertion codes
        
        # Pattern to match each pocket selection command
        pocket_pattern = re.compile(r'cmd\.select\("(?P<pocket>pocket\d+)",".+?"\)')
        # Pattern to match chain and residues within each selection command
        chain_residue_pattern = re.compile(r'///(?P<chain>\w+)/(?P<residues>[\d\.\+]+)')
    
        for pocket_match in pocket_pattern.finditer(pymol_text):
            pocket = pocket_match.group('pocket')
            selection_command = pocket_match.group(0)
            residues_list = []

            for chain_residue_match in chain_residue_pattern.finditer(selection_command):
                chain = chain_residue_match.group('chain')
                residues = chain_residue_match.group('residues').split('+')
                
                if any(res.endswith(".0") for res in residues): # Residues of PDBs with insertion codes
                    residues = tuple(res.replace(".0", "") for res in residues)

                residues_list.extend([(res, chain) for res in residues if res.isdigit()])
    
            if pocket not in pockets_dict:
                pockets_dict[pocket] = {
                    'auth_asym_id': [],
                    'auth_seq_id': []
                }
    
            for res, chain in residues_list:
                pockets_dict[pocket]['auth_seq_id'].append(res)
                pockets_dict[pocket]['auth_asym_id'].append(chain)
    
        return pockets_dict, chain_residue_match

# %%
allositepro_results = {}

for pdb in featuresd:
    pdbdir = f"{pdb}"
    if len([d for d in os.listdir(pdbdir) if not d.startswith(".")]) == 0:
        print("Missing:", pdb)
        continue

    jobid = next(f for f in os.listdir(pdbdir) if f.endswith(".tar.gz")).replace("_download.tar.gz", "")
    d = f"{pdbdir}/{jobid}_download"

    pockets = process_allositepro_txt(f"{d}/{jobid}.txt")
    pockets_res, chain_residue_match = process_allositepro_pml(f"{d}/{jobid}.pml")
    assert set(pockets.keys()) == set(pockets_res.keys())
    for p in list(pockets.keys()):
        pockets[p]["residues"] = pd.DataFrame(pockets_res[p], dtype=str)

    allositepro_results[pdb] = pockets

len(allositepro_results), allositepro_results
# Out:
# Missing: 8r4b
# Missing: 8vsd
# Missing: 9dnm
# {'7gqu': {'pocket0': {'Volume': 425.497,
#    'SASA': 211.983,
#    'Druggability Score': 0.565,
#    'logitProb': 0.564,
#    'nmaScore': 0.994,
#    'hitScore': 0.65,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         703
#    1             A         849
#    2             A         846
#    3             A         704
#    4             A         845
#    5             A         913
#    6             A         891
#    7             A         916
#    8             A         917
#    9             A         850
#    10            A         728
#    11            A         727
#    12            A         706
#    13            A         895
#    14            A         898
#    15            A         572
#    16            A         570
#    17            A         571}},
#  '7x6v': {'pocket0': {'Volume': 2655.098,
#    'SASA': 1562.978,
#    'Druggability Score': 0.78,
#    'logitProb': 0.64,
#    'nmaScore': 0.121,
#    'hitScore': 0.537,
#    'residues':    auth_asym_id auth_seq_id
#    0             A        1611
#    1             A         319
#    2             A        1615
#    3             A         505
#    4             A         339
#    5             A         378
#    6             A         328
#    7             A         320
#    8             A        1442
#    9             A         439
#    10            A         324
#    11            A         331
#    12            A         322
#    13            A         440
#    14            A         337
#    15            A         326
#    16            A         333
#    17            A         442
#    18            A        1630
#    19            A         437
#    20            A         435
#    21            A         423
#    22            A         446
#    23            A         431
#    24            A         427
#    25            A         506
#    26            A         325
#    27            A        1612
#    28            A         316
#    29            A        1616
#    30            A         340
#    31            A        1628
#    32            A         428
#    33            A         343
#    34            A         334
#    35            A         379
#    36            A         336
#    37            A         332
#    38            A         443
#    39            A         327
#    40            A         447
#    41            A         341
#    42            A         329
#    43            A         434
#    44            A         330
#    45            A         426
#    46            A         430
#    47            A         323
#    48            A         436
#    49            A         382
#    50            A         433
#    51            A         380
#    52            A         424},
#   'pocket1': {'Volume': 609.573,
#    'SASA': 285.464,
#    'Druggability Score': 0.226,
#    'logitProb': 0.654,
#    'nmaScore': 0.119,
#    'hitScore': 0.547,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         619
#    1             A         579
#    2             A         485
#    3             A         481
#    4             A         487
#    5             A         583
#    6             A         483
#    7             A         475
#    8             A         301
#    9             A         611
#    10            A         615
#    11            A         477
#    12            A         479
#    13            A         291
#    14            A         578
#    15            A         486
#    16            A         586
#    17            A         582
#    18            A         480
#    19            A         288
#    20            A         298
#    21            A         302
#    22            A         482
#    23            A         476
#    24            A         614
#    25            A         612
#    26            A         616
#    27            A         292},
#   'pocket2': {'Volume': 597.982,
#    'SASA': 213.294,
#    'Druggability Score': 0.451,
#    'logitProb': 0.68,
#    'nmaScore': 0.122,
#    'hitScore': 0.569,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         569
#    1             A         619
#    2             A         495
#    3             A         493
#    4             A         534
#    5             A         301
#    6             A         491
#    7             A         567
#    8             A         553
#    9             A         555
#    10            A         532
#    11            A         297
#    12            A         565
#    13            A         488
#    14            A         618
#    15            A         615
#    16            A         568
#    17            A         575
#    18            A         496
#    19            A         492
#    20            A         541
#    21            A         572
#    22            A         533
#    23            A         300
#    24            A         539
#    25            A         489}},
#  '7yg5': {'pocket0': {'Volume': 608.234,
#    'SASA': 328.383,
#    'Druggability Score': 0.848,
#    'logitProb': 0.783,
#    'nmaScore': 0.144,
#    'hitScore': 0.655,
#    'residues':    auth_asym_id auth_seq_id
#    0             A        1616
#    1             A        1283
#    2             A        1617
#    3             A        1269
#    4             A        1620
#    5             A        1713
#    6             A        1279
#    7             A        1282
#    8             A        1286
#    9             A        1709
#    10            A        1621
#    11            A        1613
#    12            A        1712
#    13            A        1266}},
#  '8aq6': {'pocket0': {'Volume': 792.509,
#    'SASA': 308.57,
#    'Druggability Score': 0.907,
#    'logitProb': 0.585,
#    'nmaScore': 0.227,
#    'hitScore': 0.513,
#    'residues':    auth_asym_id auth_seq_id
#    0             G         162
#    1             G          12
#    2             G          22
#    3             G          15
#    4             G          36
#    5             G          77
#    6             G          17
#    7             G          16
#    8             G          30
#    9             G          19
#    10            G         110
#    11            G          92
#    12            G          38
#    13            G          40
#    14            G          29
#    15            G          58
#    16            G          31
#    17            G          37
#    18            G          18}},
#  '8cgw': {'pocket0': {'Volume': 3162.802,
#    'SASA': 1726.621,
#    'Druggability Score': 0.722,
#    'logitProb': 0.78,
#    'nmaScore': 0.164,
#    'hitScore': 0.657,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         774
#    1             A         776
#    2             A         968
#    3             A         772
#    4             A         770
#    ..          ...         ...
#    65            A         825
#    66            A         961
#    67            A         523
#    68            A         971
#    69            A         529
#
#    [70 rows x 2 columns]}},
#  '8f4s': {'pocket0': {'Volume': 1497.231,
#    'SASA': 695.878,
#    'Druggability Score': 0.738,
#    'logitProb': 0.801,
#    'nmaScore': 0.173,
#    'hitScore': 0.675,
#    'residues':    auth_asym_id auth_seq_id
#    0             A        6917
#    1             A        6949
#    2             A        6931
#    3             A        6909
#    4             A        6947
#    5             A        6951
#    6             A        6957
#    7             A        6953
#    8             A        6927
#    9             A        6912
#    10            A        6910
#    11            A        6894
#    12            A        6958
#    13            A        6868
#    14            A        6896
#    15            A        7088
#    16            A        6916
#    17            A        6954
#    18            A        6869
#    19            A        6918
#    20            A        6950
#    21            A        6914
#    22            A        6898
#    23            A        6922
#    24            A        6929
#    25            A        6866
#    26            A        6897
#    27            A        6895
#    28            A        6911
#    29            A        6913}},
#  '8jp0': {'pocket0': {'Volume': 374.703,
#    'SASA': 273.097,
#    'Druggability Score': 0.472,
#    'logitProb': 0.744,
#    'nmaScore': 0.119,
#    'hitScore': 0.619,
#    'residues':   auth_asym_id auth_seq_id
#    0            A         206
#    1            A         210
#    2            A         832
#    3            A         839
#    4            A         836
#    5            A         244
#    6            A         835
#    7            A         245
#    8            A         207
#    9            A         248}},
#  '8qni': {'pocket0': {'Volume': 1703.293,
#    'SASA': 807.696,
#    'Druggability Score': 0.749,
#    'logitProb': 0.669,
#    'nmaScore': 0.474,
#    'hitScore': 0.63,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         261
#    1             A         236
#    2             A         148
#    3             A         293
#    4             A         145
#    5             A         149
#    6             A         142
#    7             A         220
#    8             A         232
#    9             A         295
#    10            A         257
#    11            A         292
#    12            A         262
#    13            A         258
#    14            A         224
#    15            A         222
#    16            A         287
#    17            A         291
#    18            A         141
#    19            A         294
#    20            A         240
#    21            A         254
#    22            A         263
#    23            A         264
#    24            A         335
#    25            A         239
#    26            A         368
#    27            A         288
#    28            A         272
#    29            A         138
#    30            A         144
#    31            A         235
#    32            A         364
#    33            A         268
#    34            A         218
#    35            A         260
#    36            A         363
#    37            A         359
#    38            A         369
#    39            A         255
#    40            A         219
#    41            A         221
#    42            A         152
#    43            A         362
#    44            A         367
#    45            A         366}},
#  '8qns': {'pocket0': {'Volume': 1426.509,
#    'SASA': 748.743,
#    'Druggability Score': 0.267,
#    'logitProb': 0.766,
#    'nmaScore': 0.244,
#    'hitScore': 0.662,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         309
#    1             A         284
#    2             A         172
#    3             A         139
#    4             A         171
#    5             A         405
#    6             A         230
#    7             A         174
#    8             A         481
#    9             A         261
#    10            A         453
#    11            A         260
#    12            A         142
#    13            A         175
#    14            A         163
#    15            A         259
#    16            A         435
#    17            A         457
#    18            A         176
#    19            A         452
#    20            A         162
#    21            A         137
#    22            A         141
#    23            A         262
#    24            A         231
#    25            A         482
#    26            A         285
#    27            A         140
#    28            A         136
#    29            A         310
#    30            A         313
#    31            A         454
#    32            A         164
#    33            A         161
#    34            A         437
#    35            A         232
#    36            A         258
#    37            A         283
#    38            A         436
#    39            A         404
#    40            A         138
#    41            A         480
#    42            A         402},
#   'pocket1': {'Volume': 1842.624,
#    'SASA': 905.457,
#    'Druggability Score': 0.163,
#    'logitProb': 0.762,
#    'nmaScore': 0.508,
#    'hitScore': 0.711,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         309
#    1             A         498
#    2             A         284
#    3             A         263
#    4             A         306
#    5             A         450
#    6             A         501
#    7             A         481
#    8             A         448
#    9             A         451
#    10            A         500
#    11            A         446
#    12            A         497
#    13            A         308
#    14            A         335
#    15            A         568
#    16            A         479
#    17            A         452
#    18            A         307
#    19            A         341
#    20            A         417
#    21            A         396
#    22            A         342
#    23            A         334
#    24            A         264
#    25            A         397
#    26            A         399
#    27            A         494
#    28            A         310
#    29            A         493
#    30            A         437
#    31            A         283
#    32            A         311
#    33            A         449
#    34            A         398
#    35            A         339
#    36            A         395
#    37            A         496
#    38            A         340
#    39            A         480
#    40            A         495
#    41            A         453},
#   'pocket2': {'Volume': 1141.918,
#    'SASA': 522.795,
#    'Druggability Score': 0.242,
#    'logitProb': 0.644,
#    'nmaScore': 0.211,
#    'hitScore': 0.557,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         617
#    1             A         358
#    2             A         183
#    3             A         191
#    4             A         316
#    5             A         175
#    6             A         199
#    7             A         484
#    8             A         176
#    9             A         195
#    10            A         486
#    11            A         192
#    12            A         182
#    13            A         181
#    14            A         320
#    15            A         313
#    16            A         487
#    17            A         193
#    18            A         177
#    19            A         180
#    20            A         317}},
#  '8uk6': {'pocket0': {'Volume': 1013.8,
#    'SASA': 484.166,
#    'Druggability Score': 0.517,
#    'logitProb': 0.663,
#    'nmaScore': 0.263,
#    'hitScore': 0.583,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         448
#    1             A         275
#    2             A         458
#    3             A         255
#    4             A         417
#    5             A         405
#    6             A         468
#    7             A         483
#    8             A         289
#    9             A         440
#    10            A         257
#    11            A         403
#    12            A         444
#    13            A         456
#    14            A         291
#    15            A         258
#    16            A         459
#    17            A         462
#    18            A         486
#    19            A         268
#    20            A         469
#    21            A         323
#    22            A         256
#    23            A         443
#    24            A         472
#    25            A         441
#    26            A         457
#    27            A         445
#    28            A         465
#    29            A         447
#    30            A         271
#    31            A         259},
#   'pocket1': {'Volume': 1061.007,
#    'SASA': 443.879,
#    'Druggability Score': 0.6,
#    'logitProb': 0.783,
#    'nmaScore': 0.105,
#    'hitScore': 0.648,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         495
#    1             A         497
#    2             A         493
#    3             A         518
#    4             A         520
#    5             A         700
#    6             A         262
#    7             A         264
#    8             A         699
#    9             A         498
#    10            A         268
#    11            A         496
#    12            A         494
#    13            A         519
#    14            A         302
#    15            A         703
#    16            A         513
#    17            A         701
#    18            A         501
#    19            A         517
#    20            A         259
#    21            A         261
#    22            A         265
#    23            A         263}},
#  '8v81': {'pocket0': {'Volume': 351.637,
#    'SASA': 192.926,
#    'Druggability Score': 0.535,
#    'logitProb': 0.716,
#    'nmaScore': 0.193,
#    'hitScore': 0.611,
#    'residues':    auth_asym_id auth_seq_id
#    0             A        1143
#    1             A        1142
#    2             A        1001
#    3             A         921
#    4             A         923
#    5             A        1138
#    6             A         920
#    7             A        1000
#    8             A        1139
#    9             A         924
#    10            A        1004
#    11            A        1135
#    12            A         344
#    13            A        1008
#    14            A        1005}},
#  '9ckc': {'pocket0': {'Volume': 3938.864,
#    'SASA': 1674.756,
#    'Druggability Score': 0.696,
#    'logitProb': 0.864,
#    'nmaScore': 0.425,
#    'hitScore': 0.776,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         260
#    1             A         228
#    2             A         261
#    3             A         185
#    4             A         378
#    ..          ...         ...
#    60            A         182
#    61            A          19
#    62            A         202
#    63            A         376
#    64            A         238
#
#    [65 rows x 2 columns]},
#   'pocket1': {'Volume': 2065.941,
#    'SASA': 1037.907,
#    'Druggability Score': 0.104,
#    'logitProb': 0.691,
#    'nmaScore': 0.343,
#    'hitScore': 0.622,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         345
#    1             A         299
#    2             A         338
#    3             A         370
#    4             A         387
#    5             A         340
#    6             A         248
#    7             A         250
#    8             A         191
#    9             A         383
#    10            A         341
#    11            A         380
#    12            A         344
#    13            A         251
#    14            A         241
#    15            A         247
#    16            A         384
#    17            A         295
#    18            A         274
#    19            A         273
#    20            A         249
#    21            A         244
#    22            A         270
#    23            A         303
#    24            A         277
#    25            A         292
#    26            A         246
#    27            A         255
#    28            A         242
#    29            A         190
#    30            A         374
#    31            A         256
#    32            A         245
#    33            A         302
#    34            A         252
#    35            A         253
#    36            A         306},
#   'pocket2': {'Volume': 470.635,
#    'SASA': 223.762,
#    'Druggability Score': 0.521,
#    'logitProb': 0.609,
#    'nmaScore': 0.127,
#    'hitScore': 0.513,
#    'residues':   auth_asym_id auth_seq_id
#    0            A         356
#    1            A         351
#    2            A         391
#    3            A         190
#    4            A         387
#    5            A         394
#    6            A         347
#    7            A         390
#    8            A         395}},
#  '9fvb': {'pocket0': {'Volume': 503.929,
#    'SASA': 246.096,
#    'Druggability Score': 0.743,
#    'logitProb': 0.847,
#    'nmaScore': 0.659,
#    'hitScore': 0.81,
#    'residues':    auth_asym_id auth_seq_id
#    0             A         187
#    1             A          15
#    2             A         250
#    3             A         251
#    4             A         186
#    5             A         247
#    6             A         254
#    7             A         123
#    8             A          14
#    9             A         124
#    10            A         122
#    11            A         188
#    12            A         189
#    13            A         246
#    14            A          10
#    15            A          16}}}

# %%
allositepro_resultsf = "allositepro_results.pkl"

with open(allositepro_resultsf, "wb") as f:
    pickle.dump(allositepro_results, f)
