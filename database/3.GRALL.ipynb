# %% [markdown]
# # Database

# %%
import src
from src import *
from src.creation import create_entry, combine_sites, NoModulator

# %%
db.init('database.db')
src.allodb.save_cifs = True

# %%
import pandas as pd
pd.DF = pd.DataFrame

# %% [markdown]
# # Data in GRALL
#
# Data is based on the molecules/ligands, and only the entries with `Level of Confidence` of 1 and 2 have structural evidence (i.e., PDB structures to be included in the database), either in (1) Glycine receptor subunit alpha-1 or alpha-3, or in (2) related receptors of the ligand-gated ion channel (LGIC) family.
#
# Therefore, all Uniprots of the LGIC family with an annotation score of 5/5 are going to be retrieved, and used to query the PDB database for structures that contain both a LGIC Uniprot protein chain and a molecule that matches one of the SMILES of the database for which structural data is annotated as available (Level of Confidence 1 or 2).

# %%
df = pd.read_csv("grall-v3.0-website-4-download.csv", na_values="N.A", keep_default_na=True)
df
# Out:
#                 Name                                             SMILES  \
# 0         conivaptan  Cc1nc2c([nH]1)CCN(C(=O)c1ccc(NC(=O)c3ccccc3-c3...
# 1         PNU-120596                COc1cc(OC)c(NC(=O)Nc2cc(C)on2)cc1Cl
# 2           pimozide  O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc...
# 3    cholecalciferol  C=C1CC[C@H](O)C/C1=C/C=C1\CCC[C@@]2(C)[C@H]1CC...
# 4         cinacalcet      C[C@@H](NCCCc1cccc(C(F)(F)F)c1)c1cccc2ccccc12
# ..               ...                                                ...
# 215    Maksay2004-4e      Nc1cccc(C(=O)O[C@@H]2C[C@@H]3CC[C@H](C2)N3)c1
# 216    Maksay2004-2k  CN1[C@H]2CC[C@@H]1C[C@H](OC(=O)c1cc(Cl)cc3c1OC...
# 217    Maksay2004-4d  CC1(C)Cc2cc(Cl)cc(C(=O)O[C@@H]3C[C@@H]4CC[C@H]...
# 218     Maksay2004-9       CCN1[C@H]2CC[C@@H]1C[C@@H](OC(=O)c1ccccc1)C2
# 219    Maksay2004-10         CN1[C@H]2CC[C@@H]1C[C@H](NC(=O)c1ccccc1)C2
#
#        Family   Binding Site  Level of Confidence Effect α1 Effect α3  \
# 0         HTS            NaN                  NaN         0       NaN
# 1         HTS            NaN                  NaN         0       NaN
# 2         HTS            NaN                  NaN         +       NaN
# 3         HTS            NaN                  NaN         +       NaN
# 4         HTS            NaN                  NaN         +       NaN
# ..        ...            ...                  ...       ...       ...
# 215  tropeine  (LA)-tropeine                  5.0         -         -
# 216  tropeine            NaN                  NaN         +         +
# 217  tropeine            NaN                  NaN         +         +
# 218  tropeine            NaN                  NaN         +         +
# 219  tropeine            NaN                  NaN         +         +
#
#     Activity Type α1 Activity Value α1 Activity Type α3 Activity Value α3  \
# 0           EC50(uM)          Inactive              NaN               NaN
# 1           EC50(uM)          Inactive              NaN               NaN
# 2           EC50(uM)               1.7              NaN               NaN
# 3           EC50(uM)               0.4              NaN               NaN
# 4           EC50(uM)              0.32              NaN               NaN
# ..               ...               ...              ...               ...
# 215           Kd(uM)              0.06           Kd(uM)              0.06
# 216           Kd(uM)              0.01           Kd(uM)              0.01
# 217           Kd(uM)          Inactive           Kd(uM)          Inactive
# 218           Kd(uM)               0.4           Kd(uM)               0.4
# 219           Kd(uM)              3.52           Kd(uM)              3.52
#
#                    doi  Kd_Resting(uM)  Kd_active(uM)  beta
# 0    10.1021/jm501873p             NaN            NaN   NaN
# 1    10.1021/jm501873p             NaN            NaN   NaN
# 2    10.1021/jm501873p             NaN            NaN   NaN
# 3    10.1021/jm501873p             NaN            NaN   NaN
# 4    10.1021/jm501873p             NaN            NaN   NaN
# ..                 ...             ...            ...   ...
# 215  10.1021/jm040814g        0.058479       0.081871  1.40
# 216  10.1021/jm040814g        0.232809       0.013969  0.06
# 217  10.1021/jm040814g        0.018113       0.002355  0.13
# 218  10.1021/jm040814g        0.729458       0.401202  0.55
# 219  10.1021/jm040814g       15.995580       3.519028  0.22
#
# [220 rows x 15 columns]

# %%
df_allo = df.loc[((df["Level of Confidence"] <= 2) & (df["Binding Site"] != "orthosteric"))]
df_allo
# Out:
#                      Name                                             SMILES  \
# 44                ethanol                                                CCO
# 57         ivermectin-b1a  CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@...
# 115  Pregnenolone-sulfate  CC(=O)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](OS(=O)...
# 116                 THDOC  C[C@]12CC[C@@H](O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C...
# 133              picrotin  CC(C)(O)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[...
# 134          picrotoxinin  C=C(C)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[C@...
# 136              propofol                              CC(C)c1cccc(C(C)C)c1O
# 142               AM-3607  C[C@H]1[C@H]2C(=O)N(C)c3ccncc3[C@H]2CN1S(=O)(=...
# 192           granisetron  CN1[C@H]2CCC[C@@H]1C[C@H](NC(=O)c1nn(C)c3ccccc...
#
#            Family      Binding Site  Level of Confidence Effect α1 Effect α3  \
# 44        alcohol           alcohol                  2.0         +         +
# 57     avermectin        ivermectin                  1.0         +       NaN
# 115  neurosteroid  (-)-neurosteroid                  2.0         -       NaN
# 116  neurosteroid  (+)-neurosteroid                  2.0         +       NaN
# 133    picrotoxin              pore                  1.0         -         -
# 134    picrotoxin              pore                  1.0         -         -
# 136      propofol           alcohol                  2.0         +       NaN
# 142   sulfonamide           top_ECD                  1.0         +         +
# 192      tropeine     (LA)-tropeine                  2.0         -         -
#
#       Activity Type α1 Activity Value α1 Activity Type α3 Activity Value α3  \
# 44            EC50(uM)             50000              NaN               NaN
# 57            EC50(uM)               1.7              NaN               NaN
# 115             Ki(uM)               1.9              NaN               NaN
# 116  Maximum_effect(%)               161              NaN               NaN
# 133           IC50(uM)               5.2         IC50(uM)                 6
# 134           IC50(uM)               2.1         IC50(uM)              0.43
# 136        EC50(uM)a1b              12.5              NaN               NaN
# 142           EC50(uM)              0.03         EC50(uM)              0.05
# 192             Kd(uM)              12.5           Kd(uM)              12.5
#
#                                     doi  Kd_Resting(uM)  Kd_active(uM)  beta
# 44           10.1016/j.phrs.2015.07.002             NaN            NaN   NaN
# 57              10.1074/jbc.M110.107789             NaN            NaN   NaN
# 115       10.1016/S0028-3908(01)00071-5             NaN            NaN   NaN
# 116                    10.1113/JP272122             NaN            NaN   NaN
# 133    10.1111/j.1471-4159.2007.04850.x             NaN            NaN   NaN
# 134    10.1111/j.1471-4159.2007.04850.x             NaN            NaN   NaN
# 136  10.1213/01.ANE.0000120083.10269.54            19.0          10.26  0.54
# 142                   10.1038/nsmb.3329             NaN            NaN   NaN
# 192       10.1016/S0028-3908(02)00213-7            12.5          37.50  3.00

# %%
import os, pickle, requests, json

# %% [markdown]
# ##### Get Uniprots of LGIC family
#
# Annotation score 5/5

# %%
file = "LGIC_uniprots.json"

if not os.path.isfile(file):
    lgic_uniprots = requests.get(
            "https://rest.uniprot.org/uniprotkb/stream?format=list&query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family%22%29%29+AND+%28annotation_score%3A5%29"
        ).content.decode().split("\n")

    with open(file, "wb") as f:
        pickle.dump(lgic_uniprots, f)

with open(file, "rb") as f:
    lgic_uniprots = pickle.load(f)
    
lgic_uniprots
# Out:
# ['A0A0D9R3G4',
#  'A0A0D9REP3',
#  'A0A0P6K2L9',
#  'A0A286XUB1',
#  'A0A2I3MZA7',
#  'A0A2K5CQD9',
#  'A0A2K5MSW4',
#  'A0A2K5SCY3',
#  'A0A2K5U752',
#  'A0A2K6CE69',
#  'A0A2K6GC14',
#  'A0A2K6GGC7',
#  'A0A2K6KXI8',
#  'A0A2K6U733',
#  'A0A2R8MV58',
#  'A0A2R9CBB5',
#  'A0A2Y9EU19',
#  'A0A337SQQ4',
#  'A0A3Q7R9T2',
#  'A0A3Q7UG22',
#  'A0A452EZE1',
#  'A0A452T828',
#  'A0A452VFF0',
#  'A0A493U029',
#  'A0A4W2DFT2',
#  'A0A4X1TUM3',
#  'A0A4X1U8B8',
#  'A0A4X2KCK0',
#  'A0A6I8QF26',
#  'A0A8B7EN39',
#  'A0A8C0QAY2',
#  'A0A8C8WAS3',
#  'A0A8C8WIX8',
#  'A0A8D0GJ56',
#  'A0A8I3MZA4',
#  'A0A8I3PAT2',
#  'A0A8I6A8K2',
#  'A0A8J8YBP3',
#  'A5X5Y0',
#  'A8MPY1',
#  'D1LYT2',
#  'E1JJR2',
#  'F1RDZ6',
#  'F1SNR6',
#  'F6RM03',
#  'F6UQM3',
#  'F6YAL1',
#  'F6ZNX7',
#  'F7G2F3',
#  'F7GTN8',
#  'G1LMJ3',
#  'G1NVY3',
#  'G1S3B5',
#  'G1SHV0',
#  'G1SI02',
#  'G3REP2',
#  'G3T2T7',
#  'G3TNL3',
#  'G3W3E9',
#  'G5EBR3',
#  'G5ECJ0',
#  'G5ECT0',
#  'G5EG88',
#  'G7P8R5',
#  'H0VPE2',
#  'H0WJ85',
#  'H2PH52',
#  'H2QRU5',
#  'I3MQM4',
#  'K7GDT5',
#  'M3WNZ0',
#  'M3YQE3',
#  'M9PFD8',
#  'O00591',
#  'O14764',
#  'O18276',
#  'O70174',
#  'O70212',
#  'O75311',
#  'O93430',
#  'O95264',
#  'P02708',
#  'P02712',
#  'P02714',
#  'P02716',
#  'P02718',
#  'P04756',
#  'P04757',
#  'P04758',
#  'P04760',
#  'P07510',
#  'P07727',
#  'P08219',
#  'P08220',
#  'P09478',
#  'P09481',
#  'P09482',
#  'P09483',
#  'P09484',
#  'P09660',
#  'P09690',
#  'P0C2W5',
#  'P10063',
#  'P11230',
#  'P12389',
#  'P12390',
#  'P12391',
#  'P12392',
#  'P14867',
#  'P15431',
#  'P16305',
#  'P17644',
#  'P17787',
#  'P18505',
#  'P18506',
#  'P18507',
#  'P18508',
#  'P18916',
#  'P19969',
#  'P20236',
#  'P20237',
#  'P20420',
#  'P20781',
#  'P20782',
#  'P21548',
#  'P22300',
#  'P22723',
#  'P22770',
#  'P22771',
#  'P22933',
#  'P23415',
#  'P23416',
#  'P23574',
#  'P23576',
#  'P23979',
#  'P24045',
#  'P24046',
#  'P24524',
#  'P25108',
#  'P25109',
#  'P25110',
#  'P25123',
#  'P25162',
#  'P26048',
#  'P26049',
#  'P27681',
#  'P28471',
#  'P28472',
#  'P28473',
#  'P28476',
#  'P30191',
#  'P30532',
#  'P30926',
#  'P31644',
#  'P32297',
#  'P34271',
#  'P34903',
#  'P34904',
#  'P35563',
#  'P36544',
#  'P43143',
#  'P43144',
#  'P43681',
#  'P46098',
#  'P47742',
#  'P47869',
#  'P47870',
#  'P48167',
#  'P48168',
#  'P48169',
#  'P48180',
#  'P48181',
#  'P48182',
#  'P49582',
#  'P50571',
#  'P50572',
#  'P50573',
#  'P54131',
#  'P54244',
#  'P56475',
#  'P56476',
#  'P57695',
#  'P62812',
#  'P62813',
#  'P63079',
#  'P63080',
#  'P63137',
#  'P63138',
#  'P78334',
#  'Q04844',
#  'Q05901',
#  'Q05941',
#  'Q07001',
#  'Q07263',
#  'Q08832',
#  'Q08E50',
#  'Q15822',
#  'Q15825',
#  'Q16445',
#  'Q17328',
#  'Q21005',
#  'Q23022',
#  'Q24352',
#  'Q27218',
#  'Q2MKA5',
#  'Q401N2',
#  'Q5UMH9',
#  'Q61603',
#  'Q64018',
#  'Q70Z44',
#  'Q7KT97',
#  'Q7KTF7',
#  'Q7KTF8',
#  'Q7KTF9',
#  'Q7NDN8',
#  'Q7TNC8',
#  'Q866A2',
#  'Q86MN7',
#  'Q8BHJ7',
#  'Q8BMN3',
#  'Q8IPE2',
#  'Q8N1C3',
#  'Q8R493',
#  'Q8R4G9',
#  'Q8SWZ1',
#  'Q8T5F4',
#  'Q8WXA8',
#  'Q90845',
#  'Q91X60',
#  'Q91XP5',
#  'Q94900',
#  'Q95Y52',
#  'Q98880',
#  'Q99928',
#  'Q9D6F4',
#  'Q9DES9',
#  'Q9ERK7',
#  'Q9ES14',
#  'Q9GJS9',
#  'Q9GQ00',
#  'Q9GZZ6',
#  'Q9JHJ5',
#  'Q9JJ16',
#  'Q9JLB5',
#  'Q9JLF1',
#  'Q9N587',
#  'Q9R0W9',
#  'Q9R0Y8',
#  'Q9U298',
#  'Q9U358',
#  'Q9UGM1',
#  'Q9UN88',
#  'Q9V9Y4',
#  'Q9VDU9',
#  'Q9VL79',
#  'Q9VWI9',
#  'R4GDJ5',
#  'U3K0Q5',
#  '']

# %% [markdown]
# ##### Query the PDB

# %%
from rcsbsearchapi.search import AttributeQuery, ChemSimilarityQuery

# %%
file = "LGIC_pdbs.json"

if not os.path.isfile(file):
    pdb_query = {}
    
    for (name, smi) in df_allo[["Name", "SMILES"]].values.tolist():
        upquery = AttributeQuery(
            attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
            operator="in",
            negation=False,
            value=lgic_uniprots
        )
        smiquery = ChemSimilarityQuery(
            value=smi,
            query_type="descriptor",
            descriptor_type="SMILES",
            match_type="graph-relaxed" # To search for similar molecules to the SMILES
        )
    
        pdb_query[name] = (
            (name, smi),
            list((upquery & smiquery)()),
            list((upquery & smiquery)("mol_definition"))
        )

    with open(file, "wb") as f:
        pickle.dump(pdb_query, f)

with open(file, "rb") as f:
    pdb_query = pickle.load(f)
    
pdb_query
# Out:
# {'ethanol': (('ethanol', 'CCO'), ['4HFE'], ['EOH']),
#  'ivermectin-b1a': (('ivermectin-b1a',
#    'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2'),
#   ['3JAF', '5VDH', '5VDI', '6VM0', '6VM2', '6VM3', '8F4V', '8FE1', '8UZJ'],
#   ['IVM']),
#  'Pregnenolone-sulfate': (('Pregnenolone-sulfate',
#    'CC(=O)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](OS(=O)(=O)O)CC[C@]4(C)[C@H]3CC[C@]12C'),
#   ['5OSC', '8SGO'],
#   ['A8W']),
#  'THDOC': (('THDOC',
#    'C[C@]12CC[C@@H](O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](C(=O)CO)CC[C@@H]12'),
#   ['5OSB'],
#   ['A8Z']),
#  'picrotin': (('picrotin',
#    'CC(C)(O)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[C@@]34O[C@@H]3C[C@]2(O)[C@@]14C'),
#   [],
#   []),
#  'picrotoxinin': (('picrotoxinin',
#    'C=C(C)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[C@@]34O[C@@H]3C[C@]2(O)[C@@]14C'),
#   ['6HUG', '6HUJ', '6UD3', '6X40', '8OQ8', '8OQA'],
#   ['RI5']),
#  'propofol': (('propofol', 'CC(C)c1cccc(C(C)C)c1O'),
#   ['3P50', '5MUO', '5MUR', '5MVM', '5MVN', '5MZR', '6X3T'],
#   ['PFL']),
#  'AM-3607': (('AM-3607',
#    'C[C@H]1[C@H]2C(=O)N(C)c3ccncc3[C@H]2CN1S(=O)(=O)c1ccc2c(c1)OCO2'),
#   ['5TIN', '5TIO', '5VDH', '5VDI'],
#   ['7C6']),
#  'granisetron': (('granisetron',
#    'CN1[C@H]2CCC[C@@H]1C[C@H](NC(=O)c1nn(C)c3ccccc13)C2'),
#   ['6NP0'],
#   ['CWB'])}

# %%
[p for v in pdb_query.values() for p in v[1]]
# Out:
# ['4HFE',
#  '3JAF',
#  '5VDH',
#  '5VDI',
#  '6VM0',
#  '6VM2',
#  '6VM3',
#  '8F4V',
#  '8FE1',
#  '8UZJ',
#  '5OSC',
#  '8SGO',
#  '5OSB',
#  '6HUG',
#  '6HUJ',
#  '6UD3',
#  '6X40',
#  '8OQ8',
#  '8OQA',
#  '3P50',
#  '5MUO',
#  '5MUR',
#  '5MVM',
#  '5MVN',
#  '5MZR',
#  '6X3T',
#  '5TIN',
#  '5TIO',
#  '5VDH',
#  '5VDI',
#  '6NP0']

# %%
len([p for v in pdb_query.values() for p in v[1]]), "PDBs"
# Out:
# (31, 'PDBs')

# %% [markdown]
# ## Data already in the database

# %%
list(PDB.select().where(PDB.entry_id.in_([p.lower() for v in pdb_query.values() for p in v[1]])))
# Out:
# [<PDB: 3jaf>,
#  <PDB: 3p50>,
#  <PDB: 5muo>,
#  <PDB: 5mur>,
#  <PDB: 5mvn>,
#  <PDB: 5osb>,
#  <PDB: 5osc>,
#  <PDB: 5vdh>,
#  <PDB: 5vdi>]

# %%
len(PDB.select().where(PDB.entry_id.in_([p.lower() for v in pdb_query.values() for p in v[1]]))), "PDBs already in the database"
# Out:
# (9, 'PDBs already in the database')

# %%
[
    (
        p.entry_id, 
        list(s.modulator_residues.label_comp_id.unique().tolist() for s in p.sites),
        [(k, v[-1]) for k,v in pdb_query.items() if p.entry_id.upper() in v[-2]]
    )
    for p in list(PDB.select().where(PDB.entry_id.in_([p.lower() for v in pdb_query.values() for p in v[1]])))
    
]
# Out:
# [('3jaf', [['IVM']], [('ivermectin-b1a', ['IVM'])]),
#  ('3p50', [['PFL']], [('propofol', ['PFL'])]),
#  ('5muo', [['PFL']], [('propofol', ['PFL'])]),
#  ('5mur', [['PFL']], [('propofol', ['PFL'])]),
#  ('5mvn', [['PFL']], [('propofol', ['PFL'])]),
#  ('5osb', [['A8Z']], [('THDOC', ['A8Z'])]),
#  ('5osc', [['A8W']], [('Pregnenolone-sulfate', ['A8W'])]),
#  ('5vdh', [['IVM']], [('ivermectin-b1a', ['IVM']), ('AM-3607', ['7C6'])]),
#  ('5vdi', [['IVM']], [('ivermectin-b1a', ['IVM']), ('AM-3607', ['7C6'])])]

# %% [markdown]
# ## Processing

# %%
processed = [pd.Series(index=df_allo.columns, dtype=object)]

# %%
errors = {}
error_entries = []

# %%
errors_groups = lambda: {
    val: sorted(
        k for k, v in errors.items()
        if any(map(lambda x: val in x, v))
    )
    for val in set(
        map(
            lambda x: x[0].split(": ")[-1], 
            errors.values()
        )
    )
}

# %%
def process_entry(entry, update={}, auto_site_grouping=True, stringent_site_grouping=True):
    try:
        pdb = update["pdb"]
        mod = update["mod"]
        print(pdb, mod)
    
        old_sites = None
        # If PDB already exists, save its site IDs
        if PDB.get_or_none(PDB.entry_id == pdb) is not None:
            old_sites = list(PDB.get(PDB.entry_id == pdb).sites)
            
        with db.atomic() as txn:
            sites = create_entry(db, pdb, mod, auto_site_grouping, stringent_site_grouping)
            
            assert len(sites.objects()) == 1, f"{pdb}, {mod}: using only residue name retrieves more than one site(group)"
            
            for site in sites.objects():
                site.info["source"] = {
                    "grall": [{
                        "entry": entry.to_dict(),
                        "version": '3.0',
                        "date": "12-3-2024",
                        "update": update
                    }],
                }
                site.save()
                
            if old_sites is not None:
                try:
                    combine_sites(db, pdb.lower(), old_sites, sites.objects(), auto_site_grouping, stringent_site_grouping)
                except Exception as e:
                    assert False, "combine_sites failed; " + str(e.args[0])

        return sites

    except (AssertionError, KeyError) as error:
        id = pdb.lower()
        errors.setdefault(id, [])
        errors[id].append(str(error.args[0]))
        error_entries.append(entry)
        print(id, errors[id])

# %%
pdb_query
# Out:
# {'ethanol': (('ethanol', 'CCO'), ['4HFE'], ['EOH']),
#  'ivermectin-b1a': (('ivermectin-b1a',
#    'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2'),
#   ['3JAF', '5VDH', '5VDI', '6VM0', '6VM2', '6VM3', '8F4V', '8FE1', '8UZJ'],
#   ['IVM']),
#  'Pregnenolone-sulfate': (('Pregnenolone-sulfate',
#    'CC(=O)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](OS(=O)(=O)O)CC[C@]4(C)[C@H]3CC[C@]12C'),
#   ['5OSC', '8SGO'],
#   ['A8W']),
#  'THDOC': (('THDOC',
#    'C[C@]12CC[C@@H](O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](C(=O)CO)CC[C@@H]12'),
#   ['5OSB'],
#   ['A8Z']),
#  'picrotin': (('picrotin',
#    'CC(C)(O)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[C@@]34O[C@@H]3C[C@]2(O)[C@@]14C'),
#   [],
#   []),
#  'picrotoxinin': (('picrotoxinin',
#    'C=C(C)[C@H]1[C@@H]2C(=O)O[C@H]1[C@H]1OC(=O)[C@@]34O[C@@H]3C[C@]2(O)[C@@]14C'),
#   ['6HUG', '6HUJ', '6UD3', '6X40', '8OQ8', '8OQA'],
#   ['RI5']),
#  'propofol': (('propofol', 'CC(C)c1cccc(C(C)C)c1O'),
#   ['3P50', '5MUO', '5MUR', '5MVM', '5MVN', '5MZR', '6X3T'],
#   ['PFL']),
#  'AM-3607': (('AM-3607',
#    'C[C@H]1[C@H]2C(=O)N(C)c3ccncc3[C@H]2CN1S(=O)(=O)c1ccc2c(c1)OCO2'),
#   ['5TIN', '5TIO', '5VDH', '5VDI'],
#   ['7C6']),
#  'granisetron': (('granisetron',
#    'CN1[C@H]2CCC[C@@H]1C[C@H](NC(=O)c1nn(C)c3ccccc13)C2'),
#   ['6NP0'],
#   ['CWB'])}

# %%
for name, (smi, pdbs, comp) in pdb_query.items():
    if len(pdbs) > 0 and len(comp) > 0:
        entry = df_allo.query(f"Name == '{name}'").squeeze()
        assert len(comp) == 1
        for pdb in pdbs:
            process_entry(
                entry,
                {"pdb": pdb.lower(), "mod": [[{"auth_comp_id": comp[0]}]]},
                auto_site_grouping=True,
                stringent_site_grouping=True
            )
# Out:
# 4hfe [[{'auth_comp_id': 'EOH'}]]
# Downloading 4hfe
#  ExecutiveLoad-Warning: No _chem_comp_bond data for residue 'UNL'
#  ExecutiveLoad-Warning: No _chem_comp_bond data for residue 'UNL'
#  ExecutiveLoad-Warning: No _chem_comp_bond data for residue 'UNL'
#  ExecutiveLoad-Warning: No _chem_comp_bond data for residue 'UNL'
#  ExecutiveLoad-Warning: No _chem_comp_bond data for residue 'UNL'
# 3jaf [[{'auth_comp_id': 'IVM'}]]
# 5vdh [[{'auth_comp_id': 'IVM'}]]
# 5vdi [[{'auth_comp_id': 'IVM'}]]
# 6vm0 [[{'auth_comp_id': 'IVM'}]]
# Downloading 6vm0
# 6vm2 [[{'auth_comp_id': 'IVM'}]]
# Downloading 6vm2
# 6vm3 [[{'auth_comp_id': 'IVM'}]]
# Downloading 6vm3
# 8f4v [[{'auth_comp_id': 'IVM'}]]
# Downloading 8f4v
# 8fe1 [[{'auth_comp_id': 'IVM'}]]
# Downloading 8fe1
# 8fe1 ["8fe1, [[{'auth_comp_id': 'IVM'}]]: using only residue name retrieves more than one site(group)"]
# 8uzj [[{'auth_comp_id': 'IVM'}]]
# Downloading 8uzj
# 5osc [[{'auth_comp_id': 'A8W'}]]
# 8sgo [[{'auth_comp_id': 'A8W'}]]
# Downloading 8sgo
# 5osb [[{'auth_comp_id': 'A8Z'}]]
# 6hug [[{'auth_comp_id': 'RI5'}]]
# Downloading 6hug
# 6huj [[{'auth_comp_id': 'RI5'}]]
# Downloading 6huj
# 6ud3 [[{'auth_comp_id': 'RI5'}]]
# Downloading 6ud3
# 6x40 [[{'auth_comp_id': 'RI5'}]]
# Downloading 6x40
# 8oq8 [[{'auth_comp_id': 'RI5'}]]
# Downloading 8oq8
# 8oqa [[{'auth_comp_id': 'RI5'}]]
# Downloading 8oqa
# 3p50 [[{'auth_comp_id': 'PFL'}]]
# 5muo [[{'auth_comp_id': 'PFL'}]]
# 5mur [[{'auth_comp_id': 'PFL'}]]
# 5mvm [[{'auth_comp_id': 'PFL'}]]
# Downloading 5mvm
# 5mvn [[{'auth_comp_id': 'PFL'}]]
# 5mzr [[{'auth_comp_id': 'PFL'}]]
# Downloading 5mzr
# 6x3t [[{'auth_comp_id': 'PFL'}]]
# Downloading 6x3t
# 5tin [[{'auth_comp_id': '7C6'}]]
# Downloading 5tin
# 5tio [[{'auth_comp_id': '7C6'}]]
# Downloading 5tio
# 5vdh [[{'auth_comp_id': '7C6'}]]
# 5vdi [[{'auth_comp_id': '7C6'}]]
# 6np0 [[{'auth_comp_id': 'CWB'}]]
# Downloading 6np0

# %% [markdown]
# ### Error correction

# %%
errors
# Out:
# {'8fe1': ["8fe1, [[{'auth_comp_id': 'IVM'}]]: using only residue name retrieves more than one site(group)"]}

# %%
PDB.get_or_none(PDB.entry_id == "8fe1")

# %%
name = "ivermectin-b1a"
pdb = "8fe1"
comp = "IVM"

for chain in ["H", "R", "QA"]:
    process_entry(
        entry,
        {"pdb": pdb.lower(), "mod": [[{"auth_comp_id": comp, 
                                       "label_asym_id": chain}]]},
        auto_site_grouping=True,
        stringent_site_grouping=True
    )
# Out:
# 8fe1 [[{'auth_comp_id': 'IVM', 'label_asym_id': 'H'}]]
# 8fe1 [[{'auth_comp_id': 'IVM', 'label_asym_id': 'R'}]]
# 8fe1 [[{'auth_comp_id': 'IVM', 'label_asym_id': 'QA'}]]

# %%
[s.modulator for s in PDB.get_or_none(PDB.entry_id == "8fe1").sites]
# Out:
# [{'label_asym_id': ['H']}, {'label_asym_id': ['R']}, {'label_asym_id': ['FA']}]

# %% [markdown]
# The pentamer contains a monomer of a different isoform than the rest of monomers that makes the sites of IVM different.
#
# <br>

# %%
grall_sites = list(list(s.info["source"].keys()) for s in Site.select().where(Site.info["source"].contains("grall")))
grall_sites
# Out:
# [['grall'],
#  ['allosteric_database', 'grall'],
#  ['allosteric_database', 'grall'],
#  ['allosteric_database', 'grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['allosteric_database', 'grall'],
#  ['grall'],
#  ['allosteric_database', 'grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['allosteric_database', 'grall'],
#  ['allosteric_database', 'grall'],
#  ['allosteric_database', 'grall'],
#  ['grall'],
#  ['allosteric_database', 'grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall'],
#  ['grall']]

# %%
grall_sites.count(['allosteric_database', 'grall'])
# Out:
# 9

# %%
grall_sites.count(['grall'])
# Out:
# 24

# %% [markdown]
# # Statistics

# %%
# Total number of sites
len(Site.select())
# Out:
# 3181

# %%
# Total number of different PDBs
len(PDB.select())
# Out:
# 3041

# %%
# PDBs with no sites (expected 0)
[(pdb.entry_id, pdb) for p in PDB.select() if len(p.sites) == 0]
# Out:
# []

# %%
# Number of sites in PDBs
set(len(p.sites) for p in PDB.select())
# Out:
# {1, 2, 3, 4}

# %%
# Modulator identifier fields used
set(tuple(s.modulator.keys()) for s in Site.select())
# Out:
# {('label_asym_id',)}

# %%
# Number of different entity instances (different "label_asym_id") annotated as modulators to look for outliers
modulator_chains = dict(
    sorted(
        {s.id: len(s.modulator["label_asym_id"]) for s in Site.select()}.items(),
        key=lambda i: i[-1], reverse=True
    )
)
modulator_chains
# Out:
# {520: 24,
#  582: 8,
#  608: 6,
#  4806: 6,
#  5088: 6,
#  5246: 6,
#  5320: 6,
#  5365: 6,
#  160: 4,
#  187: 4,
#  193: 4,
#  368: 4,
#  380: 4,
#  412: 4,
#  684: 4,
#  741: 4,
#  4493: 4,
#  4767: 4,
#  336: 3,
#  419: 3,
#  481: 3,
#  482: 3,
#  483: 3,
#  552: 3,
#  569: 3,
#  570: 3,
#  592: 3,
#  599: 3,
#  615: 3,
#  624: 3,
#  2319: 3,
#  2327: 3,
#  2334: 3,
#  2633: 3,
#  4542: 3,
#  4559: 3,
#  4577: 3,
#  4590: 3,
#  4636: 3,
#  4733: 3,
#  4834: 3,
#  4842: 3,
#  4863: 3,
#  4886: 3,
#  4907: 3,
#  4929: 3,
#  4949: 3,
#  4966: 3,
#  4979: 3,
#  4992: 3,
#  5002: 3,
#  5003: 3,
#  5122: 3,
#  5143: 3,
#  5190: 3,
#  5200: 3,
#  5267: 3,
#  5272: 3,
#  5382: 3,
#  5463: 3,
#  5471: 3,
#  5474: 3,
#  5: 2,
#  14: 2,
#  51: 2,
#  75: 2,
#  81: 2,
#  91: 2,
#  92: 2,
#  93: 2,
#  94: 2,
#  95: 2,
#  97: 2,
#  136: 2,
#  140: 2,
#  144: 2,
#  147: 2,
#  150: 2,
#  153: 2,
#  168: 2,
#  175: 2,
#  198: 2,
#  248: 2,
#  254: 2,
#  269: 2,
#  272: 2,
#  288: 2,
#  318: 2,
#  328: 2,
#  339: 2,
#  371: 2,
#  383: 2,
#  418: 2,
#  432: 2,
#  446: 2,
#  463: 2,
#  467: 2,
#  480: 2,
#  488: 2,
#  491: 2,
#  523: 2,
#  526: 2,
#  529: 2,
#  530: 2,
#  573: 2,
#  585: 2,
#  627: 2,
#  748: 2,
#  752: 2,
#  755: 2,
#  762: 2,
#  767: 2,
#  771: 2,
#  783: 2,
#  1035: 2,
#  1039: 2,
#  1071: 2,
#  1074: 2,
#  1107: 2,
#  1111: 2,
#  1115: 2,
#  1118: 2,
#  1121: 2,
#  1124: 2,
#  1133: 2,
#  1136: 2,
#  1141: 2,
#  1152: 2,
#  1215: 2,
#  1262: 2,
#  1267: 2,
#  1272: 2,
#  1282: 2,
#  1291: 2,
#  1300: 2,
#  1305: 2,
#  1314: 2,
#  1329: 2,
#  1340: 2,
#  1346: 2,
#  1356: 2,
#  1365: 2,
#  1374: 2,
#  1383: 2,
#  1392: 2,
#  1397: 2,
#  1406: 2,
#  1415: 2,
#  1424: 2,
#  1429: 2,
#  1438: 2,
#  1447: 2,
#  1456: 2,
#  1461: 2,
#  1466: 2,
#  1557: 2,
#  1571: 2,
#  1575: 2,
#  1580: 2,
#  1584: 2,
#  1588: 2,
#  1602: 2,
#  1605: 2,
#  1617: 2,
#  1627: 2,
#  1633: 2,
#  1664: 2,
#  1668: 2,
#  1674: 2,
#  1678: 2,
#  1684: 2,
#  1729: 2,
#  1949: 2,
#  1958: 2,
#  2643: 2,
#  2648: 2,
#  2654: 2,
#  2659: 2,
#  2681: 2,
#  2781: 2,
#  2788: 2,
#  2795: 2,
#  2826: 2,
#  2833: 2,
#  2864: 2,
#  3054: 2,
#  3057: 2,
#  3518: 2,
#  3545: 2,
#  3570: 2,
#  3619: 2,
#  3622: 2,
#  3625: 2,
#  3667: 2,
#  3672: 2,
#  3706: 2,
#  3718: 2,
#  3898: 2,
#  3948: 2,
#  3955: 2,
#  3961: 2,
#  4305: 2,
#  4317: 2,
#  4320: 2,
#  4323: 2,
#  4326: 2,
#  4329: 2,
#  4332: 2,
#  4391: 2,
#  4399: 2,
#  4409: 2,
#  4421: 2,
#  4504: 2,
#  4598: 2,
#  4622: 2,
#  4644: 2,
#  4654: 2,
#  4665: 2,
#  4679: 2,
#  4705: 2,
#  4815: 2,
#  4823: 2,
#  4826: 2,
#  4835: 2,
#  4856: 2,
#  4857: 2,
#  4996: 2,
#  5001: 2,
#  5156: 2,
#  5169: 2,
#  5195: 2,
#  5209: 2,
#  5213: 2,
#  5218: 2,
#  5275: 2,
#  5368: 2,
#  5390: 2,
#  5393: 2,
#  5397: 2,
#  5410: 2,
#  5469: 2,
#  5519: 2,
#  6: 1,
#  7: 1,
#  8: 1,
#  9: 1,
#  10: 1,
#  11: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  18: 1,
#  19: 1,
#  21: 1,
#  22: 1,
#  23: 1,
#  24: 1,
#  25: 1,
#  28: 1,
#  29: 1,
#  31: 1,
#  32: 1,
#  33: 1,
#  34: 1,
#  35: 1,
#  36: 1,
#  37: 1,
#  38: 1,
#  39: 1,
#  40: 1,
#  41: 1,
#  42: 1,
#  43: 1,
#  44: 1,
#  45: 1,
#  46: 1,
#  52: 1,
#  53: 1,
#  54: 1,
#  55: 1,
#  56: 1,
#  57: 1,
#  58: 1,
#  59: 1,
#  60: 1,
#  61: 1,
#  62: 1,
#  63: 1,
#  64: 1,
#  65: 1,
#  66: 1,
#  67: 1,
#  68: 1,
#  70: 1,
#  71: 1,
#  72: 1,
#  76: 1,
#  78: 1,
#  82: 1,
#  83: 1,
#  84: 1,
#  85: 1,
#  86: 1,
#  87: 1,
#  88: 1,
#  99: 1,
#  113: 1,
#  114: 1,
#  116: 1,
#  117: 1,
#  118: 1,
#  119: 1,
#  120: 1,
#  121: 1,
#  123: 1,
#  124: 1,
#  125: 1,
#  126: 1,
#  127: 1,
#  128: 1,
#  129: 1,
#  130: 1,
#  131: 1,
#  132: 1,
#  176: 1,
#  177: 1,
#  178: 1,
#  194: 1,
#  195: 1,
#  223: 1,
#  224: 1,
#  225: 1,
#  226: 1,
#  227: 1,
#  228: 1,
#  229: 1,
#  230: 1,
#  231: 1,
#  232: 1,
#  233: 1,
#  234: 1,
#  235: 1,
#  236: 1,
#  238: 1,
#  239: 1,
#  240: 1,
#  241: 1,
#  242: 1,
#  247: 1,
#  253: 1,
#  273: 1,
#  274: 1,
#  275: 1,
#  276: 1,
#  277: 1,
#  278: 1,
#  279: 1,
#  280: 1,
#  281: 1,
#  282: 1,
#  283: 1,
#  284: 1,
#  300: 1,
#  301: 1,
#  303: 1,
#  305: 1,
#  306: 1,
#  307: 1,
#  308: 1,
#  309: 1,
#  310: 1,
#  311: 1,
#  312: 1,
#  313: 1,
#  314: 1,
#  315: 1,
#  319: 1,
#  320: 1,
#  321: 1,
#  751: 1,
#  784: 1,
#  785: 1,
#  786: 1,
#  787: 1,
#  789: 1,
#  790: 1,
#  791: 1,
#  792: 1,
#  793: 1,
#  794: 1,
#  795: 1,
#  796: 1,
#  797: 1,
#  798: 1,
#  799: 1,
#  800: 1,
#  801: 1,
#  802: 1,
#  804: 1,
#  805: 1,
#  811: 1,
#  812: 1,
#  815: 1,
#  816: 1,
#  817: 1,
#  818: 1,
#  819: 1,
#  820: 1,
#  824: 1,
#  826: 1,
#  827: 1,
#  828: 1,
#  830: 1,
#  831: 1,
#  832: 1,
#  834: 1,
#  835: 1,
#  836: 1,
#  837: 1,
#  838: 1,
#  839: 1,
#  840: 1,
#  841: 1,
#  842: 1,
#  843: 1,
#  844: 1,
#  845: 1,
#  846: 1,
#  847: 1,
#  850: 1,
#  852: 1,
#  861: 1,
#  862: 1,
#  865: 1,
#  866: 1,
#  867: 1,
#  868: 1,
#  869: 1,
#  870: 1,
#  872: 1,
#  876: 1,
#  877: 1,
#  878: 1,
#  879: 1,
#  880: 1,
#  886: 1,
#  888: 1,
#  892: 1,
#  893: 1,
#  894: 1,
#  896: 1,
#  897: 1,
#  898: 1,
#  899: 1,
#  900: 1,
#  901: 1,
#  902: 1,
#  903: 1,
#  904: 1,
#  905: 1,
#  906: 1,
#  907: 1,
#  908: 1,
#  909: 1,
#  910: 1,
#  911: 1,
#  912: 1,
#  913: 1,
#  914: 1,
#  915: 1,
#  916: 1,
#  917: 1,
#  918: 1,
#  919: 1,
#  920: 1,
#  921: 1,
#  922: 1,
#  923: 1,
#  924: 1,
#  925: 1,
#  927: 1,
#  928: 1,
#  930: 1,
#  931: 1,
#  933: 1,
#  934: 1,
#  935: 1,
#  936: 1,
#  937: 1,
#  938: 1,
#  939: 1,
#  940: 1,
#  941: 1,
#  942: 1,
#  943: 1,
#  944: 1,
#  945: 1,
#  946: 1,
#  947: 1,
#  948: 1,
#  949: 1,
#  950: 1,
#  951: 1,
#  952: 1,
#  953: 1,
#  954: 1,
#  955: 1,
#  956: 1,
#  957: 1,
#  958: 1,
#  960: 1,
#  961: 1,
#  973: 1,
#  974: 1,
#  975: 1,
#  976: 1,
#  977: 1,
#  978: 1,
#  979: 1,
#  980: 1,
#  981: 1,
#  982: 1,
#  983: 1,
#  984: 1,
#  985: 1,
#  986: 1,
#  987: 1,
#  988: 1,
#  989: 1,
#  990: 1,
#  991: 1,
#  992: 1,
#  993: 1,
#  994: 1,
#  995: 1,
#  996: 1,
#  997: 1,
#  998: 1,
#  999: 1,
#  1000: 1,
#  1001: 1,
#  1002: 1,
#  1003: 1,
#  1004: 1,
#  1005: 1,
#  1006: 1,
#  1007: 1,
#  1008: 1,
#  1009: 1,
#  1010: 1,
#  1012: 1,
#  1015: 1,
#  1016: 1,
#  1017: 1,
#  1018: 1,
#  1020: 1,
#  1021: 1,
#  1022: 1,
#  1023: 1,
#  1024: 1,
#  1025: 1,
#  1026: 1,
#  1027: 1,
#  1029: 1,
#  1030: 1,
#  1031: 1,
#  1032: 1,
#  1036: 1,
#  1040: 1,
#  1041: 1,
#  1045: 1,
#  1046: 1,
#  1047: 1,
#  1048: 1,
#  1049: 1,
#  1050: 1,
#  1051: 1,
#  1052: 1,
#  1053: 1,
#  1054: 1,
#  1055: 1,
#  1056: 1,
#  1057: 1,
#  1058: 1,
#  1059: 1,
#  1060: 1,
#  1061: 1,
#  1062: 1,
#  1063: 1,
#  1064: 1,
#  1065: 1,
#  1066: 1,
#  1067: 1,
#  1068: 1,
#  1075: 1,
#  1076: 1,
#  1078: 1,
#  1079: 1,
#  1080: 1,
#  1081: 1,
#  1082: 1,
#  1083: 1,
#  1084: 1,
#  1085: 1,
#  1086: 1,
#  1087: 1,
#  1089: 1,
#  1090: 1,
#  1091: 1,
#  1092: 1,
#  1093: 1,
#  1094: 1,
#  1095: 1,
#  1096: 1,
#  1097: 1,
#  1098: 1,
#  1099: 1,
#  1100: 1,
#  1102: 1,
#  1154: 1,
#  1155: 1,
#  1156: 1,
#  1157: 1,
#  1158: 1,
#  1159: 1,
#  1160: 1,
#  1161: 1,
#  1162: 1,
#  1163: 1,
#  1164: 1,
#  1165: 1,
#  1166: 1,
#  1167: 1,
#  1168: 1,
#  1169: 1,
#  1170: 1,
#  1171: 1,
#  1172: 1,
#  1173: 1,
#  1174: 1,
#  1175: 1,
#  1176: 1,
#  1177: 1,
#  1178: 1,
#  1179: 1,
#  1180: 1,
#  1181: 1,
#  1183: 1,
#  1184: 1,
#  1187: 1,
#  1188: 1,
#  1189: 1,
#  1190: 1,
#  1192: 1,
#  1193: 1,
#  1194: 1,
#  1195: 1,
#  1196: 1,
#  1199: 1,
#  1201: 1,
#  1202: 1,
#  1203: 1,
#  1204: 1,
#  1205: 1,
#  1206: 1,
#  1207: 1,
#  1208: 1,
#  1209: 1,
#  1210: 1,
#  1211: 1,
#  1216: 1,
#  1217: 1,
#  1218: 1,
#  1219: 1,
#  1220: 1,
#  1221: 1,
#  1222: 1,
#  1223: 1,
#  1224: 1,
#  1225: 1,
#  1226: 1,
#  1227: 1,
#  1228: 1,
#  1229: 1,
#  1230: 1,
#  1231: 1,
#  1232: 1,
#  1233: 1,
#  1234: 1,
#  1235: 1,
#  1236: 1,
#  1237: 1,
#  1238: 1,
#  1239: 1,
#  1240: 1,
#  1241: 1,
#  1242: 1,
#  1243: 1,
#  1244: 1,
#  1245: 1,
#  1246: 1,
#  1247: 1,
#  1248: 1,
#  1249: 1,
#  1250: 1,
#  1251: 1,
#  1252: 1,
#  1253: 1,
#  1254: 1,
#  1255: 1,
#  1256: 1,
#  1257: 1,
#  1273: 1,
#  1315: 1,
#  1316: 1,
#  1317: 1,
#  1318: 1,
#  1319: 1,
#  1320: 1,
#  1330: 1,
#  1331: 1,
#  1341: 1,
#  1347: 1,
#  1467: 1,
#  1468: 1,
#  1469: 1,
#  1470: 1,
#  1471: 1,
#  1472: 1,
#  1473: 1,
#  1474: 1,
#  1475: 1,
#  1476: 1,
#  1477: 1,
#  1478: 1,
#  1479: 1,
#  1480: 1,
#  1481: 1,
#  1482: 1,
#  1483: 1,
#  1484: 1,
#  1485: 1,
#  1486: 1,
#  1487: 1,
#  1488: 1,
#  1489: 1,
#  1490: 1,
#  1491: 1,
#  1492: 1,
#  1493: 1,
#  1494: 1,
#  1495: 1,
#  1496: 1,
#  1497: 1,
#  1498: 1,
#  1499: 1,
#  1500: 1,
#  1501: 1,
#  1502: 1,
#  1508: 1,
#  1509: 1,
#  1510: 1,
#  1511: 1,
#  1512: 1,
#  1513: 1,
#  1514: 1,
#  1515: 1,
#  1516: 1,
#  1517: 1,
#  1518: 1,
#  1519: 1,
#  1520: 1,
#  1521: 1,
#  1522: 1,
#  1523: 1,
#  1524: 1,
#  1525: 1,
#  1526: 1,
#  1527: 1,
#  1528: 1,
#  1529: 1,
#  1530: 1,
#  1531: 1,
#  1532: 1,
#  1533: 1,
#  1534: 1,
#  1535: 1,
#  1536: 1,
#  1537: 1,
#  1538: 1,
#  1539: 1,
#  1540: 1,
#  1541: 1,
#  1542: 1,
#  1543: 1,
#  1544: 1,
#  1545: 1,
#  1546: 1,
#  1547: 1,
#  1548: 1,
#  1549: 1,
#  1550: 1,
#  1551: 1,
#  1553: 1,
#  1560: 1,
#  1561: 1,
#  1562: 1,
#  1563: 1,
#  1564: 1,
#  1565: 1,
#  1566: 1,
#  1567: 1,
#  1572: 1,
#  1576: 1,
#  1589: 1,
#  1590: 1,
#  1591: 1,
#  1592: 1,
#  1593: 1,
#  1594: 1,
#  1595: 1,
#  1596: 1,
#  1597: 1,
#  1598: 1,
#  1599: 1,
#  1606: 1,
#  1607: 1,
#  1608: 1,
#  1610: 1,
#  1612: 1,
#  1613: 1,
#  1618: 1,
#  1619: 1,
#  1620: 1,
#  1621: 1,
#  1622: 1,
#  1624: 1,
#  1634: 1,
#  1635: 1,
#  1636: 1,
#  1637: 1,
#  1638: 1,
#  1639: 1,
#  1641: 1,
#  1643: 1,
#  1645: 1,
#  1646: 1,
#  1647: 1,
#  1649: 1,
#  1650: 1,
#  1651: 1,
#  1652: 1,
#  1653: 1,
#  1654: 1,
#  1655: 1,
#  1656: 1,
#  1657: 1,
#  1658: 1,
#  1659: 1,
#  1660: 1,
#  1661: 1,
#  1665: 1,
#  1669: 1,
#  1670: 1,
#  1671: 1,
#  1675: 1,
#  1679: 1,
#  1680: 1,
#  1681: 1,
#  1685: 1,
#  1686: 1,
#  1687: 1,
#  1688: 1,
#  1689: 1,
#  1690: 1,
#  1691: 1,
#  1692: 1,
#  1693: 1,
#  1694: 1,
#  1695: 1,
#  1696: 1,
#  1697: 1,
#  1698: 1,
#  1699: 1,
#  1700: 1,
#  1701: 1,
#  1702: 1,
#  1703: 1,
#  1704: 1,
#  1705: 1,
#  1706: 1,
#  1707: 1,
#  1709: 1,
#  1711: 1,
#  1712: 1,
#  1713: 1,
#  1714: 1,
#  1715: 1,
#  1716: 1,
#  1717: 1,
#  1718: 1,
#  1720: 1,
#  1721: 1,
#  1722: 1,
#  1723: 1,
#  1724: 1,
#  1725: 1,
#  1726: 1,
#  1730: 1,
#  1731: 1,
#  1732: 1,
#  1733: 1,
#  1734: 1,
#  1735: 1,
#  1736: 1,
#  1737: 1,
#  1739: 1,
#  1740: 1,
#  1741: 1,
#  1742: 1,
#  1743: 1,
#  1744: 1,
#  1745: 1,
#  1746: 1,
#  1747: 1,
#  1748: 1,
#  1749: 1,
#  1752: 1,
#  1753: 1,
#  1754: 1,
#  1755: 1,
#  1756: 1,
#  1758: 1,
#  1759: 1,
#  1760: 1,
#  1761: 1,
#  1762: 1,
#  1763: 1,
#  1764: 1,
#  1766: 1,
#  1767: 1,
#  1768: 1,
#  1769: 1,
#  1770: 1,
#  1771: 1,
#  1773: 1,
#  1775: 1,
#  1776: 1,
#  1777: 1,
#  1779: 1,
#  1780: 1,
#  1781: 1,
#  1782: 1,
#  1783: 1,
#  1784: 1,
#  1785: 1,
#  1786: 1,
#  1787: 1,
#  1788: 1,
#  1795: 1,
#  1796: 1,
#  1797: 1,
#  1798: 1,
#  1799: 1,
#  1800: 1,
#  1801: 1,
#  1802: 1,
#  1803: 1,
#  1804: 1,
#  1805: 1,
#  1806: 1,
#  1807: 1,
#  1808: 1,
#  1809: 1,
#  1810: 1,
#  1811: 1,
#  1814: 1,
#  1815: 1,
#  1816: 1,
#  1817: 1,
#  1818: 1,
#  1819: 1,
#  1820: 1,
#  1821: 1,
#  1822: 1,
#  1823: 1,
#  1824: 1,
#  1825: 1,
#  1826: 1,
#  1827: 1,
#  1828: 1,
#  1829: 1,
#  1830: 1,
#  1832: 1,
#  1833: 1,
#  1834: 1,
#  1836: 1,
#  1837: 1,
#  1838: 1,
#  1839: 1,
#  ...}

# %%
db.close()
# Out:
# True
