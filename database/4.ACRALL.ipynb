# %% [markdown]
# # Database

# %%
import src
from src import *
from src.creation import create_entry, combine_sites, NoModulator

# %%
db.init('database.db')
src.allodb.save_cifs = True

# %%
import pandas as pd
pd.DF = pd.DataFrame

# %% [markdown]
# # Data in ACRALL
#
# Data is based on molecules, so only those which contain "NAM" or "PAM" as part of their effect on one of the three types of acetylcholine receptors (alpha4beta2, alpha7 and muscle) will be taken into account.
#
# The Uniprots of each AChR type will be separately retrieved, and used to query the PDB database for structures that contain both a Uniprot protein chain and a molecule that matches a SMILES of the database.
#
# Each selected SMILES will be queried only with the Uniprot of the AChR type for which the "NAM" or "PAM" effect is annotated and not all 3.

# %%
df = pd.read_excel("ACRALL-23Jun23.xlsx", sheet_name="ACRALL", header=1)
df
# Out:
#             cid                                               name  \
# 0           187                                      ACETYLCHOLINE
# 1           187                                      ACETYLCHOLINE
# 2           305                                            CHOLINE
# 3          1204                                        EPIBATIDINE
# 4          1204                                        EPIBATIDINE
# ...         ...                                                ...
# 7888  155556155             alphaO-conotoxin [C9S,C20S]GeXIVA[1,4]
# 7889  155557819  N-[(2S)-1-[3-[4-(3-aminopropylamino)butylamino...
# 7890  155562264  (1R,2R,3S,4S)-3-(6-chloropyridin-3-yl)bicyclo[...
# 7891  155564442  N-[(2S)-1-[3-[4-(3-aminopropylamino)butylamino...
# 7892  155564569             alphaO-conotoxin [C2A,C27A]GeXIVA[1,4]
#
#                                                  Smiles  \
# 0                                  CC(=O)OCC[N+](C)(C)C
# 1                                  CC(=O)OCC[N+](C)(C)C
# 2                                        C[N+](C)(C)CCO
# 3                          C1CC2C(CC1N2)C3=CN=C(C=C3)Cl
# 4                          C1CC2C(CC1N2)C3=CN=C(C=C3)Cl
# ...                                                 ...
# 7888              peptide[TCRSSGRYSRSPYDRRRRYSRRITDACV]
# 7889  C1CCC(CC1)C[C@@H](C(=O)NCCCNCCCCNCCCN)NC(=O)C2...
# 7890    C1C[C@@H]2C[C@H]1[C@H]([C@@H]2N)C3=CN=C(C=C3)Cl
# 7891  C1CCC(C1)C(=O)N[C@@H](CC2=CC=C(C=C2)O)C(=O)NCC...
# 7892              peptide[TARSSGRYCRSPYDRRRRYCRRITDAAV]
#
#                          inchikey in_vivo_tested  phase       alpha4beta2  \
# 0     OIPILFWXSMYKGL-UHFFFAOYSA-N            yes      4           agonist
# 1     OIPILFWXSMYKGL-UHFFFAOYSA-N            yes      4           agonist
# 2     OEYIOHPDSNJKLS-UHFFFAOYSA-N            yes      4  Unknown activity
# 3     NLPRAJRHRHZCQQ-UHFFFAOYSA-N            yes      0           agonist
# 4     NLPRAJRHRHZCQQ-UHFFFAOYSA-N            yes      0           agonist
# ...                           ...            ...    ...               ...
# 7888  SCLCAVDKGIIDIR-VLSRZGDXSA-N             No      0              N.A.
# 7889  FOBOXOHWDKQRAH-QFIPXVFZSA-N             No      0               NaN
# 7890  NKHNTAYDCXZLFL-IZLWQMGWSA-N             No      0               NaN
# 7891  QYFZGNQKVGYCKF-QHCPKHFHSA-N             No      0               NaN
# 7892  JHGVKJZRAQPJTO-JHKJEGEHSA-N             No      0              N.A.
#
#           alpha7        muscletype    targetname   metric     value  \
# 0        agonist           agonist    nAChR a4b2   Emax_%  172.0000
# 1        agonist           agonist      nAChR a7   Emax_%  110.0000
# 2        agonist  Unknown activity      nAChR a7   Emax_%   95.0000
# 3        agonist           agonist    nAChR a4b2   Emax_%  133.0000
# 4        agonist           agonist      nAChR a7   Emax_%  123.5000
# ...          ...               ...           ...      ...       ...
# 7888  antagonist               NaN  nAChR a1b1de  IC50_uM    2.9900
# 7889         NaN               NaN    nAChR a4b2  IC50_uM    0.0208
# 7890         NaN               NaN      nAChR a7  EC50_uM    2.7100
# 7891         NaN               NaN    nAChR a4b2  IC50_uM    0.0225
# 7892  antagonist               NaN      nAChR a7  IC50_uM    4.5800
#
#       reference   measure
# 0      16033252  efficacy
# 1      22468936  efficacy
# 2      16033252  efficacy
# 3      19232492  efficacy
# 4      16033252  efficacy
# ...         ...       ...
# 7888   31986036   potency
# 7889   31244109   potency
# 7890   30681854   potency
# 7891   31244109   potency
# 7892   31986036   potency
#
# [7893 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['cid', 'name', 'Smiles', 'inchikey', 'in_vivo_tested', 'phase',
#        'alpha4beta2', 'alpha7', 'muscletype', 'targetname', 'metric', 'value',
#        'reference', 'measure'],
#       dtype='object')

# %%
import numpy as np

# %%
set(np.concatenate(df[['alpha4beta2', 'alpha7', 'muscletype']].values))
# Out:
# {'N.A.',
#  'NAM',
#  'PAM',
#  'PAM (type n.a.)',
#  'PAM type I',
#  'PAM type II',
#  'Unknown activity',
#  'ago - PAM type II',
#  'agonist',
#  'antagonist',
#  'inactive',
#  nan,
#  'partial agonist',
#  'silent agonist'}

# %% [markdown]
# The only interesting effects are those that contain "PAM" or "NAM" ('contain' because there is an effect annotated as "ago - PAM type II").
#
# <br>

# %% [markdown]
# **ago - PAM type II**

# %%
df.query("'ago - PAM type II' in alpha4beta2 or 'ago - PAM type II' in alpha7 or 'ago - PAM type II' in muscletype")
# Out:
#           cid     name                                             Smiles  \
# 5692  6554040  GAT-107  C1C=C[C@H]2[C@@H]1[C@H](NC3=C2C=C(C=C3)S(=O)(=...
#
#                          inchikey in_vivo_tested  phase alpha4beta2  \
# 5692  YNCXHXYZTLIZTO-HDMKZQKVSA-N             No      0    inactive
#
#                  alpha7 muscletype targetname   metric  value  reference  \
# 5692  ago - PAM type II   inactive   nAChR a7  EC50_uM   28.0   24090443
#
#       measure
# 5692  potency

# %% [markdown]
# Indeed this ligand can act as an agonist by itself, binding on its allosteric-agonist binding sites; and also as a PAM of the orthosteric ligand.
#
# <br>

# %% [markdown]
# ## Selection of "PAM" or "NAM"

# %%
allosteric = df[
    df['alpha4beta2'].str.contains("AM", case=True, na=False)
    | df['alpha7'].str.contains("AM", case=True, na=False)
    | df['muscletype'].str.contains("AM", case=True, na=False)
]
allosteric
# Out:
#             cid                                               name  \
# 8          4032                                       MECAMYLAMINE
# 27       637026                            DESFORMYLFLUSTRABROMINE
# 59      5980988                           4,2,5-Trihydroxychalcone
# 255    11998180                                            NS-9283
# 470    44348296                                             KAB-18
# ...         ...                                                ...
# 7605  118714575  (Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyph...
# 7606  118714576  (E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trim...
# 7607  118714577                                       Compound 111
# 7608  118714578  (E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-d...
# 7609  118714579  (E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-in...
#
#                                                  Smiles  \
# 8                                CC1(C2CCC(C2)C1(C)NC)C
# 27              CC(C)(C=C)C1=C(C2=C(N1)C=C(C=C2)Br)CCNC
# 59            C1=CC(=CC=C1/C=C/C(=O)C2=C(C=CC(=C2)O)O)O
# 255            C1=CC(=CC(=C1)C2=NC(=NO2)C3=CN=CC=C3)C#N
# 470   C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4...
# ...                                                 ...
# 7605       C1=CC(=C(C=C1O)O)/C=C\C(=O)C2=C(C=CC(=C2)O)O
# 7606  CC1=C(C=CC(=C1)O)C(=O)/C=C/C2=C(C(=C(C=C2)OC)O...
# 7607     COC1=CC(=C(C=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)OC
# 7608  COC1=CC(=C(C(=C1)OC)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O
# 7609  C1=CC2=C(C=C1O)C(=CN2)/C=C/C(=O)C3=C(C=CC(=C3)O)O
#
#                          inchikey in_vivo_tested  phase alpha4beta2  \
# 8     IMYZQPCYWPFTAG-UHFFFAOYSA-N            yes      4         NAM
# 27    GQHSCJUTJKLZPX-UHFFFAOYSA-N             No      0         PAM
# 59    NMANELLSWUVZNL-XVNBXDOJSA-N            yes      0        N.A.
# 255   HGFXDSQLRSWUBO-UHFFFAOYSA-N            yes      0         PAM
# 470   FSLPUZLMGFJUNB-UHFFFAOYSA-N             No      0         NAM
# ...                           ...            ...    ...         ...
# 7605  NSGNPNKKTAPFEM-DJWKRKHSSA-N             No      0        N.A.
# 7606  WYADPPPAHTYQNX-WEVVVXLNSA-N             No      0        N.A.
# 7607  HOMVMWKJDBDBSW-QPJJXVBHSA-N             No      0        N.A.
# 7608  GKWKPCQXKSIKEP-GQCTYLIASA-N             No      0        N.A.
# 7609  JPSZEHWPNLUUOO-ORCRQEGFSA-N             No      0        N.A.
#
#                alpha7        muscletype  targetname        metric  value  \
# 8                 NAM               NAM  nAChR a4b2  Inhibition_%   91.8
# 27               N.A.  Unknown activity  nAChR a4b2        Emax_%  295.0
# 59        PAM type II              N.A.  nAChR a4b2        Emax_%   87.0
# 255          inactive              N.A.  nAChR a4b2          P3_%  200.0
# 470              N.A.              N.A.  nAChR a4b2  Inhibition_%   39.0
# ...               ...               ...         ...           ...    ...
# 7605  PAM (type n.a.)              N.A.    nAChR a7       EC50_uM   10.7
# 7606  PAM (type n.a.)              N.A.    nAChR a7       EC50_uM    7.3
# 7607      PAM type II              N.A.    nAChR a7       EC50_uM    3.9
# 7608  PAM (type n.a.)              N.A.    nAChR a7       EC50_uM    2.6
# 7609  PAM (type n.a.)              N.A.    nAChR a7       EC50_uM    1.9
#
#       reference   measure
# 8      23327794  efficacy
# 27     17604168  efficacy
# 59     25232969  efficacy
# 255    24365158  efficacy
# 470    23327794  efficacy
# ...         ...       ...
# 7605   25232969   potency
# 7606   25232969   potency
# 7607   25232969   potency
# 7608   25232969   potency
# 7609   25232969   potency
#
# [213 rows x 14 columns]

# %% [markdown]
# **PAM or NAM in one type and (ant)agonist in other**

# %%
allosteric[
    allosteric['alpha4beta2'].str.contains("agonist", case=True, na=False)
    | allosteric['alpha7'].str.contains("agonist", case=True, na=False)
    | allosteric['muscletype'].str.contains("agonist", case=True, na=False)
]
# Out:
#           cid        name                                             Smiles  \
# 5675  5360515  NALTREXONE  C1CC1CN2CC[C@]34[C@@H]5C(=O)CC[C@]3([C@H]2CC6=...
# 5676  5360515  NALTREXONE  C1CC1CN2CC[C@]34[C@@H]5C(=O)CC[C@]3([C@H]2CC6=...
#
#                          inchikey in_vivo_tested  phase alpha4beta2 alpha7  \
# 5675  DQCKKXVULJGBQN-XFWGSAIBSA-N            yes      4  antagonist    NAM
# 5676  DQCKKXVULJGBQN-XFWGSAIBSA-N            yes      4  antagonist    NAM
#
#      muscletype  targetname   metric  value  reference  measure
# 5675       N.A.  nAChR a4b2  IC50_uM   31.0   15050620  potency
# 5676       N.A.    nAChR a7  IC50_uM   27.5   15050620  potency

# %% [markdown]
# Indeed, naltrexone has different effects in each receptor, but only the one with NAM in its column will be taken into account for PDB querying.
#
# <br>

# %% [markdown]
# ## Only fields of interest

# %%
allo_unique = allosteric[["name", "Smiles", 'alpha4beta2', 'alpha7', 'muscletype']].drop_duplicates()
allo_unique
# Out:
#                                                    name  \
# 8                                          MECAMYLAMINE
# 27                              DESFORMYLFLUSTRABROMINE
# 59                             4,2,5-Trihydroxychalcone
# 255                                             NS-9283
# 470                                              KAB-18
# ...                                                 ...
# 7605  (Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyph...
# 7606  (E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trim...
# 7607                                       Compound 111
# 7608  (E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-d...
# 7609  (E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-in...
#
#                                                  Smiles alpha4beta2  \
# 8                                CC1(C2CCC(C2)C1(C)NC)C         NAM
# 27              CC(C)(C=C)C1=C(C2=C(N1)C=C(C=C2)Br)CCNC         PAM
# 59            C1=CC(=CC=C1/C=C/C(=O)C2=C(C=CC(=C2)O)O)O        N.A.
# 255            C1=CC(=CC(=C1)C2=NC(=NO2)C3=CN=CC=C3)C#N         PAM
# 470   C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4...         NAM
# ...                                                 ...         ...
# 7605       C1=CC(=C(C=C1O)O)/C=C\C(=O)C2=C(C=CC(=C2)O)O        N.A.
# 7606  CC1=C(C=CC(=C1)O)C(=O)/C=C/C2=C(C(=C(C=C2)OC)O...        N.A.
# 7607     COC1=CC(=C(C=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)OC        N.A.
# 7608  COC1=CC(=C(C(=C1)OC)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O        N.A.
# 7609  C1=CC2=C(C=C1O)C(=CN2)/C=C/C(=O)C3=C(C=CC(=C3)O)O        N.A.
#
#                alpha7        muscletype
# 8                 NAM               NAM
# 27               N.A.  Unknown activity
# 59        PAM type II              N.A.
# 255          inactive              N.A.
# 470              N.A.              N.A.
# ...               ...               ...
# 7605  PAM (type n.a.)              N.A.
# 7606  PAM (type n.a.)              N.A.
# 7607      PAM type II              N.A.
# 7608  PAM (type n.a.)              N.A.
# 7609  PAM (type n.a.)              N.A.
#
# [154 rows x 5 columns]

# %% [markdown]
# **Duplicated compounds**

# %%
allo_unique[
    allo_unique.duplicated("name", keep=False)
]
# Out:
#               name                               Smiles alpha4beta2 alpha7  \
# 8     MECAMYLAMINE               CC1(C2CCC(C2)C1(C)NC)C         NAM    NAM
# 5693  MECAMYLAMINE  C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC         NAM    NAM
#
#      muscletype
# 8           NAM
# 5693        NAM

# %%
import os, pickle, requests, json

# %% [markdown]
# ##### Get Uniprots of AChRs
#
# Annotation score 4/5 (instead of 5/5 to include some Torpedo Uniprots that don't have 5/5)

# %%
q_web = """https://rest.uniprot.org/uniprotkb/stream?format=list&"""

q_alpha4 = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Alpha-4%2FCHRNA4+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""
q_beta2 = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Beta-2%2FCHRNB2+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""

q_alpha7 = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Alpha-7%2FCHRNA7+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""

q_alpha = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Alpha-1%2FCHRNA1+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""
q_beta = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Beta-1%2FCHRNB1+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""
q_delta = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Delta%2FCHRND+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""
q_epsilon = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Epsilon%2FCHRNE+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""
q_gamma = """query=%28%28family%3A%22ligand-gated+ion+channel+%28TC+1.A.9%29+family+Acetylcholine+receptor+%28TC+1.A.9.1%29+subfamily+Gamma%2FCHRNG+sub-subfamily%22%29%29+AND+%28annotation_score%3A5%29"""

# %%
file = "AChRs_uniprots.json"

if not os.path.isfile(file):
    uniprots = {}
    for q in "q_alpha4, q_beta2, q_alpha7, q_alpha, q_beta, q_delta, q_epsilon, q_gamma".split(", "):
        uniprots[q] = [i for i in requests.get(q_web + eval(q)).content.decode().split("\n") if len(i)>0]
        uniprots[q].extend([i for i in requests.get(q_web + eval(q).replace("%3A5%29", "%3A4%29")).content.decode().split("\n") if len(i)>0]) # Include annotation score 4
        
    with open(file, "wb") as f:
        pickle.dump(uniprots, f)

with open(file, "rb") as f:
    uniprots = pickle.load(f)
    
uniprots
# Out:
# {'q_alpha4': ['O70174',
#   'P09482',
#   'P09483',
#   'P43681',
#   'Q5IS77',
#   'A0A286ZKF4',
#   'A0A2I2YY21',
#   'E1BHK0',
#   'F6QGI2',
#   'F7DET6',
#   'G1KER0',
#   'M3WUG2',
#   'Q19AE6'],
#  'q_beta2': ['P09484', 'P12390', 'P17787', 'Q9ERK7', 'P19370'],
#  'q_alpha7': ['A0A0P6K2L9',
#   'A0A286XUB1',
#   'A0A2K5U752',
#   'A0A2K6GC14',
#   'A0A2R8MV58',
#   'A0A337SQQ4',
#   'A0A3Q7R9T2',
#   'A0A452VFF0',
#   'A0A4X1U8B8',
#   'A0A8C8WIX8',
#   'A0A8I3PAT2',
#   'F1SNR6',
#   'F6RM03',
#   'G1SHV0',
#   'G3T2T7',
#   'P22770',
#   'P36544',
#   'P49582',
#   'P54131',
#   'Q05941',
#   'Q5UMH9',
#   'Q866A2'],
#  'q_alpha': ['P02708',
#   'P02709',
#   'P04756',
#   'P25108',
#   'Q98880',
#   'A0A1S3G4Y4',
#   'A0A286XU07',
#   'A0A287D981',
#   'A0A2I2ZA95',
#   'A0A2J8VR53',
#   'A0A2K6FUM4',
#   'A0A2K6V5P4',
#   'A0A2R8N8V0',
#   'A0A2R8ZN82',
#   'A0A2Y9F3J6',
#   'A0A384BS09',
#   'A0A452QP10',
#   'A0A4W2H4C8',
#   'A0A4X1URU6',
#   'A0A4X2LMF8',
#   'A0A5F5XL67',
#   'A0A7N4NK50',
#   'A0A8C0RN65',
#   'A0A8C5Y2K4',
#   'A0A8C8YA30',
#   'A0A8I3P2C7',
#   'F6XJA4',
#   'F7C5D6',
#   'F7E1H9',
#   'F7ET74',
#   'G1M0T4',
#   'G1PSY2',
#   'G1TJ62',
#   'G3T6T5',
#   'H0WHF2',
#   'H2QJ05',
#   'H9GA55',
#   'M3YRB0',
#   'P02710',
#   'P02711',
#   'P09479',
#   'Q05A24',
#   'W5MKA6'],
#  'q_beta': ['P02712',
#   'P04758',
#   'P09690',
#   'P11230',
#   'P25109',
#   'F6RFH4',
#   'F6SLE5',
#   'F6U9J4',
#   'G3RJU3',
#   'K7C899',
#   'P49579'],
#  'q_delta': ['P02716', 'P04759', 'P25110', 'Q07001'],
#  'q_epsilon': ['P09660', 'P20782', 'Q04844', 'A2BG85', 'P02715', 'P49580'],
#  'q_gamma': ['P02713',
#   'P02714',
#   'P04760',
#   'P07510',
#   'P13536',
#   'P18916',
#   'A0A8I6A2R4',
#   'E7F9V1',
#   'G1FMP9',
#   'P05376']}

# %% [markdown]
# ##### Query the PDB

# %%
from rcsbsearchapi.search import AttributeQuery, ChemSimilarityQuery

# %%
file = "AChRs_pdbs.json"

if not os.path.isfile(file):
    pdb_query = {}
    skip = False
else:
    with open(file, "rb") as f:
        pdb_query = pickle.load(f)
    skip = True

# %%
if not skip:
    r = "alpha4beta2"
    pdb_query[r] = {}
    
    upq_alpha4 = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_alpha4"]
    )
    upq_beta2 = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_beta2"]
    )
    
    for i, m in allo_unique[
        allo_unique[r].str.contains("AM", case=True, na=False)
    ].iterrows():
        
        smiquery = ChemSimilarityQuery(
            value=m["Smiles"],
            query_type="descriptor",
            descriptor_type="SMILES",
            match_type="graph-relaxed" # To search for similar molecules to the SMILES
        )
    
        pdb_query[r][m["name"]] = (
            m.to_dict(),
            list((upq_alpha4 & upq_beta2 & smiquery)()),
            list((upq_alpha4 & upq_beta2 & smiquery)("mol_definition"))
        )

# %%
if not skip:
    r = "alpha7"
    pdb_query[r] = {}
    
    upq_alpha7 = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_alpha7"]
    )
    
    for i, m in allo_unique[
        allo_unique[r].str.contains("AM", case=True, na=False)
    ].iterrows():
        
        smiquery = ChemSimilarityQuery(
            value=m["Smiles"],
            query_type="descriptor",
            descriptor_type="SMILES",
            match_type="graph-relaxed" # To search for similar molecules to the SMILES
        )
    
        pdb_query[r][m["name"]] = (
            m.to_dict(),
            list((upq_alpha7 & smiquery)()),
            list((upq_alpha7 & smiquery)("mol_definition"))
        )

# %%
if not skip:
    r = "muscletype"
    pdb_query[r] = {}
    
    upq_alpha = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_alpha"]
    )
    upq_beta = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_beta"]
    )
    upq_delta = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_delta"]
    )
    upq_epsilon = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_epsilon"]
    )
    upq_gamma = AttributeQuery(
        attribute="rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
        operator="in",
        negation=False,
        value=uniprots["q_gamma"]
    )
    
    
    for i, m in allo_unique[
        allo_unique[r].str.contains("AM", case=True, na=False)
    ].iterrows():
        
        smiquery = ChemSimilarityQuery(
            value=m["Smiles"],
            query_type="descriptor",
            descriptor_type="SMILES",
            match_type="graph-relaxed" # To search for similar molecules to the SMILES
        )
    
        pdb_query[r][m["name"]] = (
            m.to_dict(),
            list((upq_alpha & upq_beta & upq_delta & (upq_epsilon | upq_gamma) & smiquery)()),
            list((upq_alpha & upq_beta & upq_delta & (upq_epsilon | upq_gamma) & smiquery)("mol_definition"))
        )

# %%
if not skip:
    with open(file, "wb") as f:
        pickle.dump(pdb_query, f)
        
pdb_query
# Out:
# {'alpha4beta2': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'DESFORMYLFLUSTRABROMINE': ({'name': 'DESFORMYLFLUSTRABROMINE',
#     'Smiles': 'CC(C)(C=C)C1=C(C2=C(N1)C=C(C=C2)Br)CCNC',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'Unknown activity'},
#    [],
#    []),
#   'NS-9283': ({'name': 'NS-9283',
#     'Smiles': 'C1=CC(=CC(=C1)C2=NC(=NO2)C3=CN=CC=C3)C#N',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'inactive',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-18': ({'name': 'KAB-18',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Galantamine': ({'name': 'Galantamine',
#     'Smiles': 'CN1CC[C@@]23C=C[C@@H](C[C@@H]2OC4=C(C=CC(=C34)C1)OC)O',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'inactive',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'N-Benzyl-2-phenylbenzamide': ({'name': 'N-Benzyl-2-phenylbenzamide',
#     'Smiles': 'C1=CC=C(C=C1)CNC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'N-(Naphthalen-1-yl)biphenyl-2-carboxamide': ({'name': 'N-(Naphthalen-1-yl)biphenyl-2-carboxamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC4=CC=CC=C43',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester': ({'name': '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC(C)C)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane': ({'name': '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Schembl20942833': ({'name': 'Schembl20942833',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC4CCC4)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'IB-2': ({'name': 'IB-2',
#     'Smiles': 'C[C@H]1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@H]3CCCN(C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'IB-4': ({'name': 'IB-4',
#     'Smiles': 'C[C@@H]1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3CCCN(C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole': ({'name': '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole',
#     'Smiles': 'CCC1=NOC(=C1)[C@@H]2[C@H]3CC[C@H](N3C)C[C@@H]2C4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=C(C=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole',
#     'Smiles': 'CN1[C@H]2CC[C@@H]1[C@H]([C@H](C2)C3=CC=C(C=C3)Cl)C4=CC(=NO4)C5=CC=C(C=C5)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'RTI-371': ({'name': 'RTI-371',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=C(C=C5)Cl)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-Phenylbenzanilide': ({'name': '2-Phenylbenzanilide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'N-(Naphthylmethyl)(2-phenylphenyl)carboxamide': ({'name': 'N-(Naphthylmethyl)(2-phenylphenyl)carboxamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NCC3=CC=CC4=CC=CC=C43',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one': ({'name': '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "N-(Pyridin-2-yl)-[1,1'-biphenyl]-2-carboxamide": ({'name': "N-(Pyridin-2-yl)-[1,1'-biphenyl]-2-carboxamide",
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC=N3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one': ({'name': '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-chlorophenyl)-2-(dimethylamino)propan-1-one': ({'name': '1-(3-chlorophenyl)-2-(dimethylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'KAB-19': ({'name': 'KAB-19',
#     'Smiles': 'CC(=O)NC1=CC=CC=C1C(=O)OCC2CCCN(C2)CCCC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-Trifluoromethyl-benzoic acid 1-(3-phenyl-propyl)-piperidin-3-ylmethyl ester': ({'name': '2-Trifluoromethyl-benzoic acid 1-(3-phenyl-propyl)-piperidin-3-ylmethyl ester',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-20': ({'name': 'KAB-20',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)C5=CC=CC=C5C4=O',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-21': ({'name': 'KAB-21',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=C(C=C3)C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-30': ({'name': 'KAB-30',
#     'Smiles': 'CC1(CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCC4=CC=CC=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-23': ({'name': 'KAB-23',
#     'Smiles': 'COC1=CC=CC=C1C(=O)OCC2CCCN(C2)CCCC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-22': ({'name': 'KAB-22',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one': ({'name': '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one',
#     'Smiles': 'CC(CNC(C)(C)C)C(=O)C1=CC(=CC=C1)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one',
#     'Smiles': 'CC1=C(C=C(C=C1)C(=O)C(C)NC(C)(C)C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC(=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone": ({'name': "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone",
#     'Smiles': 'CC(C(=O)C1=CC=CS1)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-m-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-m-tolylpropan-1-one',
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)F)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)C(=O)C(C)NC(C)(C)C)Br',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-chlorophenyl)-2-(cyclopentylamino)propan-1-one': ({'name': '1-(3-chlorophenyl)-2-(cyclopentylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'JHB-12': ({'name': 'JHB-12',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3C[C@@H](CN(C3)CCCC4=CC=CC=C4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-13': ({'name': 'JHB-13',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3C[C@@H](CN(C3)CCCC4=CC=CC=C4)C5CCCCC5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-3''-nitropropiophenone": ({'name': "2-(N-Tert-Butylamino)-3''-nitropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-fluoropropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-bromopropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methylpropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methoxypropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one': ({'name': '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-fluoropropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-bromopropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methylpropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-p-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-p-tolylpropan-1-one',
#     'Smiles': 'CC1=CC=C(C=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole': ({'name': '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole',
#     'Smiles': 'CC1=CC2=C(C=C1C)N=C(N2)[C@@H]3[C@H]4CC[C@H](N4C)C[C@@H]3C5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=CC=C5)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'KAB-9': ({'name': 'KAB-9',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=C(C=C4)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'PPB-1': ({'name': 'PPB-1',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CC5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'PPB-6': ({'name': 'PPB-6',
#     'Smiles': 'CC(C)N1CCCC(C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[5-(3,4-dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[5-(3,4-dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC(=C(C=C4)OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[5-(2,3-Dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[5-(2,3-Dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=CC(=C4OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[2-[(3S,5R)-3,5-dimethoxycyclohexyl]oxyethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[2-[(3S,5R)-3,5-dimethoxycyclohexyl]oxyethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4C[C@@H](C[C@@H](C4)OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)-3,6-dihydro-2H-pyridin-5-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(3-Phenylpropyl)-3,6-dihydro-2H-pyridin-5-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'C1CN(CC(=C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4)CCCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-4-yl]methyl 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-4-yl]methyl 2-phenylbenzoate',
#     'Smiles': 'C1CN(CCC1COC(=O)C2=CC=CC=C2C3=CC=CC=C3)C(=O)CCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-8': ({'name': 'APB-8',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-1': ({'name': 'COB-1',
#     'Smiles': 'C1CC(CNC1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-18': ({'name': 'DDR-18',
#     'Smiles': 'C1CC(CN(C1)CCCN2C=C(N=N2)C3=CC=CC=C3)COC(=O)C4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-32': ({'name': 'KAB-32',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCOC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-35': ({'name': 'KAB-35',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=C(C=C4)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-38': ({'name': 'KAB-38',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(2-Phenylethyl)piperidin-3-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(2-Phenylethyl)piperidin-3-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'C1CC(CN(C1)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'c28h29no3': ({'name': 'c28h29no3',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-10': ({'name': 'KAB-10',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-33': ({'name': 'KAB-33',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-Phenyl-N-pyrimidin-4-ylbenzamide': ({'name': '2-Phenyl-N-pyrimidin-4-ylbenzamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=NC=NC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-20': ({'name': 'DDR-20',
#     'Smiles': 'CC1(OC2C3CC(C2O1)N(CC3OC(=O)C4=CC=CC=C4C5=CC=CC=C5)CCCC6=CC=CC=C6)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-11': ({'name': 'KAB-11',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NEB-2': ({'name': 'NEB-2',
#     'Smiles': 'C1CC(CNC1)COCC2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-phenylpropyl)piperidin-3-yl]methyl 2-[3-[(4-methoxyphenyl)methyl]-2,5-dioxopyrrolidin-1-yl]benzoate': ({'name': '[1-(3-phenylpropyl)piperidin-3-yl]methyl 2-[3-[(4-methoxyphenyl)methyl]-2,5-dioxopyrrolidin-1-yl]benzoate',
#     'Smiles': 'COC1=CC=C(C=C1)CC2CC(=O)N(C2=O)C3=CC=CC=C3C(=O)OCC4CCCN(C4)CCCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Cyclohexylpropyl)piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(3-Cyclohexylpropyl)piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCC4CCCCC4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-3-yl] 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-3-yl] 2-phenylbenzoate',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)OC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-5': ({'name': 'DDR-5',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)CNC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(1-Ethylpiperidin-3-yl)methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '(1-Ethylpiperidin-3-yl)methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CCN1CCCC(C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-11': ({'name': 'JHB-11',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)CCC3CCCN(C3)CCCCOC4=CC=C(C=C4)C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-13': ({'name': 'KAB-13',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-16': ({'name': 'KAB-16',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-4-yl]methyl 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-4-yl]methyl 2-phenylbenzoate',
#     'Smiles': 'C1CN(CCC1COC(=O)C2=CC=CC=C2C3=CC=CC=C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-1': ({'name': 'APB-1',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=CC(=O)C4=CC=CC=C4O3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-26': ({'name': 'DDR-26',
#     'Smiles': 'CCN1CC(C2CC1C3C2OC(O3)(C)C)OC(=O)C4=CC=CC=C4N5C(=O)CC(C5=O)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'FFB-1': ({'name': 'FFB-1',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-15': ({'name': 'KAB-15',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC(=CC=C4)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-37': ({'name': 'KAB-37',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'c28h33no': ({'name': 'c28h33no',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-3-yl]methyl 2-(trifluoromethyl)benzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-3-yl]methyl 2-(trifluoromethyl)benzoate',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-3': ({'name': 'COB-3',
#     'Smiles': 'C[N+]1(CCCC(C1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-15': ({'name': 'DDR-15',
#     'Smiles': 'C1CC(CN(C1)CCCN=[N+]=[N-])COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-19': ({'name': 'DDR-19',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C=C(N=N4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-25': ({'name': 'DDR-25',
#     'Smiles': 'CC(C)N1CC(C2CC1C3C2OC(O3)(C)C)OC(=O)C4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-4': ({'name': 'DDR-4',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)CN(CC3=CC=CC=C3C4=CC=CC=C4)CC5=CC=CC=C5C6=CC=CC=C6',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-3-yl]methyl 2-[2,5-dioxo-3-(2-phenylethyl)pyrrolidin-1-yl]benzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-3-yl]methyl 2-[2,5-dioxo-3-(2-phenylethyl)pyrrolidin-1-yl]benzoate',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-[[1-[(2-Phenylphenyl)methyl]triazol-4-yl]methoxymethyl]-1-(3-phenylpropyl)piperidine': ({'name': '3-[[1-[(2-Phenylphenyl)methyl]triazol-4-yl]methoxymethyl]-1-(3-phenylpropyl)piperidine',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COCC3=CN(N=N3)CC4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-3-yl] 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-3-yl] 2-phenylbenzoate',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)OC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-2': ({'name': 'COB-2',
#     'Smiles': 'CN1CCCC(C1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-7': ({'name': 'JHB-7',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCC4=CNC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-9': ({'name': 'JHB-9',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)C(=O)OCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-17': ({'name': 'KAB-17',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC5=CC=CC=C5C=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-28': ({'name': 'KAB-28',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=CC(=C4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[2-(3,4-dichlorophenoxy)ethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[2-(3,4-dichlorophenoxy)ethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-10': ({'name': 'APB-10',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=COC4=CC=CC=C4C3=O',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-4': ({'name': 'APB-4',
#     'Smiles': 'C1CC(CN(C1)CCCCCOC2=CC=C(C=C2)Cl)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-8': ({'name': 'COB-8',
#     'Smiles': 'C1CC(CNC1)CCC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-21': ({'name': 'DDR-21',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC3CN(C4CC3C5C4OC(O5)(C)C)CCCC6=CC=CC=C6',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-27': ({'name': 'DDR-27',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC3CN(C4CC3C5C4OC(O5)(C)C)C(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-3': ({'name': 'DDR-3',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)C(=O)NCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    [])},
#  'alpha7': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '4,2,5-Trihydroxychalcone': ({'name': '4,2,5-Trihydroxychalcone',
#     'Smiles': 'C1=CC(=CC=C1/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C/C(=O)C2=C(C=CC(=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'AVL-3288': ({'name': 'AVL-3288',
#     'Smiles': 'CC1=NOC(=C1)/C(=C/NC2=CC=C(C=C2)Cl)/C(=O)NC3=CC=C(C=C3)Cl',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'PAM type I',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Amantadine': ({'name': 'Amantadine',
#     'Smiles': 'C1C2CC3CC1CC(C2)(C3)N',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'NAM',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'SB-206553': ({'name': 'SB-206553',
#     'Smiles': 'CN1C=CC2=CC3=C(CCN3C(=O)NC4=CN=CC=C4)C=C21',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '1H-indol-5-ol': ({'name': '1H-indol-5-ol',
#     'Smiles': 'C1=CC2=C(C=CN2)C=C1O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NS-1738': ({'name': 'NS-1738',
#     'Smiles': 'C1=CC(=C(C=C1C(F)(F)F)NC(=O)NC2=C(C=CC(=C2)Cl)O)Cl',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    ['8UTB'],
#    ['XG3']),
#   'PNU-120596': ({'name': 'PNU-120596',
#     'Smiles': 'CC1=CC(=NO1)NC(=O)NC2=CC(=C(C=C2OC)OC)Cl',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    ['7EKT', '8V82', '8V8A', '8V8C', '8V8D'],
#    ['I34']),
#   'Isoliquiritigenin': ({'name': 'Isoliquiritigenin',
#     'Smiles': 'C1=CC(=CC=C1/C=C/C(=O)C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'TQS': ({'name': 'TQS',
#     'Smiles': 'C1C=CC2C1C(NC3=C2C=C(C=C3)S(=O)(=O)N)C4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    ['8V80'],
#    ['YLR']),
#   '(E)-2,4,4-Trihydroxychalcone': ({'name': '(E)-2,4,4-Trihydroxychalcone',
#     'Smiles': 'C1=CC(=CC=C1C(=O)/C=C/C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NALTREXONE': ({'name': 'NALTREXONE',
#     'Smiles': 'C1CC1CN2CC[C@]34[C@@H]5C(=O)CC[C@]3([C@H]2CC6=C4C(=C(C=C6)O)O5)O',
#     'alpha4beta2': 'antagonist',
#     'alpha7': 'NAM',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2,2`,5`-Trihydroxychalcone': ({'name': '2,2`,5`-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2,2`,4`-Trihydroxychalcone': ({'name': '2,2`,4`-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-dihydroxyphenyl)-1-(3-hydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-dihydroxyphenyl)-1-(3-hydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=CC(=C1)O)C(=O)/C=C/C2=C(C=C(C=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-Methoxy-4,2`,5`-trihydroxychalcone': ({'name': '3-Methoxy-4,2`,5`-trihydroxychalcone',
#     'Smiles': 'COC1=C(C=CC(=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'Ivermectin': ({'name': 'Ivermectin',
#     'Smiles': 'CC[C@H](C)[C@@H]1[C@H](CC[C@@]2(O1)C[C@@H]3C[C@H](O2)C/C=C(/[C@H]([C@H](/C=C/C=C/4CO[C@H]5[C@@]4([C@@H](C=C([C@H]5O)C)C(=O)O3)O)C)O[C@H]6C[C@@H]([C@H]([C@@H](O6)C)O[C@H]7C[C@@H]([C@H]([C@@H](O7)C)O)OC)OC)C)C',
#     'alpha4beta2': 'Unknown activity',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    ['8F4V', '8UZJ'],
#    ['IVM']),
#   '2,2`,4-Trihydroxychalcone': ({'name': '2,2`,4-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)C(=O)/C=C/C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'GAT-107': ({'name': 'GAT-107',
#     'Smiles': 'C1C=C[C@H]2[C@@H]1[C@H](NC3=C2C=C(C=C3)S(=O)(=O)N)C4=CC=C(C=C4)Br',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'ago - PAM type II',
#     'muscletype': 'inactive'},
#    ['8V86', '8V88'],
#    ['YLI']),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'A-867744': ({'name': 'A-867744',
#     'Smiles': 'CCC(=O)C1=C(N(C(=C1)C2=CC=C(C=C2)Cl)C3=CC=C(C=C3)S(=O)(=O)N)C',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NSC17051': ({'name': 'NSC17051',
#     'Smiles': 'C1=CC(=CC(=C1)O)C(=O)/C=C\\C2=C(C=C(C=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2-Hydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2-Hydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=CC(=C(C=C2O)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-Dihydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-Dihydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C/C(=O)C2=CC(=C(C=C2O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one': ({'name': '(Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C\\C(=O)C2=C(C=CC(=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trimethoxyphenyl)prop-2-en-1-one': ({'name': '(E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trimethoxyphenyl)prop-2-en-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)O)C(=O)/C=C/C2=C(C(=C(C=C2)OC)OC)OC',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'Compound 111': ({'name': 'Compound 111',
#     'Smiles': 'COC1=CC(=C(C=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)OC',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-dimethoxyphenyl)prop-2-en-1-one': ({'name': '(E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-dimethoxyphenyl)prop-2-en-1-one',
#     'Smiles': 'COC1=CC(=C(C(=C1)OC)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-indol-3-yl)prop-2-en-1-one': ({'name': '(E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-indol-3-yl)prop-2-en-1-one',
#     'Smiles': 'C1=CC2=C(C=C1O)C(=CN2)/C=C/C(=O)C3=C(C=CC(=C3)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    [])},
#  'muscletype': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester': ({'name': '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC(C)C)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane': ({'name': '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Schembl20942833': ({'name': 'Schembl20942833',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC4CCC4)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole': ({'name': '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole',
#     'Smiles': 'CCC1=NOC(=C1)[C@@H]2[C@H]3CC[C@H](N3C)C[C@@H]2C4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=C(C=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole',
#     'Smiles': 'CN1[C@H]2CC[C@@H]1[C@H]([C@H](C2)C3=CC=C(C=C3)Cl)C4=CC(=NO4)C5=CC=C(C=C5)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one': ({'name': '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one': ({'name': '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one': ({'name': '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one',
#     'Smiles': 'CC(CNC(C)(C)C)C(=O)C1=CC(=CC=C1)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one',
#     'Smiles': 'CC1=C(C=C(C=C1)C(=O)C(C)NC(C)(C)C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC(=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone": ({'name': "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone",
#     'Smiles': 'CC(C(=O)C1=CC=CS1)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-m-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-m-tolylpropan-1-one',
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)F)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)C(=O)C(C)NC(C)(C)C)Br',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-3''-nitropropiophenone": ({'name': "2-(N-Tert-Butylamino)-3''-nitropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-fluoropropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-bromopropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methylpropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methoxypropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one': ({'name': '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-bromopropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methylpropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-p-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-p-tolylpropan-1-one',
#     'Smiles': 'CC1=CC=C(C=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole': ({'name': '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole',
#     'Smiles': 'CC1=CC2=C(C=C1C)N=C(N2)[C@@H]3[C@H]4CC[C@H](N4C)C[C@@H]3C5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=CC=C5)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    [])}}

# %%
pdb_query["muscletype"].values()
# Out:
# dict_values([({'name': 'MECAMYLAMINE', 'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC', 'alpha4beta2': 'NAM', 'alpha7': 'NAM', 'muscletype': 'NAM'}, [], []), ({'name': 'buproprion', 'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'NAM', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one', 'Smiles': 'CCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one', 'Smiles': 'CCCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Cl)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester', 'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC(C)C)N3C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane', 'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': 'Schembl20942833', 'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC4CCC4)N3C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole', 'Smiles': 'CCC1=NOC(=C1)[C@@H]2[C@H]3CC[C@H](N3C)C[C@@H]2C4=CC=C(C=C4)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': 'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate', 'Smiles': 'CC1=C(C=C(C=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)F', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole', 'Smiles': 'CN1[C@H]2CC[C@@H]1[C@H]([C@H](C2)C3=CC=C(C=C3)Cl)C4=CC(=NO4)C5=CC=C(C=C5)OC', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': 'DEXMECAMYLAMINE', 'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC', 'alpha4beta2': 'NAM', 'alpha7': 'NAM', 'muscletype': 'NAM'}, [], []), ({'name': '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N2CCCCC2', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one', 'Smiles': 'CC(CNC(C)(C)C)C(=O)C1=CC(=CC=C1)Cl', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Br)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one', 'Smiles': 'CC1=C(C=C(C=C1)C(=O)C(C)NC(C)(C)C)Cl', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one', 'Smiles': 'CC(C(=O)C1=CC(=CC(=C1)Cl)Cl)NC(C)(C)C', 'alpha4beta2': 'NAM', 'alpha7': 'N.A.', 'muscletype': 'NAM'}, [], []), ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one', 'Smiles': 'CCC(C(=O)C1= ...

# %%
{
    k: [p for v in v.values() for p in v[1]]
    for k,v in pdb_query.items()
}
# Out:
# {'alpha4beta2': [],
#  'alpha7': ['8UTB',
#   '7EKT',
#   '8V82',
#   '8V8A',
#   '8V8C',
#   '8V8D',
#   '8V80',
#   '8F4V',
#   '8UZJ',
#   '8V86',
#   '8V88'],
#  'muscletype': []}

# %%
{
    k: {n: (a[-1], a[-2]) for n, a in v.items() if len(a[-2]) > 0}
    for k,v in pdb_query.items()
}
# Out:
# {'alpha4beta2': {},
#  'alpha7': {'NS-1738': (['XG3'], ['8UTB']),
#   'PNU-120596': (['I34'], ['7EKT', '8V82', '8V8A', '8V8C', '8V8D']),
#   'TQS': (['YLR'], ['8V80']),
#   'Ivermectin': (['IVM'], ['8F4V', '8UZJ']),
#   'GAT-107': (['YLI'], ['8V86', '8V88'])},
#  'muscletype': {}}

# %%
len([p for k,v in pdb_query.items() for e in v.values() for p in e[1]]), "PDBs"
# Out:
# (11, 'PDBs')

# %% [markdown]
# ## Comparison with papers
#
# ### Review
#
# https://www.annualreviews.org/content/journals/10.1146/annurev-biochem-030122-033116
#
# The only compounds annotated as possible "*AM"s in Table 1 are etomidate, PNU-120596 (7EKT, 7KOX (not resolved)) and the nanobodies C4 and E3. PNU-120596 is correctly identified in 7EKT (it's not resolved in 7KOX), while etomidate is not written down as "*AM" in any instance in the ACRALL database and therefore was not used for searching. Nanobodies are not in ACRALL.
#
# ### Paper with alpha7 structures
#
# https://doi.org/10.1016/j.cell.2024.01.032
#
# The structures with modulators 8UZJ (ivermectin), 8UTB (NS1738), 8V82 (PNU-120596), 8V80 (TQS), 8V86 (GAT107), 8V88 (GAT107), 8V8A (PNU-120596), 8V8C (PNU-120596) and 8V8D (PNU-120596) have been retrieved, plus 7EKT that is mentioned in the paper. 8UT1 and 8V89 deposited with the paper contain epibatidine (orthosteric) and no ligand, respectively.
#
# ### Other
#
# 8F4V is the only one that does not appear in either paper and it corresponds to ivermectin.

# %% [markdown]
# ## Data already in the database

# %%
list(PDB.select().where(PDB.entry_id.in_([p.lower() for k,v in pdb_query.items() for e in v.values() for p in e[1]])))
# Out:
# [<PDB: 8f4v>, <PDB: 8uzj>]

# %%
[
    (
        p.entry_id, 
        list(s.modulator_residues.label_comp_id.unique().tolist() for s in p.sites),
        [(n, e[-1]) for k,v in pdb_query.items() for n,e in v.items() if p.entry_id.upper() in e[-2]]
    )
    for p in list(PDB.select().where(PDB.entry_id.in_([p.lower() for k,v in pdb_query.items() for e in v.values() for p in e[1]])))
    
]
# Out:
# [('8f4v', [['IVM']], [('Ivermectin', ['IVM'])]),
#  ('8uzj', [['IVM']], [('Ivermectin', ['IVM'])])]

# %%
PDB.get(PDB.entry_id == "8f4v").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'F'}],
#    'label_entity_id': '2',
#    'type': 'non-polymer',
#    'pdbx_description': "(2aE,4E,5'S,6S,6'R,7S,8E,11R,13R,15S,17aR,20R,20aR,20bS)-6'-[(2S)-butan-2-yl]-20,20b-dihydroxy-5',6,8,19-tetramethyl-17 -oxo-3',4',5',6,6',10,11,14,15,17,17a,20,20a,20b-tetradecahydro-2H,7H-spiro[11,15-methanofuro[4,3,2-pq][2,6]benzodioxacy clooctadecine-13,2'-pyran]-7-yl 2,6-dideoxy-4-O-(2,6-dideoxy-3-O-methyl-alpha-L-arabino-hexopyranosyl)-3-O-methyl-alpha-L-arabino-hexopyranoside"}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['A', 'E']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['P36544']}],
#  'source': {'grall': [{'entry': {'Name': 'ivermectin-b1a',
#      'SMILES': 'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2',
#      'Family': 'avermectin',
#      'Binding Site': 'ivermectin',
#      'Level of Confidence': 1.0,
#      'Effect α1': '+',
#      'Effect α3': None,
#      'Activity Type α1': 'EC50(uM)',
#      'Activity Value α1': '1.7',
#      'Activity Type α3': None,
#      'Activity Value α3': None,
#      'doi': '10.1074/jbc.M110.107789',
#      'Kd_Resting(uM)': None,
#      'Kd_active(uM)': None,
#      'beta': None},
#     'version': '3.0',
#     'date': '12-3-2024',
#     'update': {'pdb': '8f4v', 'mod': [[{'auth_comp_id': 'IVM'}]]}}]}}

# %%
PDB.get(PDB.entry_id == "8uzj").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'BA'}],
#    'label_entity_id': '8',
#    'type': 'non-polymer',
#    'pdbx_description': "(2aE,4E,5'S,6S,6'R,7S,8E,11R,13R,15S,17aR,20R,20aR,20bS)-6'-[(2S)-butan-2-yl]-20,20b-dihydroxy-5',6,8,19-tetramethyl-17 -oxo-3',4',5',6,6',10,11,14,15,17,17a,20,20a,20b-tetradecahydro-2H,7H-spiro[11,15-methanofuro[4,3,2-pq][2,6]benzodioxacy clooctadecine-13,2'-pyran]-7-yl 2,6-dideoxy-4-O-(2,6-dideoxy-3-O-methyl-alpha-L-arabino-hexopyranosyl)-3-O-methyl-alpha-L-arabino-hexopyranoside"}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['B', 'C']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['P36544']}],
#  'source': {'grall': [{'entry': {'Name': 'ivermectin-b1a',
#      'SMILES': 'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2',
#      'Family': 'avermectin',
#      'Binding Site': 'ivermectin',
#      'Level of Confidence': 1.0,
#      'Effect α1': '+',
#      'Effect α3': None,
#      'Activity Type α1': 'EC50(uM)',
#      'Activity Value α1': '1.7',
#      'Activity Type α3': None,
#      'Activity Value α3': None,
#      'doi': '10.1074/jbc.M110.107789',
#      'Kd_Resting(uM)': None,
#      'Kd_active(uM)': None,
#      'beta': None},
#     'version': '3.0',
#     'date': '12-3-2024',
#     'update': {'pdb': '8uzj', 'mod': [[{'auth_comp_id': 'IVM'}]]}}]}}

# %% [markdown]
# ## Processing

# %%
errors = {}
error_entries = []

# %%
def process_entry(entry, update={}, auto_site_grouping=True, stringent_site_grouping=True):
    try:
        pdb = update["pdb"]
        mod = update["mod"]
        print(pdb, mod)
    
        old_sites = None
        # If PDB already exists, save its site IDs
        if PDB.get_or_none(PDB.entry_id == pdb) is not None:
            old_sites = list(PDB.get(PDB.entry_id == pdb).sites)
            
        with db.atomic() as txn:
            sites = create_entry(db, pdb, mod, auto_site_grouping, stringent_site_grouping)
            
            assert len(sites.objects()) == 1, f"{pdb}, {mod}: using only residue name retrieves more than one site(group)"
            
            for site in sites.objects():
                site.info["source"] = {
                    "acrall": [{
                        "entry": entry.to_dict(orient="list"),
                        "version": '23Jun23',
                        "date": "21-6-2024",
                        "update": update
                    }],
                }
                site.save()
                
            if old_sites is not None:
                try:
                    combine_sites(db, pdb.lower(), old_sites, sites.objects(), auto_site_grouping, stringent_site_grouping)
                except Exception as e:
                    assert False, "combine_sites failed; " + str(e.args[0])

        return sites

    except (AssertionError, KeyError) as error:
        id = pdb.lower()
        errors.setdefault(id, [])
        errors[id].append(str(error.args[0]))
        error_entries.append(entry)
        print(id, errors[id])

# %%
pdb_query
# Out:
# {'alpha4beta2': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'DESFORMYLFLUSTRABROMINE': ({'name': 'DESFORMYLFLUSTRABROMINE',
#     'Smiles': 'CC(C)(C=C)C1=C(C2=C(N1)C=C(C=C2)Br)CCNC',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'Unknown activity'},
#    [],
#    []),
#   'NS-9283': ({'name': 'NS-9283',
#     'Smiles': 'C1=CC(=CC(=C1)C2=NC(=NO2)C3=CN=CC=C3)C#N',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'inactive',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-18': ({'name': 'KAB-18',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Galantamine': ({'name': 'Galantamine',
#     'Smiles': 'CN1CC[C@@]23C=C[C@@H](C[C@@H]2OC4=C(C=CC(=C34)C1)OC)O',
#     'alpha4beta2': 'PAM',
#     'alpha7': 'inactive',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'N-Benzyl-2-phenylbenzamide': ({'name': 'N-Benzyl-2-phenylbenzamide',
#     'Smiles': 'C1=CC=C(C=C1)CNC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'N-(Naphthalen-1-yl)biphenyl-2-carboxamide': ({'name': 'N-(Naphthalen-1-yl)biphenyl-2-carboxamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC4=CC=CC=C43',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester': ({'name': '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC(C)C)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane': ({'name': '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Schembl20942833': ({'name': 'Schembl20942833',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC4CCC4)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'IB-2': ({'name': 'IB-2',
#     'Smiles': 'C[C@H]1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@H]3CCCN(C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'IB-4': ({'name': 'IB-4',
#     'Smiles': 'C[C@@H]1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3CCCN(C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole': ({'name': '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole',
#     'Smiles': 'CCC1=NOC(=C1)[C@@H]2[C@H]3CC[C@H](N3C)C[C@@H]2C4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=C(C=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole',
#     'Smiles': 'CN1[C@H]2CC[C@@H]1[C@H]([C@H](C2)C3=CC=C(C=C3)Cl)C4=CC(=NO4)C5=CC=C(C=C5)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'RTI-371': ({'name': 'RTI-371',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=C(C=C5)Cl)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-Phenylbenzanilide': ({'name': '2-Phenylbenzanilide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'N-(Naphthylmethyl)(2-phenylphenyl)carboxamide': ({'name': 'N-(Naphthylmethyl)(2-phenylphenyl)carboxamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NCC3=CC=CC4=CC=CC=C43',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one': ({'name': '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "N-(Pyridin-2-yl)-[1,1'-biphenyl]-2-carboxamide": ({'name': "N-(Pyridin-2-yl)-[1,1'-biphenyl]-2-carboxamide",
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=CC=CC=N3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one': ({'name': '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-chlorophenyl)-2-(dimethylamino)propan-1-one': ({'name': '1-(3-chlorophenyl)-2-(dimethylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'KAB-19': ({'name': 'KAB-19',
#     'Smiles': 'CC(=O)NC1=CC=CC=C1C(=O)OCC2CCCN(C2)CCCC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-Trifluoromethyl-benzoic acid 1-(3-phenyl-propyl)-piperidin-3-ylmethyl ester': ({'name': '2-Trifluoromethyl-benzoic acid 1-(3-phenyl-propyl)-piperidin-3-ylmethyl ester',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-20': ({'name': 'KAB-20',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)C5=CC=CC=C5C4=O',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-21': ({'name': 'KAB-21',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=C(C=C3)C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-30': ({'name': 'KAB-30',
#     'Smiles': 'CC1(CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCC4=CC=CC=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-23': ({'name': 'KAB-23',
#     'Smiles': 'COC1=CC=CC=C1C(=O)OCC2CCCN(C2)CCCC3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-22': ({'name': 'KAB-22',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one': ({'name': '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one',
#     'Smiles': 'CC(CNC(C)(C)C)C(=O)C1=CC(=CC=C1)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one',
#     'Smiles': 'CC1=C(C=C(C=C1)C(=O)C(C)NC(C)(C)C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC(=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone": ({'name': "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone",
#     'Smiles': 'CC(C(=O)C1=CC=CS1)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-m-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-m-tolylpropan-1-one',
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)F)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)C(=O)C(C)NC(C)(C)C)Br',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-chlorophenyl)-2-(cyclopentylamino)propan-1-one': ({'name': '1-(3-chlorophenyl)-2-(cyclopentylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'JHB-12': ({'name': 'JHB-12',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3C[C@@H](CN(C3)CCCC4=CC=CC=C4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-13': ({'name': 'JHB-13',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC[C@@H]3C[C@@H](CN(C3)CCCC4=CC=CC=C4)C5CCCCC5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-3''-nitropropiophenone": ({'name': "2-(N-Tert-Butylamino)-3''-nitropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-fluoropropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-bromopropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methylpropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methoxypropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one': ({'name': '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-fluoropropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-bromopropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methylpropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-p-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-p-tolylpropan-1-one',
#     'Smiles': 'CC1=CC=C(C=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole': ({'name': '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole',
#     'Smiles': 'CC1=CC2=C(C=C1C)N=C(N2)[C@@H]3[C@H]4CC[C@H](N4C)C[C@@H]3C5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=CC=C5)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'KAB-9': ({'name': 'KAB-9',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=C(C=C4)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'PPB-1': ({'name': 'PPB-1',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CC5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'PPB-6': ({'name': 'PPB-6',
#     'Smiles': 'CC(C)N1CCCC(C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[5-(3,4-dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[5-(3,4-dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC(=C(C=C4)OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[5-(2,3-Dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[5-(2,3-Dimethoxyphenoxy)pentyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=CC(=C4OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[2-[(3S,5R)-3,5-dimethoxycyclohexyl]oxyethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[2-[(3S,5R)-3,5-dimethoxycyclohexyl]oxyethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4C[C@@H](C[C@@H](C4)OC)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)-3,6-dihydro-2H-pyridin-5-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(3-Phenylpropyl)-3,6-dihydro-2H-pyridin-5-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'C1CN(CC(=C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4)CCCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-4-yl]methyl 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-4-yl]methyl 2-phenylbenzoate',
#     'Smiles': 'C1CN(CCC1COC(=O)C2=CC=CC=C2C3=CC=CC=C3)C(=O)CCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-8': ({'name': 'APB-8',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-1': ({'name': 'COB-1',
#     'Smiles': 'C1CC(CNC1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-18': ({'name': 'DDR-18',
#     'Smiles': 'C1CC(CN(C1)CCCN2C=C(N=N2)C3=CC=CC=C3)COC(=O)C4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-32': ({'name': 'KAB-32',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCOC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-35': ({'name': 'KAB-35',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=C(C=C4)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-38': ({'name': 'KAB-38',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(2-Phenylethyl)piperidin-3-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(2-Phenylethyl)piperidin-3-yl]methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'C1CC(CN(C1)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'c28h29no3': ({'name': 'c28h29no3',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-10': ({'name': 'KAB-10',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-33': ({'name': 'KAB-33',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCOC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2-Phenyl-N-pyrimidin-4-ylbenzamide': ({'name': '2-Phenyl-N-pyrimidin-4-ylbenzamide',
#     'Smiles': 'C1=CC=C(C=C1)C2=CC=CC=C2C(=O)NC3=NC=NC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-20': ({'name': 'DDR-20',
#     'Smiles': 'CC1(OC2C3CC(C2O1)N(CC3OC(=O)C4=CC=CC=C4C5=CC=CC=C5)CCCC6=CC=CC=C6)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-11': ({'name': 'KAB-11',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NEB-2': ({'name': 'NEB-2',
#     'Smiles': 'C1CC(CNC1)COCC2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-phenylpropyl)piperidin-3-yl]methyl 2-[3-[(4-methoxyphenyl)methyl]-2,5-dioxopyrrolidin-1-yl]benzoate': ({'name': '[1-(3-phenylpropyl)piperidin-3-yl]methyl 2-[3-[(4-methoxyphenyl)methyl]-2,5-dioxopyrrolidin-1-yl]benzoate',
#     'Smiles': 'COC1=CC=C(C=C1)CC2CC(=O)N(C2=O)C3=CC=CC=C3C(=O)OCC4CCCN(C4)CCCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Cyclohexylpropyl)piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-(3-Cyclohexylpropyl)piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCC4CCCCC4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-3-yl] 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-3-yl] 2-phenylbenzoate',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)OC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-5': ({'name': 'DDR-5',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)CNC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(1-Ethylpiperidin-3-yl)methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '(1-Ethylpiperidin-3-yl)methyl 2-(3-benzyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CCN1CCCC(C1)COC(=O)C2=CC=CC=C2N3C(=O)CC(C3=O)CC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-11': ({'name': 'JHB-11',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)CCC3CCCN(C3)CCCCOC4=CC=C(C=C4)C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-13': ({'name': 'KAB-13',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-16': ({'name': 'KAB-16',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-4-yl]methyl 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-4-yl]methyl 2-phenylbenzoate',
#     'Smiles': 'C1CN(CCC1COC(=O)C2=CC=CC=C2C3=CC=CC=C3)CCCC4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-1': ({'name': 'APB-1',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=CC(=O)C4=CC=CC=C4O3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-26': ({'name': 'DDR-26',
#     'Smiles': 'CCN1CC(C2CC1C3C2OC(O3)(C)C)OC(=O)C4=CC=CC=C4N5C(=O)CC(C5=O)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'FFB-1': ({'name': 'FFB-1',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-15': ({'name': 'KAB-15',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC(=CC=C4)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-37': ({'name': 'KAB-37',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCCCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'c28h33no': ({'name': 'c28h33no',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-3-yl]methyl 2-(trifluoromethyl)benzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-3-yl]methyl 2-(trifluoromethyl)benzoate',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3C(F)(F)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-3': ({'name': 'COB-3',
#     'Smiles': 'C[N+]1(CCCC(C1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-15': ({'name': 'DDR-15',
#     'Smiles': 'C1CC(CN(C1)CCCN=[N+]=[N-])COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-19': ({'name': 'DDR-19',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C=C(N=N4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-25': ({'name': 'DDR-25',
#     'Smiles': 'CC(C)N1CC(C2CC1C3C2OC(O3)(C)C)OC(=O)C4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-4': ({'name': 'DDR-4',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)CN(CC3=CC=CC=C3C4=CC=CC=C4)CC5=CC=CC=C5C6=CC=CC=C6',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropyl)piperidin-3-yl]methyl 2-[2,5-dioxo-3-(2-phenylethyl)pyrrolidin-1-yl]benzoate': ({'name': '[1-(3-Phenylpropyl)piperidin-3-yl]methyl 2-[2,5-dioxo-3-(2-phenylethyl)pyrrolidin-1-yl]benzoate',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COC(=O)C3=CC=CC=C3N4C(=O)CC(C4=O)CCC5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-[[1-[(2-Phenylphenyl)methyl]triazol-4-yl]methoxymethyl]-1-(3-phenylpropyl)piperidine': ({'name': '3-[[1-[(2-Phenylphenyl)methyl]triazol-4-yl]methoxymethyl]-1-(3-phenylpropyl)piperidine',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)COCC3=CN(N=N3)CC4=CC=CC=C4C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-(3-Phenylpropanoyl)piperidin-3-yl] 2-phenylbenzoate': ({'name': '[1-(3-Phenylpropanoyl)piperidin-3-yl] 2-phenylbenzoate',
#     'Smiles': 'C1CC(CN(C1)C(=O)CCC2=CC=CC=C2)OC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-2': ({'name': 'COB-2',
#     'Smiles': 'CN1CCCC(C1)COC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-7': ({'name': 'JHB-7',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCC4=CNC5=CC=CC=C54',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'JHB-9': ({'name': 'JHB-9',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)C(=O)OCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-17': ({'name': 'KAB-17',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC5=CC=CC=C5C=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'KAB-28': ({'name': 'KAB-28',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC=CC(=C4)C5=CC=CC=C5',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '[1-[2-(3,4-dichlorophenoxy)ethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate': ({'name': '[1-[2-(3,4-dichlorophenoxy)ethyl]piperidin-3-yl]methyl 2-(3-methyl-2,5-dioxopyrrolidin-1-yl)benzoate',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OCC3CCCN(C3)CCOC4=CC(=C(C=C4)Cl)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-10': ({'name': 'APB-10',
#     'Smiles': 'COC1=CC=C(C=C1)OCCCCCN2CCCC(C2)COC(=O)C3=COC4=CC=CC=C4C3=O',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'APB-4': ({'name': 'APB-4',
#     'Smiles': 'C1CC(CN(C1)CCCCCOC2=CC=C(C=C2)Cl)COC(=O)C3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'COB-8': ({'name': 'COB-8',
#     'Smiles': 'C1CC(CNC1)CCC(=O)C2=CC=CC=C2C3=CC=CC=C3',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-21': ({'name': 'DDR-21',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC3CN(C4CC3C5C4OC(O5)(C)C)CCCC6=CC=CC=C6',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-27': ({'name': 'DDR-27',
#     'Smiles': 'CC1CC(=O)N(C1=O)C2=CC=CC=C2C(=O)OC3CN(C4CC3C5C4OC(O5)(C)C)C(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'DDR-3': ({'name': 'DDR-3',
#     'Smiles': 'C1CC(CN(C1)CCCC2=CC=CC=C2)C(=O)NCC3=CC=CC=C3C4=CC=CC=C4',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'N.A.'},
#    [],
#    [])},
#  'alpha7': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '4,2,5-Trihydroxychalcone': ({'name': '4,2,5-Trihydroxychalcone',
#     'Smiles': 'C1=CC(=CC=C1/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C/C(=O)C2=C(C=CC(=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'AVL-3288': ({'name': 'AVL-3288',
#     'Smiles': 'CC1=NOC(=C1)/C(=C/NC2=CC=C(C=C2)Cl)/C(=O)NC3=CC=C(C=C3)Cl',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'PAM type I',
#     'muscletype': 'inactive'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Amantadine': ({'name': 'Amantadine',
#     'Smiles': 'C1C2CC3CC1CC(C2)(C3)N',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'NAM',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'SB-206553': ({'name': 'SB-206553',
#     'Smiles': 'CN1C=CC2=CC3=C(CCN3C(=O)NC4=CN=CC=C4)C=C21',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '1H-indol-5-ol': ({'name': '1H-indol-5-ol',
#     'Smiles': 'C1=CC2=C(C=CN2)C=C1O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NS-1738': ({'name': 'NS-1738',
#     'Smiles': 'C1=CC(=C(C=C1C(F)(F)F)NC(=O)NC2=C(C=CC(=C2)Cl)O)Cl',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    ['8UTB'],
#    ['XG3']),
#   'PNU-120596': ({'name': 'PNU-120596',
#     'Smiles': 'CC1=CC(=NO1)NC(=O)NC2=CC(=C(C=C2OC)OC)Cl',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    ['7EKT', '8V82', '8V8A', '8V8C', '8V8D'],
#    ['I34']),
#   'Isoliquiritigenin': ({'name': 'Isoliquiritigenin',
#     'Smiles': 'C1=CC(=CC=C1/C=C/C(=O)C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'TQS': ({'name': 'TQS',
#     'Smiles': 'C1C=CC2C1C(NC3=C2C=C(C=C3)S(=O)(=O)N)C4=CC=CC5=CC=CC=C54',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    ['8V80'],
#    ['YLR']),
#   '(E)-2,4,4-Trihydroxychalcone': ({'name': '(E)-2,4,4-Trihydroxychalcone',
#     'Smiles': 'C1=CC(=CC=C1C(=O)/C=C/C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NALTREXONE': ({'name': 'NALTREXONE',
#     'Smiles': 'C1CC1CN2CC[C@]34[C@@H]5C(=O)CC[C@]3([C@H]2CC6=C4C(=C(C=C6)O)O5)O',
#     'alpha4beta2': 'antagonist',
#     'alpha7': 'NAM',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2,2`,5`-Trihydroxychalcone': ({'name': '2,2`,5`-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '2,2`,4`-Trihydroxychalcone': ({'name': '2,2`,4`-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-dihydroxyphenyl)-1-(3-hydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-dihydroxyphenyl)-1-(3-hydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=CC(=C1)O)C(=O)/C=C/C2=C(C=C(C=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '3-Methoxy-4,2`,5`-trihydroxychalcone': ({'name': '3-Methoxy-4,2`,5`-trihydroxychalcone',
#     'Smiles': 'COC1=C(C=CC(=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'Ivermectin': ({'name': 'Ivermectin',
#     'Smiles': 'CC[C@H](C)[C@@H]1[C@H](CC[C@@]2(O1)C[C@@H]3C[C@H](O2)C/C=C(/[C@H]([C@H](/C=C/C=C/4CO[C@H]5[C@@]4([C@@H](C=C([C@H]5O)C)C(=O)O3)O)C)O[C@H]6C[C@@H]([C@H]([C@@H](O6)C)O[C@H]7C[C@@H]([C@H]([C@@H](O7)C)O)OC)OC)C)C',
#     'alpha4beta2': 'Unknown activity',
#     'alpha7': 'PAM type I',
#     'muscletype': 'N.A.'},
#    ['8F4V', '8UZJ'],
#    ['IVM']),
#   '2,2`,4-Trihydroxychalcone': ({'name': '2,2`,4-Trihydroxychalcone',
#     'Smiles': 'C1=CC=C(C(=C1)C(=O)/C=C/C2=C(C=C(C=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'GAT-107': ({'name': 'GAT-107',
#     'Smiles': 'C1C=C[C@H]2[C@@H]1[C@H](NC3=C2C=C(C=C3)S(=O)(=O)N)C4=CC=C(C=C4)Br',
#     'alpha4beta2': 'inactive',
#     'alpha7': 'ago - PAM type II',
#     'muscletype': 'inactive'},
#    ['8V86', '8V88'],
#    ['YLI']),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'A-867744': ({'name': 'A-867744',
#     'Smiles': 'CCC(=O)C1=C(N(C(=C1)C2=CC=C(C=C2)Cl)C3=CC=C(C=C3)S(=O)(=O)N)C',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'NSC17051': ({'name': 'NSC17051',
#     'Smiles': 'C1=CC(=CC(=C1)O)C(=O)/C=C\\C2=C(C=C(C=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2-Hydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2-Hydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC=C(C(=C1)/C=C/C(=O)C2=CC(=C(C=C2O)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-3-(2,4-Dihydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one': ({'name': '(E)-3-(2,4-Dihydroxyphenyl)-1-(2,4,5-trihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C/C(=O)C2=CC(=C(C=C2O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one': ({'name': '(Z)-3-(2,4-Dihydroxyphenyl)-1-(2,5-dihydroxyphenyl)prop-2-en-1-one',
#     'Smiles': 'C1=CC(=C(C=C1O)O)/C=C\\C(=O)C2=C(C=CC(=C2)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trimethoxyphenyl)prop-2-en-1-one': ({'name': '(E)-1-(4-Hydroxy-2-methylphenyl)-3-(2,3,4-trimethoxyphenyl)prop-2-en-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)O)C(=O)/C=C/C2=C(C(=C(C=C2)OC)OC)OC',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   'Compound 111': ({'name': 'Compound 111',
#     'Smiles': 'COC1=CC(=C(C=C1)/C=C/C(=O)C2=C(C=CC(=C2)O)O)OC',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM type II',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-dimethoxyphenyl)prop-2-en-1-one': ({'name': '(E)-1-(2,5-Dihydroxyphenyl)-3-(2-hydroxy-4,6-dimethoxyphenyl)prop-2-en-1-one',
#     'Smiles': 'COC1=CC(=C(C(=C1)OC)/C=C/C(=O)C2=C(C=CC(=C2)O)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    []),
#   '(E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-indol-3-yl)prop-2-en-1-one': ({'name': '(E)-1-(2,5-Dihydroxyphenyl)-3-(5-hydroxy-1H-indol-3-yl)prop-2-en-1-one',
#     'Smiles': 'C1=CC2=C(C=C1O)C(=CN2)/C=C/C(=O)C3=C(C=CC(=C3)O)O',
#     'alpha4beta2': 'N.A.',
#     'alpha7': 'PAM (type n.a.)',
#     'muscletype': 'N.A.'},
#    [],
#    [])},
#  'muscletype': {'MECAMYLAMINE': ({'name': 'MECAMYLAMINE',
#     'Smiles': 'C[C@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'buproprion': ({'name': 'buproprion',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-fluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(3-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(4-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester': ({'name': '(1R,5S)-3beta-(4-Methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2beta-carboxylic acid isopropyl ester',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC(C)C)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane': ({'name': '2beta-Carbomethoxy-3beta-(3-methyl-4-chlorophenyl)tropane',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Schembl20942833': ({'name': 'Schembl20942833',
#     'Smiles': 'CC1=CC=C(C=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC4CCC4)N3C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole': ({'name': '3-Ethyl-5-[(1R,2S,3S,5S)-8-methyl-3-(4-methylphenyl)-8-azabicyclo[3.2.1]octan-2-yl]-1,2-oxazole',
#     'Smiles': 'CCC1=NOC(=C1)[C@@H]2[C@H]3CC[C@H](N3C)C[C@@H]2C4=CC=C(C=C4)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(3-fluoro-4-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=C(C=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)F',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-(4-methoxyphenyl)-1,2-oxazole',
#     'Smiles': 'CN1[C@H]2CC[C@@H]1[C@H]([C@H](C2)C3=CC=C(C=C3)Cl)C4=CC(=NO4)C5=CC=C(C=C5)OC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'DEXMECAMYLAMINE': ({'name': 'DEXMECAMYLAMINE',
#     'Smiles': 'C[C@@]1([C@@H]2CC[C@@H](C2)C1(C)C)NC',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'NAM',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one': ({'name': '2-[tert-butyl(methyl)amino]-1-(3-chlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N(C)C(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one': ({'name': '1-(3-Chlorophenyl)-2-(piperidin-1-yl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Cl)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one': ({'name': '3-(Tert-butylamino)-1-(3-chlorophenyl)-2-methylpropan-1-one',
#     'Smiles': 'CC(CNC(C)(C)C)C(=O)C1=CC(=CC=C1)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromophenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC=C(C=C1)Br)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-chloro-4-methylphenyl)propan-1-one',
#     'Smiles': 'CC1=C(C=C(C=C1)C(=O)C(C)NC(C)(C)C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,5-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC(=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)butan-1-one',
#     'Smiles': 'CCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone": ({'name': "2-(N-Tert-Butylamino)-1-(2'-thienyl)-1-propanone",
#     'Smiles': 'CC(C(=O)C1=CC=CS1)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-m-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-m-tolylpropan-1-one',
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-difluorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)F)F)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one': ({'name': '1-(4-Bromo-3-methylphenyl)-2-(tert-butylamino)propan-1-one',
#     'Smiles': 'CC1=C(C=CC(=C1)C(=O)C(C)NC(C)(C)C)Br',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)pentan-1-one',
#     'Smiles': 'CCCC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3-methoxyphenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Tert-Butylamino)-3''-nitropropiophenone": ({'name': "2-(N-Tert-Butylamino)-3''-nitropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-fluoropropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-fluoropropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)F)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-bromopropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methylpropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Cyclopentylamino)-3''-methoxypropiophenone": ({'name': "2-(N-Cyclopentylamino)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one': ({'name': '2-(cyclopentylamino)-1-(3-nitrophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)[N+](=O)[O-])NC2CCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-bromopropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-bromopropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)Br)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methylpropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methylpropiophenone",
#     'Smiles': 'CC1=CC(=CC=C1)C(=O)C(C)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone": ({'name': "2-(N-Pyrrolidinyl)-3''-methoxypropiophenone",
#     'Smiles': 'CC(C(=O)C1=CC(=CC=C1)OC)N2CCCCC2',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one': ({'name': '2-(Tert-butylamino)-1-(3,4-dichlorophenyl)propan-1-one',
#     'Smiles': 'CC(C(=O)C1=CC(=C(C=C1)Cl)Cl)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-(Tert-butylamino)-1-p-tolylpropan-1-one': ({'name': '2-(Tert-butylamino)-1-p-tolylpropan-1-one',
#     'Smiles': 'CC1=CC=C(C=C1)C(=O)C(C)NC(C)(C)C',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole': ({'name': '2-[(1R,2S,3S,5S)-3-(4-Chlorophenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-5,6-dimethyl-1H-benzimidazole',
#     'Smiles': 'CC1=CC2=C(C=C1C)N=C(N2)[C@@H]3[C@H]4CC[C@H](N4C)C[C@@H]3C5=CC=C(C=C5)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3S,5S)-3-(4-chloro-3-methylphenyl)-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-methyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole': ({'name': '5-[(1R,2S,3S,5S)-3-(4-Chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octan-2-yl]-3-phenyl-1,2-oxazole',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@H]2C[C@@H]3CC[C@H]([C@H]2C4=CC(=NO4)C5=CC=CC=C5)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    []),
#   'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate': ({'name': 'Methyl (1R,2S,3R,5S)-3-(4-chloro-3-methylphenyl)-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate',
#     'Smiles': 'CC1=C(C=CC(=C1)[C@@H]2C[C@@H]3CC[C@H]([C@H]2C(=O)OC)N3C)Cl',
#     'alpha4beta2': 'NAM',
#     'alpha7': 'N.A.',
#     'muscletype': 'NAM'},
#    [],
#    [])}}

# %%
for r, pdbs in pdb_query.items():
    for name, (row, pdbs, comp) in pdbs.items():
        if len(pdbs) > 0 and len(comp) > 0:
            entry = allosteric.merge(pd.DF([row]))
            assert len(comp) == 1
            for pdb in pdbs:
                process_entry(
                    entry,
                    {"pdb": pdb.lower(), "mod": [[{"auth_comp_id": comp[0]}]]},
                    auto_site_grouping=True,
                    stringent_site_grouping=True
                )
# Out:
# 8utb [[{'auth_comp_id': 'XG3'}]]
# 7ekt [[{'auth_comp_id': 'I34'}]]
# 8v82 [[{'auth_comp_id': 'I34'}]]
# 8v8a [[{'auth_comp_id': 'I34'}]]
# 8v8c [[{'auth_comp_id': 'I34'}]]
# 8v8d [[{'auth_comp_id': 'I34'}]]
# 8v80 [[{'auth_comp_id': 'YLR'}]]
# 8f4v [[{'auth_comp_id': 'IVM'}]]
# 8uzj [[{'auth_comp_id': 'IVM'}]]
# 8v86 [[{'auth_comp_id': 'YLI'}]]
# 8v88 [[{'auth_comp_id': 'YLI'}]]

# %%
errors
# Out:
# {}

# %%
PDB.get(PDB.entry_id == "8f4v").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'F'}],
#    'label_entity_id': '2',
#    'type': 'non-polymer',
#    'pdbx_description': "(2aE,4E,5'S,6S,6'R,7S,8E,11R,13R,15S,17aR,20R,20aR,20bS)-6'-[(2S)-butan-2-yl]-20,20b-dihydroxy-5',6,8,19-tetramethyl-17 -oxo-3',4',5',6,6',10,11,14,15,17,17a,20,20a,20b-tetradecahydro-2H,7H-spiro[11,15-methanofuro[4,3,2-pq][2,6]benzodioxacy clooctadecine-13,2'-pyran]-7-yl 2,6-dideoxy-4-O-(2,6-dideoxy-3-O-methyl-alpha-L-arabino-hexopyranosyl)-3-O-methyl-alpha-L-arabino-hexopyranoside"}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['A', 'E']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['P36544']}],
#  'source': {'grall': [{'entry': {'Name': 'ivermectin-b1a',
#      'SMILES': 'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2',
#      'Family': 'avermectin',
#      'Binding Site': 'ivermectin',
#      'Level of Confidence': 1.0,
#      'Effect α1': '+',
#      'Effect α3': None,
#      'Activity Type α1': 'EC50(uM)',
#      'Activity Value α1': '1.7',
#      'Activity Type α3': None,
#      'Activity Value α3': None,
#      'doi': '10.1074/jbc.M110.107789',
#      'Kd_Resting(uM)': None,
#      'Kd_active(uM)': None,
#      'beta': None},
#     'version': '3.0',
#     'date': '12-3-2024',
#     'update': {'pdb': '8f4v', 'mod': [[{'auth_comp_id': 'IVM'}]]}}],
#   'acrall': [{'entry': {'cid': [6321424],
#      'name': ['Ivermectin'],
#      'Smiles': ['CC[C@H](C)[C@@H]1[C@H](CC[C@@]2(O1)C[C@@H]3C[C@H](O2)C/C=C(/[C@H]([C@H](/C=C/C=C/4CO[C@H]5[C@@]4([C@@H](C=C([C@H]5O)C)C(=O)O3)O)C)O[C@H]6C[C@@H]([C@H]([C@@H](O6)C)O[C@H]7C[C@@H]([C@H]([C@@H](O7)C)O)OC)OC)C)C'],
#      'inchikey': ['AZSNMRSAGSSBNP-XPNPUAGNSA-N'],
#      'in_vivo_tested': ['yes'],
#      'phase': [3],
#      'alpha4beta2': ['Unknown activity'],
#      'alpha7': ['PAM type I'],
#      'muscletype': ['N.A.'],
#      'targetname': ['nAChR a7'],
#      'metric': ['EC50_uM'],
#      'value': [11.0],
#      'reference': [9463487],
#      'measure': ['potency']},
#     'version': '23Jun23',
#     'date': '21-6-2024',
#     'update': {'pdb': '8f4v', 'mod': [[{'auth_comp_id': 'IVM'}]]}}]}}

# %%
PDB.get(PDB.entry_id == "8uzj").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'BA'}],
#    'label_entity_id': '8',
#    'type': 'non-polymer',
#    'pdbx_description': "(2aE,4E,5'S,6S,6'R,7S,8E,11R,13R,15S,17aR,20R,20aR,20bS)-6'-[(2S)-butan-2-yl]-20,20b-dihydroxy-5',6,8,19-tetramethyl-17 -oxo-3',4',5',6,6',10,11,14,15,17,17a,20,20a,20b-tetradecahydro-2H,7H-spiro[11,15-methanofuro[4,3,2-pq][2,6]benzodioxacy clooctadecine-13,2'-pyran]-7-yl 2,6-dideoxy-4-O-(2,6-dideoxy-3-O-methyl-alpha-L-arabino-hexopyranosyl)-3-O-methyl-alpha-L-arabino-hexopyranoside"}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['B', 'C']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['P36544']}],
#  'source': {'grall': [{'entry': {'Name': 'ivermectin-b1a',
#      'SMILES': 'CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\\C)[C@@H](O[C@H]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C)/C=C/C=C3\\CO[C@@H]4[C@H](O)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2',
#      'Family': 'avermectin',
#      'Binding Site': 'ivermectin',
#      'Level of Confidence': 1.0,
#      'Effect α1': '+',
#      'Effect α3': None,
#      'Activity Type α1': 'EC50(uM)',
#      'Activity Value α1': '1.7',
#      'Activity Type α3': None,
#      'Activity Value α3': None,
#      'doi': '10.1074/jbc.M110.107789',
#      'Kd_Resting(uM)': None,
#      'Kd_active(uM)': None,
#      'beta': None},
#     'version': '3.0',
#     'date': '12-3-2024',
#     'update': {'pdb': '8uzj', 'mod': [[{'auth_comp_id': 'IVM'}]]}}],
#   'acrall': [{'entry': {'cid': [6321424],
#      'name': ['Ivermectin'],
#      'Smiles': ['CC[C@H](C)[C@@H]1[C@H](CC[C@@]2(O1)C[C@@H]3C[C@H](O2)C/C=C(/[C@H]([C@H](/C=C/C=C/4CO[C@H]5[C@@]4([C@@H](C=C([C@H]5O)C)C(=O)O3)O)C)O[C@H]6C[C@@H]([C@H]([C@@H](O6)C)O[C@H]7C[C@@H]([C@H]([C@@H](O7)C)O)OC)OC)C)C'],
#      'inchikey': ['AZSNMRSAGSSBNP-XPNPUAGNSA-N'],
#      'in_vivo_tested': ['yes'],
#      'phase': [3],
#      'alpha4beta2': ['Unknown activity'],
#      'alpha7': ['PAM type I'],
#      'muscletype': ['N.A.'],
#      'targetname': ['nAChR a7'],
#      'metric': ['EC50_uM'],
#      'value': [11.0],
#      'reference': [9463487],
#      'measure': ['potency']},
#     'version': '23Jun23',
#     'date': '21-6-2024',
#     'update': {'pdb': '8uzj', 'mod': [[{'auth_comp_id': 'IVM'}]]}}]}}

# %%
PDB.get(PDB.entry_id == "8v8d").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'DA'}],
#    'label_entity_id': '5',
#    'type': 'non-polymer',
#    'pdbx_description': "N-(5-Chloro-2,4-dimethoxyphenyl)-N'-(5-methyl-3-isoxazolyl)-urea"}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['D', 'E']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['P36544']}],
#  'source': {'acrall': [{'entry': {'cid': [311434],
#      'name': ['PNU-120596'],
#      'Smiles': ['CC1=CC(=NO1)NC(=O)NC2=CC(=C(C=C2OC)OC)Cl'],
#      'inchikey': ['CEIIEALEIHQDBX-UHFFFAOYSA-N'],
#      'in_vivo_tested': ['yes'],
#      'phase': [0],
#      'alpha4beta2': ['N.A.'],
#      'alpha7': ['PAM type II'],
#      'muscletype': ['N.A.'],
#      'targetname': ['nAChR a7'],
#      'metric': ['EC50_uM'],
#      'value': [0.829245],
#      'reference': [20591663],
#      'measure': ['potency']},
#     'version': '23Jun23',
#     'date': '21-6-2024',
#     'update': {'pdb': '8v8d', 'mod': [[{'auth_comp_id': 'I34'}]]}}]}}

# %%
acrall_sites = list(list(s.info["source"].keys()) for s in Site.select().where(Site.info["source"].contains("acrall")))
acrall_sites
# Out:
# [['acrall'],
#  ['acrall'],
#  ['acrall'],
#  ['acrall'],
#  ['acrall'],
#  ['acrall'],
#  ['acrall'],
#  ['grall', 'acrall'],
#  ['grall', 'acrall'],
#  ['acrall'],
#  ['acrall']]

# %%
acrall_sites.count(['grall', 'acrall'])
# Out:
# 2

# %%
acrall_sites.count(['acrall'])
# Out:
# 9

# %% [markdown]
# # Statistics

# %%
# Total number of sites
len(Site.select())
# Out:
# 3190

# %%
# Total number of different PDBs
len(PDB.select())
# Out:
# 3050

# %%
# PDBs with no sites (expected 0)
[(pdb.entry_id, pdb) for p in PDB.select() if len(p.sites) == 0]
# Out:
# []

# %%
# Number of sites in PDBs
set(len(p.sites) for p in PDB.select())
# Out:
# {1, 2, 3, 4}

# %%
# Modulator identifier fields used
set(tuple(s.modulator.keys()) for s in Site.select())
# Out:
# {('label_asym_id',)}

# %%
# Number of different entity instances (different "label_asym_id") annotated as modulators to look for outliers
modulator_chains = dict(
    sorted(
        {s.id: len(s.modulator["label_asym_id"]) for s in Site.select()}.items(),
        key=lambda i: i[-1], reverse=True
    )
)
modulator_chains
# Out:
# {520: 24,
#  582: 8,
#  608: 6,
#  4806: 6,
#  5088: 6,
#  5246: 6,
#  5320: 6,
#  5365: 6,
#  160: 4,
#  187: 4,
#  193: 4,
#  368: 4,
#  380: 4,
#  412: 4,
#  684: 4,
#  741: 4,
#  4493: 4,
#  4767: 4,
#  336: 3,
#  419: 3,
#  481: 3,
#  482: 3,
#  483: 3,
#  552: 3,
#  569: 3,
#  570: 3,
#  592: 3,
#  599: 3,
#  615: 3,
#  624: 3,
#  2319: 3,
#  2327: 3,
#  2334: 3,
#  2633: 3,
#  4542: 3,
#  4559: 3,
#  4577: 3,
#  4590: 3,
#  4636: 3,
#  4733: 3,
#  4834: 3,
#  4842: 3,
#  4863: 3,
#  4886: 3,
#  4907: 3,
#  4929: 3,
#  4949: 3,
#  4966: 3,
#  4979: 3,
#  4992: 3,
#  5002: 3,
#  5003: 3,
#  5122: 3,
#  5143: 3,
#  5190: 3,
#  5200: 3,
#  5267: 3,
#  5272: 3,
#  5382: 3,
#  5463: 3,
#  5471: 3,
#  5474: 3,
#  5: 2,
#  14: 2,
#  51: 2,
#  75: 2,
#  81: 2,
#  91: 2,
#  92: 2,
#  93: 2,
#  94: 2,
#  95: 2,
#  97: 2,
#  136: 2,
#  140: 2,
#  144: 2,
#  147: 2,
#  150: 2,
#  153: 2,
#  168: 2,
#  175: 2,
#  198: 2,
#  248: 2,
#  254: 2,
#  269: 2,
#  272: 2,
#  288: 2,
#  318: 2,
#  328: 2,
#  339: 2,
#  371: 2,
#  383: 2,
#  418: 2,
#  432: 2,
#  446: 2,
#  463: 2,
#  467: 2,
#  480: 2,
#  488: 2,
#  491: 2,
#  523: 2,
#  526: 2,
#  529: 2,
#  530: 2,
#  573: 2,
#  585: 2,
#  627: 2,
#  748: 2,
#  752: 2,
#  755: 2,
#  762: 2,
#  767: 2,
#  771: 2,
#  783: 2,
#  1035: 2,
#  1039: 2,
#  1071: 2,
#  1074: 2,
#  1107: 2,
#  1111: 2,
#  1115: 2,
#  1118: 2,
#  1121: 2,
#  1124: 2,
#  1133: 2,
#  1136: 2,
#  1141: 2,
#  1152: 2,
#  1215: 2,
#  1262: 2,
#  1267: 2,
#  1272: 2,
#  1282: 2,
#  1291: 2,
#  1300: 2,
#  1305: 2,
#  1314: 2,
#  1329: 2,
#  1340: 2,
#  1346: 2,
#  1356: 2,
#  1365: 2,
#  1374: 2,
#  1383: 2,
#  1392: 2,
#  1397: 2,
#  1406: 2,
#  1415: 2,
#  1424: 2,
#  1429: 2,
#  1438: 2,
#  1447: 2,
#  1456: 2,
#  1461: 2,
#  1466: 2,
#  1557: 2,
#  1571: 2,
#  1575: 2,
#  1580: 2,
#  1584: 2,
#  1588: 2,
#  1602: 2,
#  1605: 2,
#  1617: 2,
#  1627: 2,
#  1633: 2,
#  1664: 2,
#  1668: 2,
#  1674: 2,
#  1678: 2,
#  1684: 2,
#  1729: 2,
#  1949: 2,
#  1958: 2,
#  2643: 2,
#  2648: 2,
#  2654: 2,
#  2659: 2,
#  2681: 2,
#  2781: 2,
#  2788: 2,
#  2795: 2,
#  2826: 2,
#  2833: 2,
#  2864: 2,
#  3054: 2,
#  3057: 2,
#  3518: 2,
#  3545: 2,
#  3570: 2,
#  3619: 2,
#  3622: 2,
#  3625: 2,
#  3667: 2,
#  3672: 2,
#  3706: 2,
#  3718: 2,
#  3898: 2,
#  3948: 2,
#  3955: 2,
#  3961: 2,
#  4305: 2,
#  4317: 2,
#  4320: 2,
#  4323: 2,
#  4326: 2,
#  4329: 2,
#  4332: 2,
#  4391: 2,
#  4399: 2,
#  4409: 2,
#  4421: 2,
#  4504: 2,
#  4598: 2,
#  4622: 2,
#  4644: 2,
#  4654: 2,
#  4665: 2,
#  4679: 2,
#  4705: 2,
#  4815: 2,
#  4823: 2,
#  4826: 2,
#  4835: 2,
#  4856: 2,
#  4857: 2,
#  4996: 2,
#  5001: 2,
#  5156: 2,
#  5169: 2,
#  5195: 2,
#  5209: 2,
#  5213: 2,
#  5218: 2,
#  5275: 2,
#  5368: 2,
#  5390: 2,
#  5393: 2,
#  5397: 2,
#  5410: 2,
#  5469: 2,
#  5519: 2,
#  6: 1,
#  7: 1,
#  8: 1,
#  9: 1,
#  10: 1,
#  11: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  18: 1,
#  19: 1,
#  21: 1,
#  22: 1,
#  23: 1,
#  24: 1,
#  25: 1,
#  28: 1,
#  29: 1,
#  31: 1,
#  32: 1,
#  33: 1,
#  34: 1,
#  35: 1,
#  36: 1,
#  37: 1,
#  38: 1,
#  39: 1,
#  40: 1,
#  41: 1,
#  42: 1,
#  43: 1,
#  44: 1,
#  45: 1,
#  46: 1,
#  52: 1,
#  53: 1,
#  54: 1,
#  55: 1,
#  56: 1,
#  57: 1,
#  58: 1,
#  59: 1,
#  60: 1,
#  61: 1,
#  62: 1,
#  63: 1,
#  64: 1,
#  65: 1,
#  66: 1,
#  67: 1,
#  68: 1,
#  70: 1,
#  71: 1,
#  72: 1,
#  76: 1,
#  78: 1,
#  82: 1,
#  83: 1,
#  84: 1,
#  85: 1,
#  86: 1,
#  87: 1,
#  88: 1,
#  99: 1,
#  113: 1,
#  114: 1,
#  116: 1,
#  117: 1,
#  118: 1,
#  119: 1,
#  120: 1,
#  121: 1,
#  123: 1,
#  124: 1,
#  125: 1,
#  126: 1,
#  127: 1,
#  128: 1,
#  129: 1,
#  130: 1,
#  131: 1,
#  132: 1,
#  176: 1,
#  177: 1,
#  178: 1,
#  194: 1,
#  195: 1,
#  223: 1,
#  224: 1,
#  225: 1,
#  226: 1,
#  227: 1,
#  228: 1,
#  229: 1,
#  230: 1,
#  231: 1,
#  232: 1,
#  233: 1,
#  234: 1,
#  235: 1,
#  236: 1,
#  238: 1,
#  239: 1,
#  240: 1,
#  241: 1,
#  242: 1,
#  247: 1,
#  253: 1,
#  273: 1,
#  274: 1,
#  275: 1,
#  276: 1,
#  277: 1,
#  278: 1,
#  279: 1,
#  280: 1,
#  281: 1,
#  282: 1,
#  283: 1,
#  284: 1,
#  300: 1,
#  301: 1,
#  303: 1,
#  305: 1,
#  306: 1,
#  307: 1,
#  308: 1,
#  309: 1,
#  310: 1,
#  311: 1,
#  312: 1,
#  313: 1,
#  314: 1,
#  315: 1,
#  319: 1,
#  320: 1,
#  321: 1,
#  751: 1,
#  784: 1,
#  785: 1,
#  786: 1,
#  787: 1,
#  789: 1,
#  790: 1,
#  791: 1,
#  792: 1,
#  793: 1,
#  794: 1,
#  795: 1,
#  796: 1,
#  797: 1,
#  798: 1,
#  799: 1,
#  800: 1,
#  801: 1,
#  802: 1,
#  804: 1,
#  805: 1,
#  811: 1,
#  812: 1,
#  815: 1,
#  816: 1,
#  817: 1,
#  818: 1,
#  819: 1,
#  820: 1,
#  824: 1,
#  826: 1,
#  827: 1,
#  828: 1,
#  830: 1,
#  831: 1,
#  832: 1,
#  834: 1,
#  835: 1,
#  836: 1,
#  837: 1,
#  838: 1,
#  839: 1,
#  840: 1,
#  841: 1,
#  842: 1,
#  843: 1,
#  844: 1,
#  845: 1,
#  846: 1,
#  847: 1,
#  850: 1,
#  852: 1,
#  861: 1,
#  862: 1,
#  865: 1,
#  866: 1,
#  867: 1,
#  868: 1,
#  869: 1,
#  870: 1,
#  872: 1,
#  876: 1,
#  877: 1,
#  878: 1,
#  879: 1,
#  880: 1,
#  886: 1,
#  888: 1,
#  892: 1,
#  893: 1,
#  894: 1,
#  896: 1,
#  897: 1,
#  898: 1,
#  899: 1,
#  900: 1,
#  901: 1,
#  902: 1,
#  903: 1,
#  904: 1,
#  905: 1,
#  906: 1,
#  907: 1,
#  908: 1,
#  909: 1,
#  910: 1,
#  911: 1,
#  912: 1,
#  913: 1,
#  914: 1,
#  915: 1,
#  916: 1,
#  917: 1,
#  918: 1,
#  919: 1,
#  920: 1,
#  921: 1,
#  922: 1,
#  923: 1,
#  924: 1,
#  925: 1,
#  927: 1,
#  928: 1,
#  930: 1,
#  931: 1,
#  933: 1,
#  934: 1,
#  935: 1,
#  936: 1,
#  937: 1,
#  938: 1,
#  939: 1,
#  940: 1,
#  941: 1,
#  942: 1,
#  943: 1,
#  944: 1,
#  945: 1,
#  946: 1,
#  947: 1,
#  948: 1,
#  949: 1,
#  950: 1,
#  951: 1,
#  952: 1,
#  953: 1,
#  954: 1,
#  955: 1,
#  956: 1,
#  957: 1,
#  958: 1,
#  960: 1,
#  961: 1,
#  973: 1,
#  974: 1,
#  975: 1,
#  976: 1,
#  977: 1,
#  978: 1,
#  979: 1,
#  980: 1,
#  981: 1,
#  982: 1,
#  983: 1,
#  984: 1,
#  985: 1,
#  986: 1,
#  987: 1,
#  988: 1,
#  989: 1,
#  990: 1,
#  991: 1,
#  992: 1,
#  993: 1,
#  994: 1,
#  995: 1,
#  996: 1,
#  997: 1,
#  998: 1,
#  999: 1,
#  1000: 1,
#  1001: 1,
#  1002: 1,
#  1003: 1,
#  1004: 1,
#  1005: 1,
#  1006: 1,
#  1007: 1,
#  1008: 1,
#  1009: 1,
#  1010: 1,
#  1012: 1,
#  1015: 1,
#  1016: 1,
#  1017: 1,
#  1018: 1,
#  1020: 1,
#  1021: 1,
#  1022: 1,
#  1023: 1,
#  1024: 1,
#  1025: 1,
#  1026: 1,
#  1027: 1,
#  1029: 1,
#  1030: 1,
#  1031: 1,
#  1032: 1,
#  1036: 1,
#  1040: 1,
#  1041: 1,
#  1045: 1,
#  1046: 1,
#  1047: 1,
#  1048: 1,
#  1049: 1,
#  1050: 1,
#  1051: 1,
#  1052: 1,
#  1053: 1,
#  1054: 1,
#  1055: 1,
#  1056: 1,
#  1057: 1,
#  1058: 1,
#  1059: 1,
#  1060: 1,
#  1061: 1,
#  1062: 1,
#  1063: 1,
#  1064: 1,
#  1065: 1,
#  1066: 1,
#  1067: 1,
#  1068: 1,
#  1075: 1,
#  1076: 1,
#  1078: 1,
#  1079: 1,
#  1080: 1,
#  1081: 1,
#  1082: 1,
#  1083: 1,
#  1084: 1,
#  1085: 1,
#  1086: 1,
#  1087: 1,
#  1089: 1,
#  1090: 1,
#  1091: 1,
#  1092: 1,
#  1093: 1,
#  1094: 1,
#  1095: 1,
#  1096: 1,
#  1097: 1,
#  1098: 1,
#  1099: 1,
#  1100: 1,
#  1102: 1,
#  1154: 1,
#  1155: 1,
#  1156: 1,
#  1157: 1,
#  1158: 1,
#  1159: 1,
#  1160: 1,
#  1161: 1,
#  1162: 1,
#  1163: 1,
#  1164: 1,
#  1165: 1,
#  1166: 1,
#  1167: 1,
#  1168: 1,
#  1169: 1,
#  1170: 1,
#  1171: 1,
#  1172: 1,
#  1173: 1,
#  1174: 1,
#  1175: 1,
#  1176: 1,
#  1177: 1,
#  1178: 1,
#  1179: 1,
#  1180: 1,
#  1181: 1,
#  1183: 1,
#  1184: 1,
#  1187: 1,
#  1188: 1,
#  1189: 1,
#  1190: 1,
#  1192: 1,
#  1193: 1,
#  1194: 1,
#  1195: 1,
#  1196: 1,
#  1199: 1,
#  1201: 1,
#  1202: 1,
#  1203: 1,
#  1204: 1,
#  1205: 1,
#  1206: 1,
#  1207: 1,
#  1208: 1,
#  1209: 1,
#  1210: 1,
#  1211: 1,
#  1216: 1,
#  1217: 1,
#  1218: 1,
#  1219: 1,
#  1220: 1,
#  1221: 1,
#  1222: 1,
#  1223: 1,
#  1224: 1,
#  1225: 1,
#  1226: 1,
#  1227: 1,
#  1228: 1,
#  1229: 1,
#  1230: 1,
#  1231: 1,
#  1232: 1,
#  1233: 1,
#  1234: 1,
#  1235: 1,
#  1236: 1,
#  1237: 1,
#  1238: 1,
#  1239: 1,
#  1240: 1,
#  1241: 1,
#  1242: 1,
#  1243: 1,
#  1244: 1,
#  1245: 1,
#  1246: 1,
#  1247: 1,
#  1248: 1,
#  1249: 1,
#  1250: 1,
#  1251: 1,
#  1252: 1,
#  1253: 1,
#  1254: 1,
#  1255: 1,
#  1256: 1,
#  1257: 1,
#  1273: 1,
#  1315: 1,
#  1316: 1,
#  1317: 1,
#  1318: 1,
#  1319: 1,
#  1320: 1,
#  1330: 1,
#  1331: 1,
#  1341: 1,
#  1347: 1,
#  1467: 1,
#  1468: 1,
#  1469: 1,
#  1470: 1,
#  1471: 1,
#  1472: 1,
#  1473: 1,
#  1474: 1,
#  1475: 1,
#  1476: 1,
#  1477: 1,
#  1478: 1,
#  1479: 1,
#  1480: 1,
#  1481: 1,
#  1482: 1,
#  1483: 1,
#  1484: 1,
#  1485: 1,
#  1486: 1,
#  1487: 1,
#  1488: 1,
#  1489: 1,
#  1490: 1,
#  1491: 1,
#  1492: 1,
#  1493: 1,
#  1494: 1,
#  1495: 1,
#  1496: 1,
#  1497: 1,
#  1498: 1,
#  1499: 1,
#  1500: 1,
#  1501: 1,
#  1502: 1,
#  1508: 1,
#  1509: 1,
#  1510: 1,
#  1511: 1,
#  1512: 1,
#  1513: 1,
#  1514: 1,
#  1515: 1,
#  1516: 1,
#  1517: 1,
#  1518: 1,
#  1519: 1,
#  1520: 1,
#  1521: 1,
#  1522: 1,
#  1523: 1,
#  1524: 1,
#  1525: 1,
#  1526: 1,
#  1527: 1,
#  1528: 1,
#  1529: 1,
#  1530: 1,
#  1531: 1,
#  1532: 1,
#  1533: 1,
#  1534: 1,
#  1535: 1,
#  1536: 1,
#  1537: 1,
#  1538: 1,
#  1539: 1,
#  1540: 1,
#  1541: 1,
#  1542: 1,
#  1543: 1,
#  1544: 1,
#  1545: 1,
#  1546: 1,
#  1547: 1,
#  1548: 1,
#  1549: 1,
#  1550: 1,
#  1551: 1,
#  1553: 1,
#  1560: 1,
#  1561: 1,
#  1562: 1,
#  1563: 1,
#  1564: 1,
#  1565: 1,
#  1566: 1,
#  1567: 1,
#  1572: 1,
#  1576: 1,
#  1589: 1,
#  1590: 1,
#  1591: 1,
#  1592: 1,
#  1593: 1,
#  1594: 1,
#  1595: 1,
#  1596: 1,
#  1597: 1,
#  1598: 1,
#  1599: 1,
#  1606: 1,
#  1607: 1,
#  1608: 1,
#  1610: 1,
#  1612: 1,
#  1613: 1,
#  1618: 1,
#  1619: 1,
#  1620: 1,
#  1621: 1,
#  1622: 1,
#  1624: 1,
#  1634: 1,
#  1635: 1,
#  1636: 1,
#  1637: 1,
#  1638: 1,
#  1639: 1,
#  1641: 1,
#  1643: 1,
#  1645: 1,
#  1646: 1,
#  1647: 1,
#  1649: 1,
#  1650: 1,
#  1651: 1,
#  1652: 1,
#  1653: 1,
#  1654: 1,
#  1655: 1,
#  1656: 1,
#  1657: 1,
#  1658: 1,
#  1659: 1,
#  1660: 1,
#  1661: 1,
#  1665: 1,
#  1669: 1,
#  1670: 1,
#  1671: 1,
#  1675: 1,
#  1679: 1,
#  1680: 1,
#  1681: 1,
#  1685: 1,
#  1686: 1,
#  1687: 1,
#  1688: 1,
#  1689: 1,
#  1690: 1,
#  1691: 1,
#  1692: 1,
#  1693: 1,
#  1694: 1,
#  1695: 1,
#  1696: 1,
#  1697: 1,
#  1698: 1,
#  1699: 1,
#  1700: 1,
#  1701: 1,
#  1702: 1,
#  1703: 1,
#  1704: 1,
#  1705: 1,
#  1706: 1,
#  1707: 1,
#  1709: 1,
#  1711: 1,
#  1712: 1,
#  1713: 1,
#  1714: 1,
#  1715: 1,
#  1716: 1,
#  1717: 1,
#  1718: 1,
#  1720: 1,
#  1721: 1,
#  1722: 1,
#  1723: 1,
#  1724: 1,
#  1725: 1,
#  1726: 1,
#  1730: 1,
#  1731: 1,
#  1732: 1,
#  1733: 1,
#  1734: 1,
#  1735: 1,
#  1736: 1,
#  1737: 1,
#  1739: 1,
#  1740: 1,
#  1741: 1,
#  1742: 1,
#  1743: 1,
#  1744: 1,
#  1745: 1,
#  1746: 1,
#  1747: 1,
#  1748: 1,
#  1749: 1,
#  1752: 1,
#  1753: 1,
#  1754: 1,
#  1755: 1,
#  1756: 1,
#  1758: 1,
#  1759: 1,
#  1760: 1,
#  1761: 1,
#  1762: 1,
#  1763: 1,
#  1764: 1,
#  1766: 1,
#  1767: 1,
#  1768: 1,
#  1769: 1,
#  1770: 1,
#  1771: 1,
#  1773: 1,
#  1775: 1,
#  1776: 1,
#  1777: 1,
#  1779: 1,
#  1780: 1,
#  1781: 1,
#  1782: 1,
#  1783: 1,
#  1784: 1,
#  1785: 1,
#  1786: 1,
#  1787: 1,
#  1788: 1,
#  1795: 1,
#  1796: 1,
#  1797: 1,
#  1798: 1,
#  1799: 1,
#  1800: 1,
#  1801: 1,
#  1802: 1,
#  1803: 1,
#  1804: 1,
#  1805: 1,
#  1806: 1,
#  1807: 1,
#  1808: 1,
#  1809: 1,
#  1810: 1,
#  1811: 1,
#  1814: 1,
#  1815: 1,
#  1816: 1,
#  1817: 1,
#  1818: 1,
#  1819: 1,
#  1820: 1,
#  1821: 1,
#  1822: 1,
#  1823: 1,
#  1824: 1,
#  1825: 1,
#  1826: 1,
#  1827: 1,
#  1828: 1,
#  1829: 1,
#  1830: 1,
#  1832: 1,
#  1833: 1,
#  1834: 1,
#  1836: 1,
#  1837: 1,
#  1838: 1,
#  1839: 1,
#  ...}

# %%
db.close()
# Out:
# True
