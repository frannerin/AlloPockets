# %% [markdown]
# # Database

# %%
import src
from src import *
from src.creation import create_entry, combine_sites, NoModulator

# %%
db.init('database.db')
src.allodb.save_cifs = True

# %%
import pandas as pd
pd.DF = pd.DataFrame

# %% [markdown]
# # Data in Peter *et al.*
#
# Data directly provides PDB IDs and the residue names/IDs of the molecules found in them and their different mode of actions, so only those with "Allosteric" mode will be taken into account.

# %%
df = pd.read_excel("data/Resubmission_ci-2024-00819j_SI-data_10July2024.xlsx", sheet_name=1)
df
# Out:
#                  Class_state  \
# 0                   A-Active
# 1                 A-Inactive
# 2    A-Inactive/Intermediate
# 3                 A-Inactive
# 4                 A-Inactive
# ..                       ...
# 192                 C-Active
# 193  C-Inactive/Intermediate
# 194                      NaN
# 195                      [1]
# 196                      [2]
#
#                                         Structure_name ligand_id  \
# 0                                          5ht1a_8w8bR       UJL
# 1                                          c5ar1_6c1qB       9P2
# 2                                          p2ry1_4xnvA       BUR
# 3                                          c5ar1_6c1rB       EFD
# 4                                          adrb2_6obaA       M3J
# ..                                                 ...       ...
# 192                                        grm5_8taoAB       YKU
# 193                                         grm5_4oo9A       2U8
# ...

# %%
df.value_counts("Ligand Mode")
# Out:
# Ligand Mode
# Orthosteric    131
# Allosteric      63
# Name: count, dtype: int64

# %% [markdown]
# <br>
#
# Number of structures per class

# %%
df.query("`Ligand Mode` == 'Allosteric'").value_counts("Class_state")
# Out:
# Class_state
# A-Active                    19
# A-Inactive/Intermediate     11
# C-Inactive/Intermediate     11
# C-Active                     9
# B1-Inactive/Intermediate     7
# A-Inactive                   3
# B1-Active                    3
# Name: count, dtype: int64

# %% [markdown]
# <br>
#
# Unique combinations of structure ID and ligand ID

# %%
df.query("`Ligand Mode` == 'Allosteric'")[["Structure_name", "ligand_id"]]
# Out:
#     Structure_name ligand_id
# 1      c5ar1_6c1qB       9P2
# 2      p2ry1_4xnvA       BUR
# 3      c5ar1_6c1rB       EFD
# 4      adrb2_6obaA       M3J
# 5       cnr1_7wv9R       7IC
# ..             ...       ...
# 189     grm5_5cgdA       51E
# 190     grm5_7p2lA       4YI
# 191     grm5_5cgcA       51D
# 192    grm5_8taoAB       YKU
# 193     grm5_4oo9A       2U8
#
# [63 rows x 2 columns]

# %% [markdown]
# <br>
#
# Duplicated unique PDBs

# %%
df.query("`Ligand Mode` == 'Allosteric'")["Structure_name"].apply(lambda x: x.split("_")[-1][:4]).value_counts()
# Out:
# Structure_name
# 8jd5    2
# 6c1q    1
# 7sil    1
# 8gti    1
# 4k5y    1
#        ..
# 5kw2    1
# 6kqi    1
# 7cfn    1
# 8jii    1
# 4oo9    1
# Name: count, Length: 62, dtype: int64

# %%
df.query("`Ligand Mode` == 'Allosteric'")[df.query("`Ligand Mode` == 'Allosteric'")["Structure_name"].str.contains("8jd5")]
# Out:
#                  Class_state Structure_name ligand_id  \
# 182                 C-Active    grm2_8jd524       HZR
# 185  C-Inactive/Intermediate    grm4_8jd524       BQI
#
#                                        Smiles Ligand Mode  \
# 182  CCCCN1C=CC(=C(C1=O)Cl)N2CCC(CC2)c3ccccc3  Allosteric
# 185        Cc1ccnc(n1)Nc2nc(c(s2)C)c3c[nH]nc3  Allosteric
#
#          Barplot Category Predicted Site Pocket Volume [Å³]  \
# 182      intrahelical (C)  C-IH-TM234567           2114.016
# 185  extrahelical mid (C)  C-EH-TM67_mid            1329.75
#
#      Ligand Volume [Å³] chromlogD (pred.) Halogen [#]  Br [#]  Cl [#]  F [#]  \
# 182            2125.828              7.29           1     0.0     1.0    0.0
# 185            1447.453                 3           0     0.0     0.0    0.0
#
#      I [#]
# 182    0.0
# 185    0.0

# %% [markdown]
# 8jd5 is a PDB with an orthosteric ligand and two allosteric modulators bound, so two different Sites will be processed.
#
# <br>

# %%
# import os, pickle, requests, json

# %% [markdown]
# ## Data already in the database

# %%
list(
    PDB.select()
    .where(
        PDB.entry_id.in_(
            df.query("`Ligand Mode` == 'Allosteric'")["Structure_name"]
            .apply(lambda x: x.split("_")[-1][:4])
            .unique().tolist()
        )
    )
)
# Out:
# [<PDB: 4k5y>,
#  <PDB: 4oo9>,
#  <PDB: 4or2>,
#  <PDB: 4xnv>,
#  <PDB: 5cgc>,
#  <PDB: 5cgd>,
#  <PDB: 5ee7>,
#  <PDB: 5kw2>,
#  <PDB: 5lwe>,
#  <PDB: 5ndz>,
#  <PDB: 5t1a>,
#  <PDB: 5tzy>,
#  <PDB: 5vex>,
#  <PDB: 5x7d>,
#  <PDB: 6c1q>,
#  <PDB: 6c1r>,
#  <PDB: 6ffh>,
#  <PDB: 6ffi>,
#  <PDB: 6kqi>,
#  <PDB: 6n48>,
#  <PDB: 6oba>,
#  <PDB: 6qzh>,
#  <PDB: 6uo8>,
#  <PDB: 6vcb>,
#  <PDB: 7c7q>,
#  <PDB: 7cfn>,
#  <PDB: 7ld3>,
#  <PDB: 7ljc>,
#  <PDB: 7p2l>,
#  <PDB: 7v6a>,
#  <PDB: 7wv9>]

# %%
[
    (p.entry_id, r["ligand_id"] in s, r["ligand_id"], s)
    for i, r in df.query("`Ligand Mode` == 'Allosteric'")[["Structure_name", "ligand_id"]].iterrows()
    for p in [PDB.get_or_none(PDB.entry_id == r["Structure_name"].split("_")[-1][:4])]
    if p is not None
    for s in [[m for s in p.sites for m in s.modulator_residues.label_comp_id.unique().tolist()]]
]
# Out:
# [('6c1q', True, '9P2', ['9P2']),
#  ('4xnv', True, 'BUR', ['BUR']),
#  ('6c1r', True, 'EFD', ['EFD']),
#  ('6oba', True, 'M3J', ['M3J']),
#  ('7wv9', True, '7IC', ['7IC']),
#  ('7ld3', True, 'XTD', ['XTD']),
#  ('7ljc', True, 'G4C', ['G4C']),
#  ('6n48', True, 'KBY', ['KBY']),
#  ('7v6a', True, '5XI', ['5XI']),
#  ('5x7d', True, '8VS', ['8VS']),
#  ('5ndz', True, '8UN', ['8UN']),
#  ('5t1a', True, 'VT5', ['VT5']),
#  ('6qzh', True, 'JLW', ['JLW']),
#  ('5lwe', True, '79K', ['79K']),
#  ('5tzy', True, '7OS', ['7OS']),
#  ('5kw2', True, '6XQ', ['6XQ']),
#  ('6kqi', True, '9GL', ['9GL']),
#  ('7cfn', True, 'FX0', ['FX0']),
#  ('4k5y', True, '1Q5', ['1Q5']),
#  ('6vcb', True, 'QW7', ['QW7']),
#  ('5vex', True, '97V', ['97V']),
#  ('5ee7', True, '5MV', ['5MV']),
#  ('6uo8', True, 'QDA', ['QDA']),
#  ('7c7q', False, 'FN0', ['2C0']),
#  ('4or2', True, 'FM9', ['FM9']),
#  ('6ffi', True, 'D8B', ['D8B']),
#  ('6ffh', True, 'D7W', ['D7W']),
#  ('5cgd', True, '51E', ['51E']),
# ...

# %%
PDB.get(PDB.entry_id == "7c7q").sites[0].info
# Out:
# {'modulator_info': [{'modulator': [{'label_asym_id': 'I'}],
#    'label_entity_id': '5',
#    'type': 'non-polymer',
#    'pdbx_description': 'baclofen'}],
#  'interacting_chains_info': [{'label_entity_id': '1',
#    'interacting_chains': {'label_asym_id': ['A']},
#    'polymer_type': 'polypeptide(L)',
#    'Uniprot': ['Q9UBS5']}],
#  'source': {'allosteric_database': [{'entry': [{'target_id': 'ASD01150000_1',
#       'target_gene': 'GABBR1',
#       'organism': 'Homo sapiens',
#       'pdb_uniprot': 'Q9UBS5',
#       'allosteric_pdb': '7C7Q',
#       'modulator_serial': None,
#       'modulator_alias': '2C0',
#       'modulator_chain': 'A',
#       'modulator_class': 'Lig',
#       'modulator_feature': 'Regulator',
#       'modulator_name': 'baclofen',
#       'modulator_resi': '1007',
#       'function': None,
#       'position': None,
#       'pubmed_id': None,
#       'ref_title': None,
#       'site_overlap': None,
#       'allosteric_site_residue': '7C7Q'}],
# ...

# %% [markdown]
# The already-annotated allosteric modulator on PDB 7c7q (from the Allosteric Database) does not coincide with the annotated modulator in the dataset in Peter *et al.*, and upon inspection of the primary reference the existing annotation is indeed wrong and will be deleted.
#
# <br>

# %%
PDB.get(PDB.entry_id == "7c7q").delete_instance()
# Out:
# 1

# %% [markdown]
# ## *Wrong* data already in the database

# %%
list(
    PDB.select()
    .where(
        PDB.entry_id.in_(
            df.query("`Ligand Mode` == 'Orthosteric'")["Structure_name"]
            .apply(lambda x: x.split("_")[-1][:4])
            .unique().tolist()
        )
    )
)
# Out:
# [<PDB: 4n6h>, <PDB: 5ndd>, <PDB: 5tzr>, <PDB: 6tpk>, <PDB: 7cfm>, <PDB: 7ld3>]

# %%
pd.DF([
    (
        p.entry_id,
        r["ligand_id"],
        df.query("`Ligand Mode` == 'Allosteric'")[
            df.query("`Ligand Mode` == 'Allosteric'")["Structure_name"].str.contains(p.entry_id)
        ]["ligand_id"].tolist(),
        s
    )
    for i, r in df.query("`Ligand Mode` == 'Orthosteric'")[["Structure_name", "ligand_id"]].iterrows()
    for p in [PDB.get_or_none(PDB.entry_id == r["Structure_name"].split("_")[-1][:4])]
    if p is not None
    for s in [[m for s in p.sites for m in s.modulator_residues.label_comp_id.unique().tolist()]]
], columns=["pdb", "ortho", "allo", "allodb"])
# Out:
#     pdb ortho   allo allodb
# 0  4n6h   EJ4     []   [NA]
# 1  5ndd   8TZ     []  [8TZ]
# 2  6tpk   NU2     []  [CLR]
# 3  5tzr   MK6     []  [MK6]
# 4  7ld3   ADN  [XTD]  [XTD]
# 5  7cfm   FWX     []  [FWX]

# %% [markdown]
# The new dataset-annotated othosteric site is annotated as the allosteric modulator in the previously existing annotations for 3 different PDBs. For other 2 (4n6h, 6tpk), molecules different than the orthosteric ligand are annotated as allosteric although they are not recognised as allosteric in the new Peter *et al.* dataset. Finally, one structure with both new-dataset-annotated orthosteric and allosteric ligands has a correctly saved allosteric site.
#
# The 3 wrongly annotated orthosteric ligands are going to be deleted.
#
# <br>

# %%
assert all(len(PDB.get(PDB.entry_id == p).sites) == 1 for p in ["5ndd", "5tzr", "7cfm"])

# %%
for p in ["5ndd", "5tzr", "7cfm"]:
    PDB.get(PDB.entry_id == p).delete_instance()

# %% [markdown]
# ## Processing

# %%
errors = {}
error_entries = []

# %%
def process_entry(entry, update=None, auto_site_grouping=True, stringent_site_grouping=True):
    try:
        if update is None:
            pdb = entry["Structure_name"].split("_")[-1][:4]
            mod = [[{"auth_comp_id": entry["ligand_id"]}]]
        else:
            pdb = update["pdb"]
            mod = update["mod"]
        print(pdb, mod)
    
        old_sites = None
        # If PDB already exists, save its site IDs
        if PDB.get_or_none(PDB.entry_id == pdb) is not None:
            old_sites = list(PDB.get(PDB.entry_id == pdb).sites)
            
        with db.atomic() as txn:
            sites = create_entry(db, pdb, mod, auto_site_grouping, stringent_site_grouping)
            
            assert len(sites.objects()) == 1, f"{pdb}, {mod}: using only residue name retrieves more than one site(group)"
            
            for site in sites.objects():
                site.info["source"] = {
                    "petersetal": [{                        
                        k: v for k, v in {
                            "entry": [entry.to_dict()],
                            "date": "26-7-2024",
                            "update": update 
                        }.items() if v is not None
                    }],
                }
                site.save()
                
            if old_sites is not None:
                try:
                    combine_sites(db, pdb.lower(), old_sites, sites.objects(), auto_site_grouping, stringent_site_grouping)
                except Exception as e:
                    assert False, "combine_sites failed; " + str(e.args[0])

        return sites

    except (AssertionError, KeyError) as error:
        id = pdb.lower()
        errors.setdefault(id, [])
        errors[id].append(str(error.args[0]))
        error_entries.append(entry)
        print(id, errors[id])

# %%
for i, row in df.query("`Ligand Mode` == 'Allosteric'").iterrows():
    process_entry(
        row,
        None,
        auto_site_grouping=True,
        stringent_site_grouping=True
    )
# Out:
# 6c1q [[{'auth_comp_id': '9P2'}]]
# 4xnv [[{'auth_comp_id': 'BUR'}]]
# 6c1r [[{'auth_comp_id': 'EFD'}]]
# 6oba [[{'auth_comp_id': 'M3J'}]]
# 7wv9 [[{'auth_comp_id': '7IC'}]]
# 7ld3 [[{'auth_comp_id': 'XTD'}]]
# 7ljc [[{'auth_comp_id': 'G4C'}]]
# 6n48 [[{'auth_comp_id': 'KBY'}]]
# 6u1n [[{'auth_comp_id': '2CU'}]]
# 8fx5 [[{'auth_comp_id': 'XNO'}]]
# 8fx5 ["8fx5, [[{'auth_comp_id': 'XNO'}]]: using only residue name retrieves more than one site(group)"]
# 7v6a [[{'auth_comp_id': '5XI'}]]
# 7trp [[{'auth_comp_id': 'IUE'}]]
# 7trq [[{'auth_comp_id': 'IUI'}]]
# 5x7d [[{'auth_comp_id': '8VS'}]]
# 8jpf [[{'auth_comp_id': 'SRW'}]]
# 5ndz [[{'auth_comp_id': '8UN'}]]
# 5t1a [[{'auth_comp_id': 'VT5'}]]
# 6qzh [[{'auth_comp_id': 'JLW'}]]
# 5lwe [[{'auth_comp_id': '79K'}]]
# 6lfl [[{'auth_comp_id': 'EBX'}]]
# 8hnn [[{'auth_comp_id': '43I'}]]
# 8i2g [[{'auth_comp_id': 'O6F'}]]
# 7fih [[{'auth_comp_id': '55Z'}]]
# 7xw6 [[{'auth_comp_id': 'HOI'}]]
# 5tzy [[{'auth_comp_id': '7OS'}]]
# ...

# %%
errors
# Out:
# {'8fx5': ["8fx5, [[{'auth_comp_id': 'XNO'}]]: using only residue name retrieves more than one site(group)"],
#  '7cfn': ["7cfn, [[{'auth_comp_id': 'FX0'}]]: using only residue name retrieves more than one site(group)"]}

# %%
PDB.get_or_none(PDB.entry_id == "8fx5")

# %%
pdb = "8fx5"
row = df.query("`Ligand Mode` == 'Allosteric'").loc[lambda x: x["Structure_name"].str.contains(pdb)]
assert len(row) == 1
sites = process_entry(
    row.squeeze(),
    {"pdb": pdb, "mod":[[{"auth_comp_id": row["ligand_id"].item(), "label_asym_id": "G"}]]},
    auto_site_grouping=True,
    stringent_site_grouping=True
)
[s.info for s in sites]
# Out:
# 8fx5 [[{'auth_comp_id': 'XNO', 'label_asym_id': 'G'}]]
# [{'modulator_info': [{'modulator': [{'label_asym_id': 'G'}],
#     'label_entity_id': '6',
#     'type': 'non-polymer',
#     'pdbx_description': 'xanomeline'}],
#   'interacting_chains_info': [{'label_entity_id': '1',
#     'interacting_chains': {'label_asym_id': ['A']},
#     'polymer_type': 'polypeptide(L)',
#     'Uniprot': ['P08173']}],
#   'source': {'petersetal': [{'entry': [{'Class_state': 'A-Active',
#        'Structure_name': 'acm4_8fx5R',
#        'ligand_id': 'XNO',
#        'Smiles': 'CCCCCCOc1c(nsn1)C2=CCCN(C2)C',
#        'Ligand Mode': 'Allosteric',
#        'Barplot Category': 'intrahelical (A)',
#        'Predicted Site': 'A-IH-Orthosteric-ECV',
#        'Pocket Volume [Å³]': 2166.328,
#        'Ligand Volume [Å³]': 2430.0,
#        'chromlogD (pred.)': 6.9,
#        'Halogen [#]': 0,
#        'Br [#]': 0.0,
#        'Cl [#]': 0.0,
#        'F [#]': 0.0,
#        'I [#]': 0.0}],
#      'date': '26-7-2024',
# ...

# %% [markdown]
# According to the primary reference, only label_asym_id G is the allosteric modulator.
#
# <br>

# %%
PDB.get_or_none(PDB.entry_id == "7cfn")
# Out:
# <PDB: 7cfn>

# %%
[(s.id, s.modulator_residues.to_dict(orient="records")) for s in PDB.get(PDB.entry_id == "7cfn").sites]
# Out:
# [(4441,
#   [{'label_comp_id': 'FX0',
#     'label_asym_id': 'F',
#     'label_entity_id': '6',
#     'label_seq_id': '.',
#     'pdbx_PDB_ins_code': '?',
#     'auth_seq_id': '401',
#     'auth_comp_id': 'FX0',
#     'auth_asym_id': 'R',
#     'pdbx_PDB_model_num': '1',
#     'pdbx_label_index': '401',
#     'pdbx_sifts_xref_db_name': '?',
#     'pdbx_sifts_xref_db_acc': '?',
#     'pdbx_sifts_xref_db_num': '?',
#     'pdbx_sifts_xref_db_res': '?'}])]

# %%
pdb = "7cfn"
row = df.query("`Ligand Mode` == 'Allosteric'").loc[lambda x: x["Structure_name"].str.contains(pdb)]
assert len(row) == 1
sites = process_entry(
    row.squeeze(),
    {"pdb": pdb, "mod":[[{"auth_comp_id": row["ligand_id"].item(), "label_asym_id": "F"}]]},
    auto_site_grouping=True,
    stringent_site_grouping=True
)
[s.info for s in sites]
# Out:
# 7cfn [[{'auth_comp_id': 'FX0', 'label_asym_id': 'F'}]]
# [{'modulator_info': [{'modulator': [{'label_asym_id': 'F'}],
#     'label_entity_id': '6',
#     'type': 'non-polymer',
#     'pdbx_description': '(2S,4R)-4-[(3R,5S,6R,7R,8R,9S,10S,12S,13R,14S,17R)-6-ethyl-10,13-dimethyl-3,7,12-tris(oxidanyl)-2,3,4,5,6,7,8,9,11,12,14,15,16,17-tetradecahydro-1H-cyclopenta[a]phenanthren-17-yl]-2-methyl-pentanoic acid'}],
#   'interacting_chains_info': [{'label_entity_id': '5',
#     'interacting_chains': {'label_asym_id': ['E']},
#     'polymer_type': 'polypeptide(L)',
#     'Uniprot': ['Q8TDU6']}],
#   'source': {'allosteric_database': [{'entry': [{'target_id': 'ASD21930000_1',
#        'target_gene': 'GPBAR1',
#        'organism': 'Homo sapiens',
#        'pdb_uniprot': 'Q8TDU6',
#        'allosteric_pdb': '7CFN',
#        'modulator_serial': None,
#        'modulator_alias': 'FX0',
#        'modulator_chain': 'R',
#        'modulator_class': 'Lig',
#        'modulator_feature': 'Activator',
# ...

# %% [markdown]
# According to the primary reference, only label_asym_id F is the allosteric modulator, which also coincides with the molecule that was already annotated in the database.
#
# <br>

# %%
new_sites = list(list(s.info["source"].keys()) for s in Site.select().where(Site.info["source"].contains("petersetal")))
new_sites
# Out:
# [['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['allosteric_database', 'petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
#  ['petersetal'],
# ...

# %%
new_sites.count(['allosteric_database', 'petersetal'])
# Out:
# 30

# %%
new_sites.count(['petersetal'])
# Out:
# 33

# %% [markdown]
# # Statistics

# %%
# Total number of sites
len(Site.select())
# Out:
# 3219

# %%
# Total number of different PDBs
len(PDB.select())
# Out:
# 3078

# %%
# PDBs with no sites (expected 0)
[(pdb.entry_id, pdb) for p in PDB.select() if len(p.sites) == 0]
# Out:
# []

# %%
# Number of sites in PDBs
set(len(p.sites) for p in PDB.select())
# Out:
# {1, 2, 3, 4}

# %%
# Modulator identifier fields used
set(tuple(s.modulator.keys()) for s in Site.select())
# Out:
# {('label_asym_id',)}

# %%
# Number of different entity instances (different "label_asym_id") annotated as modulators to look for outliers
modulator_chains = dict(
    sorted(
        {s.id: len(s.modulator["label_asym_id"]) for s in Site.select()}.items(),
        key=lambda i: i[-1], reverse=True
    )
)
modulator_chains
# Out:
# {520: 24,
#  582: 8,
#  608: 6,
#  4806: 6,
#  5088: 6,
#  5246: 6,
#  5320: 6,
#  5365: 6,
#  160: 4,
#  187: 4,
#  193: 4,
#  368: 4,
#  380: 4,
#  412: 4,
#  684: 4,
#  741: 4,
#  4493: 4,
#  4767: 4,
#  336: 3,
#  419: 3,
#  481: 3,
#  482: 3,
#  483: 3,
#  552: 3,
#  569: 3,
#  570: 3,
#  592: 3,
#  599: 3,
#  615: 3,
#  624: 3,
#  2319: 3,
#  2327: 3,
#  2334: 3,
#  2633: 3,
#  4542: 3,
#  4559: 3,
#  4577: 3,
#  4590: 3,
#  4636: 3,
#  4733: 3,
#  4834: 3,
#  4842: 3,
#  4863: 3,
#  4886: 3,
#  4907: 3,
#  4929: 3,
#  4949: 3,
#  4966: 3,
#  4979: 3,
#  4992: 3,
#  5002: 3,
#  5003: 3,
#  5122: 3,
#  5143: 3,
#  5190: 3,
#  5200: 3,
#  5267: 3,
#  5272: 3,
#  5382: 3,
#  5463: 3,
#  5471: 3,
#  5474: 3,
#  5: 2,
#  14: 2,
#  51: 2,
#  75: 2,
#  81: 2,
#  91: 2,
#  92: 2,
#  93: 2,
#  94: 2,
#  95: 2,
#  97: 2,
#  136: 2,
#  140: 2,
#  144: 2,
#  147: 2,
#  150: 2,
#  153: 2,
#  168: 2,
#  175: 2,
#  198: 2,
#  248: 2,
#  254: 2,
#  269: 2,
#  272: 2,
#  288: 2,
#  318: 2,
# ...

# %%
db.close()
# Out:
# True
